# %% [markdown]
# #### 모듈

# %%
import os
import os.path as path
import glob

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
import numpy as np

# %% [markdown]
# #### 함수 정의

# %%
def read_sample(path, samplesize=4000000):
    # set
    df = []
    # read
    temp = pd.read_csv(path, chunksize=2000000)
    
    # append and union
    for chunk in temp:
        df.append(chunk)
    
    # check df length
    if len(df) == 1:
        df = df[0]
    else:
        df = pd.concat(df, ignore_index=True)
    
    # sample and drop duplicates
    if df.shape[0] > samplesize:
        df = df.sample(samplesize, replace=True)
        df.drop_duplicates(inplace=True)
        df.reset_index(drop=True, inplace=True) 
        
    return df

# %% [markdown]
# #### 파일 탐색

# %%
BaseFilePath = 'd:\Codeit\intermediate_project'
filelist = os.listdir(BaseFilePath)

# filter filename
dirname = [f for f in filelist if not f.endswith('.zip')][1]
print(dirname)
# Out:
# 주제 2. 구독서비스 프로덕트 데이터 분석
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\4155365745.py:1: SyntaxWarning: invalid escape sequence '\C'
#   BaseFilePath = 'd:\Codeit\intermediate_project'

# %%
# set
DF = []
dfs = []
common_cols = []
all_cols = []
core_cols = ['user_id', 'event_type', 'client_event_time']

# get filelist
filelist = os.listdir(path.join(BaseFilePath, dirname))

# read csv files and check common columns
for filename in filelist:
    # csv
    if filename.endswith('.csv'):
        print('csv file found')
    
        # read csv
        df = read_sample(path.join(BaseFilePath, dirname, filename))

        # if common columns are not set, set it            
        if common_cols == [] and list(df.columns):
            common_cols = list(df.columns)
        
        # if common columns are set, check common columns
        common_cols = list(set(common_cols).intersection(set(df.columns)))
        all_cols = list(set(all_cols).union(set(df.columns)))

        ## preprocessing
        # drop device_carrier
        df = df.drop('device_carrier', axis=1)
        # convert client_event_time to datetime
        df['client_event_time'] = pd.to_datetime(df['client_event_time'])
        # convert os_version to string
        df['os_version'] = df['os_version'].astype(str)
        # # before update, fillna with '0'
        # df.fillna({'country' : '0', 'city' : '0', 'device_type' : '0', 'device_family' : '0'}, inplace=True)
        
        # update
        dfs.append(df)

    # if not csv, just pass    
    else:
        print('other file found')
        print(filename)

print(common_cols)
# Out:
# csv file found
# csv file found
# csv file found
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\4143787329.py:8: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in temp:
# csv file found
# csv file found
# csv file found
# csv file found
# csv file found
# csv file found
# csv file found
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\4143787329.py:8: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in temp:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\4143787329.py:8: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in temp:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\4143787329.py:8: DtypeWarning: Columns (9,13,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in temp:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\4143787329.py:8: DtypeWarning: Columns (9,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in temp:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\4143787329.py:8: DtypeWarning: Columns (9,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in temp:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\4143787329.py:8: DtypeWarning: Columns (13,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in temp:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\4143787329.py:8: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in temp:
# csv file found
# csv file found
# csv file found
# csv file found
# csv file found
# csv file found
# csv file found
# other file found
# 중급1_구독서비스 데이터 이벤트 명세서.xlsx
# ['city', 'device_family', 'client_event_time', 'user_id', 'event_type', 'os_version', 'country', 'device_carrier', 'os_name', 'device_type', 'platform', 'language']

# %%
# set unique values of common columns
col_unique_dict = dict(map(lambda x: (x, set()), all_cols))
print("\n\n", col_unique_dict)

device_and_familiy = set()
country_and_city = set()

# read csv files and check common columns
for filename in filelist:
    # csv
    if filename.endswith('.csv'):
        print("\n\n", filename)
            
        print(df.columns)
        display(df.isna().sum())
    
        # read
        temp = pd.read_csv(path.join(BaseFilePath, dirname, filename), chunksize=2000000)

        # append and union
        for i, chunk in enumerate(temp):
            df = chunk
            print(i)
            
            # update unique values of common columns
            for col in all_cols:
                if col in ['device_carrier', 'client_event_time']:
                    continue
                if col not in df.columns:
                    continue
                
                print(col, len(df[col].unique()))
                col_unique_dict[col].update(df[col].unique())
                
            # update unique values of device_type and device_family
            device_and_familiy.update(set(df[['device_type', 'device_family']].value_counts().index))
            country_and_city.update(set(df[['country', 'city']].value_counts().index))

    # if not csv, just pass    
    else:
        print('other file found')
        print(filename)
# Out:
#  {'city': set(), 'paid_amount': set(), 'content.id': set(), 'button_name': set(), 'os_version': set(), 'lesson.id': set(), 'os_name': set(), 'language': set(), 'device_family': set(), 'plan.type': set(), 'device_carrier': set(), 'plan.price': set(), 'platform': set(), 'button.name': set(), 'user_id': set(), 'type': set(), 'trial.type': set(), 'device_type': set(), 'client_event_time': set(), 'country': set(), 'question.id': set(), 'coupon.discount_amount': set(), 'pg.type': set(), 'content.difficulty': set(), 'event_type': set(), 'is_free_trial': set(), 'is_trial': set()}
#
#
#  click.cancel_plan_button.csv
# Index(['city', 'client_event_time', 'country', 'device_carrier',
#        'device_family', 'device_type', 'event_type', 'language', 'os_name',
#        'os_version', 'platform', 'user_id'],
#       dtype='object')
# city                   153
# client_event_time        0
# country                  2
# device_carrier       17895
# device_family            0
# device_type            328
# event_type               0
# language                 0
# os_name                  0
# os_version               3
# platform                 0
# user_id               1042
# dtype: int64
# 0
# city 477
# os_version 431
# os_name 19
# language 9
# device_family 37
# platform 1
# user_id 14644
# device_type 111
# country 45
# event_type 1
#
#
#  click.content_page_more_review_button.csv
# Index(['city', 'client_event_time', 'country', 'device_carrier',
#        'device_family', 'device_type', 'event_type', 'language', 'os_name',
#        'os_version', 'platform', 'user_id'],
#       dtype='object')
# city                   153
# client_event_time        0
# country                  2
# device_carrier       17895
# device_family            0
# device_type            328
# event_type               0
# language                 0
# os_name                  0
# os_version               3
# platform                 0
# user_id               1042
# dtype: int64
# 0
# city 276
# content.id 76
# os_version 313
# os_name 18
# language 7
# device_family 20
# platform 1
# user_id 3196
# device_type 83
# country 22
# event_type 1
#
#
#  click.content_page_start_content_button.csv
# Index(['city', 'client_event_time', 'country', 'device_carrier',
#        'device_family', 'device_type', 'event_type', 'language', 'os_name',
#        'os_version', 'platform', 'user_id', 'content.id'],
#       dtype='object')
# city                   170
# client_event_time        0
# country                 18
# device_carrier       93962
# device_family            0
# device_type             53
# event_type               0
# language                 0
# os_name                  0
# os_version               3
# platform                 0
# user_id              83260
# content.id              24
# dtype: int64
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\3815697093.py:21: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(temp):
# 0
# city 843
# content.id 166
# button_name 5
# os_version 993
# os_name 25
# language 18
# device_family 144
# platform 1
# button.name 9
# user_id 35111
# device_type 233
# country 59
# event_type 1
#
#
#  click.lesson_page_related_question_box.csv
# Index(['city', 'client_event_time', 'country', 'device_carrier',
#        'device_family', 'device_type', 'event_type', 'language', 'os_name',
#        'os_version', 'platform', 'user_id', 'content.id', 'button.name',
#        'button_name'],
#       dtype='object')
# city                   3474
# client_event_time         0
# country                1416
# device_carrier       172911
# device_family             0
# device_type            1330
# event_type                0
# language                  0
# os_name                   0
# os_version              318
# platform                  0
# user_id               44550
# content.id              212
# button.name           86669
# button_name          133960
# dtype: int64
# 0
# city 966
# content.id 114
# os_version 913
# lesson.id 3057
# os_name 23
# language 18
# device_family 74
# platform 1
# user_id 40408
# device_type 166
# country 55
# question.id 7796
# event_type 1
#
#
#  complete.lesson.csv
# Index(['city', 'client_event_time', 'country', 'device_carrier',
#        'device_family', 'device_type', 'event_type', 'language', 'os_name',
#        'os_version', 'platform', 'user_id', 'question.id', 'content.id',
#        'lesson.id'],
#       dtype='object')
# city                   23461
# client_event_time          0
# country                14891
# device_carrier       1379136
# device_family              1
# device_type             6334
# event_type                 0
# language                   0
# os_name                    1
# os_version               213
# platform                   0
# user_id                52903
# question.id           554347
# content.id            554348
# lesson.id             554347
# dtype: int64
# 0
# city 847
# content.id 108
# os_version 697
# lesson.id 4151
# os_name 22
# language 13
# device_family 81
# platform 2
# user_id 28355
# device_type 159
# country 51
# event_type 1
# 1
# city 869
# content.id 158
# os_version 715
# lesson.id 4937
# os_name 22
# language 16
# device_family 54
# platform 2
# user_id 29266
# device_type 158
# country 54
# event_type 1
# 2
# city 673
# content.id 163
# os_version 693
# lesson.id 4827
# os_name 21
# language 13
# device_family 63
# platform 2
# user_id 23096
# device_type 159
# country 55
# event_type 1
#
#
#  complete.signup.csv
# Index(['city', 'client_event_time', 'country', 'device_carrier',
#        'device_family', 'device_type', 'event_type', 'language', 'os_name',
#        'os_version', 'platform', 'user_id', 'content.id', 'lesson.id'],
#       dtype='object')
# city                   51010
# client_event_time          0
# country                42398
# device_carrier       1405069
# device_family          18771
# device_type            36169
# event_type                 0
# language               18762
# os_name                18771
# os_version             18912
# platform               18762
# user_id                    0
# content.id                 0
# lesson.id                  0
# dtype: int64
# 0
# city 544
# os_version 845
# os_name 20
# language 17
# device_family 68
# platform 2
# user_id 145133
# type 7
# device_type 168
# country 57
# event_type 1
#
#
#  complete.subscription.csv
# Index(['city', 'client_event_time', 'country', 'device_carrier',
#        'device_family', 'device_type', 'event_type', 'language', 'os_name',
#        'os_version', 'platform', 'user_id', 'type'],
#       dtype='object')
# city                 100359
# client_event_time         0
# country               99377
# device_carrier       145133
# device_family         99366
# device_type          100474
# event_type                0
# language              99366
# os_name               99388
# os_version            99482
# platform              99366
# user_id                   0
# type                    175
# dtype: int64
# 0
# city 390
# paid_amount 41
# os_version 468
# os_name 19
# language 10
# device_family 35
# plan.price 12
# platform 2
# user_id 13881
# device_type 122
# country 38
# coupon.discount_amount 33
# pg.type 3
# event_type 1
#
#
#  end.content.csv
# Index(['city', 'client_event_time', 'country', 'device_carrier',
#        'device_family', 'device_type', 'event_type', 'language', 'os_name',
#        'os_version', 'platform', 'user_id', 'plan.price', 'paid_amount',
#        'coupon.discount_amount', 'pg.type'],
#       dtype='object')
# city                        532
# client_event_time             0
# country                     383
# device_carrier            14289
# device_family               375
# device_type                 525
# event_type                    0
# language                    375
# os_name                     381
# os_version                  390
# platform                    375
# user_id                       0
# plan.price                    0
# paid_amount                   0
# coupon.discount_amount        0
# pg.type                   12647
# dtype: int64
# 0
# city 712
# content.id 160
# os_version 678
# os_name 21
# language 14
# device_family 46
# platform 2
# user_id 29236
# device_type 134
# country 49
# event_type 1
#
#
#  enter.content_page.csv
# Index(['city', 'client_event_time', 'country', 'device_carrier',
#        'device_family', 'device_type', 'event_type', 'language', 'os_name',
#        'os_version', 'platform', 'user_id', 'content.id'],
#       dtype='object')
# city                   4302
# client_event_time         0
# country                3400
# device_carrier       120582
# device_family          1191
# device_type            1716
# event_type                0
# language               1190
# os_name                1195
# os_version             1220
# platform               1190
# user_id                   0
# content.id                0
# dtype: int64
# 0
# city 1867
# content.id 208
# os_version 1816
# os_name 31
# language 35
# device_family 291
# platform 1
# user_id 72707
# device_type 358
# country 112
# event_type 1
#
#
#  enter.lesson_page-002.csv
# Index(['city', 'client_event_time', 'country', 'device_carrier',
#        'device_family', 'device_type', 'event_type', 'language', 'os_name',
#        'os_version', 'platform', 'user_id', 'content.id'],
#       dtype='object')
# city                   30757
# client_event_time          0
# country                 7570
# device_carrier       1914257
# device_family            639
# device_type            23651
# event_type                 0
# language                   0
# os_name                  149
# os_version              2549
# platform                   0
# user_id               465168
# content.id                 0
# dtype: int64
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\3815697093.py:21: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(temp):
# 0
# city 615
# content.id 110
# os_version 636
# lesson.id 4098
# os_name 20
# language 13
# device_family 86
# platform 1
# user_id 19669
# device_type 172
# country 46
# event_type 1
# is_free_trial 1
# is_trial 3
# 1
# city 609
# content.id 111
# os_version 654
# lesson.id 4072
# os_name 21
# language 10
# device_family 87
# platform 1
# user_id 20031
# device_type 169
# country 47
# event_type 1
# is_free_trial 1
# is_trial 2
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\3815697093.py:21: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(temp):
# 2
# city 584
# content.id 111
# os_version 630
# lesson.id 4097
# os_name 22
# language 13
# device_family 99
# platform 1
# user_id 19688
# device_type 171
# country 46
# event_type 1
# is_free_trial 1
# is_trial 3
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\3815697093.py:21: DtypeWarning: Columns (9,13,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(temp):
# 3
# city 841
# content.id 112
# os_version 738
# lesson.id 4219
# os_name 24
# language 14
# device_family 83
# platform 1
# user_id 32870
# device_type 171
# country 53
# event_type 1
# is_free_trial 3
# is_trial 3
# 4
# city 813
# content.id 90
# os_version 409
# lesson.id 3775
# os_name 21
# language 14
# device_family 60
# platform 1
# user_id 27809
# device_type 154
# country 51
# event_type 1
# is_free_trial 3
# is_trial 1
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\3815697093.py:21: DtypeWarning: Columns (9,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(temp):
# 5
# city 800
# content.id 92
# os_version 451
# lesson.id 3844
# os_name 23
# language 14
# device_family 60
# platform 1
# user_id 27740
# device_type 154
# country 50
# event_type 1
# is_free_trial 3
# is_trial 1
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\3815697093.py:21: DtypeWarning: Columns (9,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(temp):
# 6
# city 791
# content.id 93
# os_version 419
# lesson.id 3814
# os_name 22
# language 13
# device_family 56
# platform 1
# user_id 27748
# device_type 146
# country 49
# event_type 1
# is_free_trial 3
# is_trial 1
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\3815697093.py:21: DtypeWarning: Columns (13,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(temp):
# 7
# city 766
# content.id 173
# os_version 809
# lesson.id 5101
# os_name 26
# language 18
# device_family 75
# platform 1
# user_id 31551
# device_type 181
# country 58
# event_type 1
# is_free_trial 3
# is_trial 3
# 8
# city 681
# content.id 173
# os_version 714
# lesson.id 4930
# os_name 23
# language 15
# device_family 67
# platform 1
# user_id 24511
# device_type 176
# country 52
# event_type 1
# is_free_trial 1
# is_trial 2
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\3815697093.py:21: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(temp):
# 9
# city 680
# content.id 172
# os_version 733
# lesson.id 4914
# os_name 23
# language 14
# device_family 72
# platform 1
# user_id 24498
# device_type 176
# country 61
# event_type 1
# is_free_trial 1
# is_trial 3
# 10
# city 560
# content.id 171
# os_version 630
# lesson.id 4756
# os_name 23
# language 10
# device_family 63
# platform 1
# user_id 17319
# device_type 157
# country 46
# event_type 1
# is_free_trial 1
# is_trial 2
#
#
#  enter.main_page.csv
# Index(['city', 'client_event_time', 'country', 'device_carrier',
#        'device_family', 'device_type', 'event_type', 'language', 'os_name',
#        'os_version', 'platform', 'user_id', 'content.id', 'is_trial',
#        'lesson.id', 'is_free_trial'],
#       dtype='object')
# city                   25232
# client_event_time          0
# country                17072
# device_carrier       1029707
# device_family             14
# device_type            13947
# event_type                 0
# language                   0
# os_name                    3
# os_version               121
# platform                   0
# user_id               216155
# content.id                42
# is_trial                   0
# lesson.id                  0
# is_free_trial        1029707
# dtype: int64
# 0
# city 3298
# os_version 2642
# os_name 41
# language 59
# device_family 642
# platform 1
# user_id 74489
# device_type 517
# country 172
# event_type 1
# 1
# city 898
# os_version 977
# os_name 24
# language 32
# device_family 186
# platform 1
# user_id 2288
# device_type 275
# country 109
# event_type 1
#
#
#  enter.payment_page.csv
# Index(['city', 'client_event_time', 'country', 'device_carrier',
#        'device_family', 'device_type', 'event_type', 'language', 'os_name',
#        'os_version', 'platform', 'user_id'],
#       dtype='object')
# city                   3424
# client_event_time         0
# country                  66
# device_carrier       133548
# device_family           142
# device_type            9991
# event_type                0
# language                  0
# os_name                 108
# os_version              547
# platform                  0
# user_id              126867
# dtype: int64
# 0
# city 779
# os_version 1071
# os_name 22
# language 18
# device_family 132
# platform 1
# user_id 63919
# device_type 230
# country 70
# event_type 1
#
#
#  enter.signup_page.csv
# Index(['city', 'client_event_time', 'country', 'device_carrier',
#        'device_family', 'device_type', 'event_type', 'language', 'os_name',
#        'os_version', 'platform', 'user_id'],
#       dtype='object')
# city                   2699
# client_event_time         0
# country                 162
# device_carrier       165061
# device_family             1
# device_type            5995
# event_type                0
# language                  0
# os_name                   0
# os_version              501
# platform                  0
# user_id                6227
# dtype: int64
# 0
# city 2472
# os_version 1996
# os_name 35
# language 59
# device_family 850
# platform 1
# user_id 1
# device_type 553
# country 181
# event_type 1
#
#
#  renew.subscription.csv
# Index(['city', 'client_event_time', 'country', 'device_carrier',
#        'device_family', 'device_type', 'event_type', 'language', 'os_name',
#        'os_version', 'platform', 'user_id'],
#       dtype='object')
# city                  15805
# client_event_time         0
# country                 514
# device_carrier       596829
# device_family            82
# device_type           29442
# event_type                0
# language                  0
# os_name                  75
# os_version             2179
# platform                  0
# user_id              596829
# dtype: int64
# 0
# city 422
# paid_amount 43
# os_version 369
# os_name 17
# language 10
# device_family 27
# plan.price 11
# platform 2
# user_id 7498
# device_type 100
# country 40
# coupon.discount_amount 37
# pg.type 4
# event_type 1
#
#
#  resubscribe.subscription.csv
# Index(['city', 'client_event_time', 'country', 'device_carrier',
#        'device_family', 'device_type', 'event_type', 'language', 'os_name',
#        'os_version', 'platform', 'user_id', 'plan.price', 'paid_amount',
#        'coupon.discount_amount', 'pg.type'],
#       dtype='object')
# city                        370
# client_event_time             0
# country                     289
# device_carrier            15945
# device_family               288
# device_type                 461
# event_type                    0
# language                    288
# os_name                     291
# os_version                  301
# platform                    288
# user_id                       0
# plan.price                    0
# paid_amount                   0
# coupon.discount_amount        0
# pg.type                   13213
# dtype: int64
# 0
# city 151
# paid_amount 22
# os_version 113
# os_name 14
# language 4
# device_family 14
# plan.price 4
# platform 2
# user_id 761
# device_type 34
# country 13
# coupon.discount_amount 19
# pg.type 3
# event_type 1
#
#
#  start.content.csv
# Index(['city', 'client_event_time', 'country', 'device_carrier',
#        'device_family', 'device_type', 'event_type', 'language', 'os_name',
#        'os_version', 'platform', 'user_id', 'plan.price', 'paid_amount',
#        'coupon.discount_amount', 'pg.type'],
#       dtype='object')
# city                       16
# client_event_time           0
# country                     7
# device_carrier            791
# device_family               7
# device_type                18
# event_type                  0
# language                    7
# os_name                     7
# os_version                  7
# platform                    7
# user_id                     0
# plan.price                  0
# paid_amount                 0
# coupon.discount_amount      0
# pg.type                   618
# dtype: int64
# 0
# city 724
# content.id 151
# os_version 925
# os_name 24
# language 14
# device_family 92
# platform 2
# user_id 42798
# device_type 200
# country 58
# content.difficulty 4
# event_type 1
#
#
#  start.free_trial.csv
# Index(['city', 'client_event_time', 'country', 'device_carrier',
#        'device_family', 'device_type', 'event_type', 'language', 'os_name',
#        'os_version', 'platform', 'user_id', 'content.id',
#        'content.difficulty'],
#       dtype='object')
# city                    3900
# client_event_time          0
# country                 2885
# device_carrier        124917
# device_family           2227
# device_type             4849
# event_type                 0
# language                2225
# os_name                 2246
# os_version              2332
# platform                2225
# user_id                    0
# content.id                 0
# content.difficulty         0
# dtype: int64
# 0
# city 391
# os_version 256
# os_name 17
# language 13
# device_family 24
# plan.type 3
# plan.price 3
# platform 2
# user_id 16310
# trial.type 2
# device_type 84
# country 39
# event_type 1
# other file found
# 중급1_구독서비스 데이터 이벤트 명세서.xlsx

# %%
# rename df
for df in dfs:
    df.rename(columns = {'button_name': 'button_name_A',
                         'button.name': 'button_name_B'}, inplace=True)
    df.rename(columns = (lambda x: x.replace('.', '_')), inplace=True)

# %%
print(common_cols)

for k, v in col_unique_dict.items():
    print(k, len(v))
    
print(len(device_and_familiy), device_and_familiy)
print(len(country_and_city), country_and_city)
# Out:
# ['city', 'device_family', 'client_event_time', 'user_id', 'event_type', 'os_version', 'country', 'device_carrier', 'os_name', 'device_type', 'platform', 'language']
# city 4340
# device_family 1120
# client_event_time 0
# user_id 179758
# event_type 17
# os_version 3086
# country 189
# device_carrier 0
# os_name 44
# device_type 652
# platform 2
# language 71
# 690 {('Samsung Galaxy Z Fold4', 'Samsung Phone'), ('Samsung Galaxy A50s', 'Samsung Phone'), ('Oppo A5 2020', 'Oppo Phone'), ('Oppo OPPO Reno5 Z', 'Oppo Phone'), ('Huawei M3', 'Huawei TV'), ('Sony Xperia 10 III', 'Sony Phone'), ('Redmi K20', 'Redmi Phone'), ('Xiaomi Redmi 5 Plus', 'Xiaomi Phone'), ('Samsung Galaxy A7(2017)', 'Samsung Phone'), ('Realme 5pro', 'Realme Phone'), ('Samsung Galaxy A02', 'Samsung Phone'), ('ZTE Trek 2 HD', 'ZTE Tablet'), ('Google Pixel 3', 'Google Phone'), ('Apple iPhone 13', 'Apple iPhone'), ('Apple iPad Air 4th Gen (Wi-Fi Only)', 'Apple iPad'), ('Samsung Galaxy Folder', 'Samsung Phone'), ('Samsung Galaxy Note Fan Edition', 'Samsung Phone'), ('Samsung Galaxy S II', 'Samsung Galaxy Phone'), ('Apple iPad Pro', 'Apple iPad'), ('Apple iPad 10.9" 10th Gen (Wi-Fi Only)', 'Apple iPad'), ('Apple iPad Mini 4', 'Apple iPad'), ('Samsung Galaxy A31', 'Samsung Galaxy Phone'), ('Samsung Galaxy M20', 'Samsung Phone'), ('Samsung Galaxy S8+ Duos', 'Samsung Galaxy Phone'), ('Samsung Galaxy Tab A (8.4", 2020)', 'Samsung Tablet'), ('Samsung Galaxy A33 5G', 'Samsung Phone'), ('HTC Desire 20 Pro', 'HTC Phone'), ('Vivo V2118A', 'Vivo Phone'), ('Realme 3Pro', 'Realme Phone'), ('Huawei HONOR 20', 'Huawei Phone'), ('Realme RMX2040', 'Realme Phone'), ('Samsung Galaxy A30', 'Samsung Phone'), ('Samsung Galaxy M42 5G', 'Samsung Phone'), ('Google Pixel 3a', 'Google Phone'), ('Samsung Galaxy A71 5G', 'Samsung Galaxy Phone'), ('Oppo A9 2020', 'Oppo Phone'), ('Samsung Galaxy Z Fold2 5G', 'Samsung Phone'), ('HTC Desire 21 Pro 5G', 'HTC Phone'), ('Google Pixel 7', 'Google Phone'), ('Huawei Y9 Prime (2019)', 'Huawei Phone'), ('Samsung Galaxy Tab S6', 'Samsung Tablet'), ('Samsung Galaxy S22+', 'Samsung Phone'), ('Samsung Galaxy S23 5G', 'Samsung Phone'), ('Xiaomi Redmi 3S', 'Xiaomi Phone'), ('Samsung Galaxy 9 Plus', 'Samsung Galaxy Phone'), ('Redmi K30', 'Redmi Phone'), ('Sony Xperia Ace III', 'Sony Phone'), ('Samsung Galaxy M02s', 'Samsung Phone'), ('Samsung Galaxy A7', 'Samsung Galaxy Phone'), ('Samsung Galaxy A20', 'Samsung Phone'), ('Samsung Galaxy J7 Max', 'Samsung Phone'), ('Samsung Galaxy A7 (2018)', 'Samsung Phone'), ('Samsung Galaxy J7', 'Samsung Galaxy Phone'), ('Redmi Note 9 Pro', 'Redmi Phone'), ('Samsung Galaxy F62', 'Samsung Phone'), ('BlackBerry KEY2', 'Blackberry Phone'), ('Samsung Galaxy S20 FE 5G', 'Samsung Phone'), ('Samsung Galaxy Wide2', 'Samsung Phone'), ('Apple iPad Pro 11 inch 2nd Gen', 'Apple iPad'), ('Vivo Y66', 'Vivo Phone'), ('Google Pixel 4a', 'Google Phone'), ('Samsung Galaxy J6', 'Samsung Galaxy Phone'), ('Xiaomi MI CC 9', 'Xiaomi Phone'), ('Samsung Galaxy A10e', 'Samsung Galaxy Phone'), ('Huawei Mate 20 Pro', 'Huawei Phone'), ('Apple iPad 6', 'Apple iPad'), ('Samsung Galaxy Z Fold3 5G', 'Samsung Phone'), ('Huawei Mate 10 Lite', 'Huawei Phone'), ('Realme C17', 'Realme Phone'), ('Samsung Galaxy Note 3', 'Samsung Galaxy Note'), ('Apple iPhone 7', 'Apple iPhone'), ('Samsung Galaxy Note 10', 'Samsung Galaxy Note'), ('Huawei HUAWEI Mate 20 X (5G)', 'Huawei Phone'), ('Samsung Galaxy Tab S9+ 5G', 'Samsung Tablet'), ('Google Pixel', 'Google Phone'), ('Motorola moto g22', 'Motorola Phone'), ('Fairphone3', 'Fairphone Phone'), ('Apple iPad Pro 11" 3rd Gen (Wi-Fi/Cellular)', 'Apple iPad'), ('Oppo CPH1729', 'Oppo Phone'), ('Samsung Galaxy S23', 'Samsung Phone'), ('Realme narzo 30', 'Realme Phone'), ('Apple iPhone 15', 'Apple iPhone'), ('Xiaomi Redmi Note 7 Pro', 'Xiaomi Phone'), ('Samsung Galaxy M52 5G', 'Samsung Phone'), ('Samsung Galaxy A6', 'Samsung Phone'), ('Xiaomi Redmi Note 5A', 'Xiaomi Phone'), ('Apple iPad Pro 3', 'Apple iPad'), ('Huawei HUAWEI P30', 'Huawei Phone'), ('Samsung Galaxy A20e', 'Samsung Galaxy Phone'), ('Samsung Galaxy J7 Core', 'Samsung Galaxy Phone'), ('Samsung Galaxy Note', 'Samsung Galaxy Note'), ('Motorola moto g32', 'Motorola Phone'), ('Samsung Galaxy Tab S7+ 5G', 'Samsung Tablet'), ('Samsung Galaxy A10', 'Samsung Galaxy Phone'), ('Samsung Galaxy S8+', 'Samsung Galaxy Phone'), ('Samsung Galax ...
# 4412 {('United States', 'Stanardsville'), ('United States', 'Newnan'), ('Brazil', 'Porto Alegre'), ('South Korea', 'Ulleung-gun'), ('Australia', 'Koo-Wee-Rup'), ('Germany', 'Oberursel'), ('United States', 'Charlottesville'), ('Germany', 'Gifhorn'), ('India', 'Shillong'), ('United States', 'Seattle'), ('United States', 'Alpine'), ('Japan', 'Hakuba'), ('Philippines', 'Pinagbuhatan'), ('United States', 'Yuba City'), ('South Korea', 'Yangsan'), ('Portugal', 'Vila Nova de Gaia'), ('India', 'Phagwara'), ('Poland', 'Katowice'), ('South Korea', 'Cheorwon-gun'), ('Hungary', 'Veresegyhaz'), ('United States', 'Highlands Ranch'), ('United States', 'San Marcos'), ('New Zealand', 'Nelson'), ('United States', 'Stevenson Ranch'), ('Bangladesh', 'Khilgaon'), ('United States', 'Waco'), ('United States', 'Pooler'), ('Germany', 'Braunschweig'), ('Faroe Islands', 'Nes'), ('Sweden', 'Ängelholm'), ('Germany', 'Waiblingen'), ('South Korea', 'Iksan'), ('South Korea', 'Suncheon'), ('Netherlands', 'Alblasserdam'), ('Ukraine', 'Kropyvnytskyi'), ('Spain', 'la Senia'), ('Japan', 'Shiki'), ('United Kingdom', 'Westcliff-on-Sea'), ('South Korea', 'Pocheon-si'), ('Japan', 'Daikan'), ('United States', 'Moreno Valley'), ('China', 'Hebi'), ('Switzerland', 'Payerne'), ('Indonesia', 'Bandung'), ('United States', 'Allentown'), ('Bangladesh', 'Karimganj'), ('Denmark', 'Birkerød'), ('Ethiopia', 'Addis Ababa'), ('South Korea', 'Pyeongchang'), ('Canada', 'Port Elgin'), ('Japan', 'Sunahara'), ('United States', 'Arlington Heights'), ('Japan', 'Nishinomiya'), ('Canada', 'Hamilton'), ('Netherlands', 'Roosendaal'), ('United States', 'Crown Point'), ('United States', "'Ewa Beach"), ('United States', 'Brainerd'), ('South Korea', 'Yeongdong-gun'), ('Sweden', 'Borlänge'), ('Thailand', 'Nonthaburi'), ('South Korea', 'Yeosu-dong'), ('United States', 'Phoenix'), ('India', 'Siliguri'), ('Indonesia', 'Selong'), ('South Korea', 'Hwacheon'), ('South Korea', 'Jamsil'), ('United States', 'Urbana'), ('United States', 'Pacoima'), ('India', 'Karur'), ('Japan', 'Kyotango-shi'), ('Israel', 'Raanana'), ('United States', 'Beaumont'), ('Canada', 'Coquitlam'), ('United States', 'Huntingdon'), ('Japan', 'Heiwajima'), ('Egypt', 'Al Fayyum'), ('Rwanda', 'Kigali'), ('United Kingdom', 'Mitcham'), ('United States', 'Orlando'), ('India', 'Pathankot'), ('Sri Lanka', 'Homagama'), ('Australia', 'Taree'), ('Japan', 'Ayabe'), ('United Kingdom', 'Isleworth'), ('United Kingdom', 'Durham'), ('United Kingdom', 'Cambridge'), ('India', 'Kadi'), ('South Korea', 'Hayang'), ('Thailand', 'Trang'), ('United States', 'Los Altos'), ('United States', 'Bellevue'), ('Japan', 'Suguecho'), ('South Korea', 'Seocho-gu'), ('United States', 'Little Rock'), ('India', 'Indore'), ('United Kingdom', 'Camberwell'), ('United States', 'Cordova'), ('Morocco', 'Fes'), ('United States', 'Gualala'), ('United States', 'Clovis'), ('Canada', 'Nepean'), ('Japan', 'Higashiikebukuro'), ('United Kingdom', 'Nottingham'), ('Japan', 'Gifu City'), ('South Korea', 'Dongjak-gu'), ('India', 'Solan'), ('Poland', 'Ząbki'), ('South Korea', 'Jindo-gun'), ('China', 'Menghutun'), ('United States', 'Sullivan'), ('United States', 'Novato'), ('Japan', 'Sagamino'), ('South Korea', 'Jiya'), ('India', 'Nidadavole'), ('Sri Lanka', 'Kelaniya'), ('Germany', 'Starnberg'), ('Philippines', 'Taytay'), ('Germany', 'Hatzenport'), ('Pakistan', 'Chakwal'), ('Australia', 'Newtown'), ('United States', 'Delaware'), ('South Korea', 'Jungnang-gu'), ('South Korea', 'Hanam'), ('United States', 'Garden Grove'), ('Taiwan', 'Hsinchu'), ('Morocco', 'Marrakesh'), ('United States', 'Oyster Bay'), ('United States', 'Bryan'), ('Taiwan', 'New Taipei'), ('United States', 'Sherborn'), ('United States', 'Goleta'), ('United States', 'Richmond'), ('Mexico', 'Ixtapa-Zihuatanejo'), ('United States', 'Salt Lake City'), ('Morocco', 'Settat'), ('Bangladesh', 'Pabna'), ('Spain', 'Vigo'), ('United States', 'Phenix City'), ('South Korea', 'Sunchang-gun'), ('United States', 'Syracuse'), ('Egypt', 'Rosetta' ...

# %% [markdown]
# #### 로그 시간 중복 체크
# - 동일한 유저ID에 대해 같은 로그가 짧은 시간 내에 발생했는지 확인해봅니다.

# %%
def check_too_close_log(df, offset = 1):
    ## error handling
    
    # check 'user_id' column
    if 'user_id' not in df.columns:
        print("'user_id' column not found")
        return
    
    # check 'client_event_time' column
    if 'client_event_time' not in df.columns:
        print("'client_event_time' column not found")
        return
    
    # if 'client_event_time' is str, convert to datetime
    if type(df['client_event_time']) == str:    
        df['client_event_time'] = pd.to_datetime(df['client_event_time'])

    ## main

    # drop duplicate
    temp = df.drop_duplicates().copy()
    print(f"drop duplicate : {df.shape[0] - temp.shape[0]} \\")
    df = temp.copy()
    
    # 'user_id' - max conut
    temp = df.groupby('user_id')['user_id'].count().sort_values(ascending=False)
    print(f"'user_id' - max conut : {temp.max()} \\")

    # over 1
    df_len = df.shape[0]
    print(f"over 1 : {((temp > 1).sum() / df_len * 100).round(2)}% \\" )
    
    # 'user_id', 'client_event_time' - max conut
    temp = df.groupby(['user_id', 'client_event_time'])['client_event_time']\
        .count()\
        .sort_values(ascending=False)
    print(f"'user_id', 'client_event_time' - max conut : {temp.max()} \\\n")
    
    if temp.max() > 1:
        mask = df.duplicated(subset=['user_id', 'client_event_time'], keep=False)
        display(df[mask].sort_values(['user_id', 'client_event_time']).head(10))
    
    # too_close_log check
    temp = df.sort_values(['user_id', 'client_event_time'])\
            .groupby('user_id')['client_event_time']\
            .diff().dt.total_seconds()
    temp = temp.dropna()
    temp = temp.sort_values(ascending=False)
    
    # display
    print(temp.head(3))
    print(temp.tail(3), '\n\n')
    
    # display too close log
    if (temp < offset).sum() > (temp == 0).sum():
        cnt = (temp < offset).sum() - (temp == 0).sum()
        print(f"too close log : {cnt}, {(cnt / df_len * 100).round(2)}%")
        indexs = temp[((temp < offset) & (~(temp == 0)))].index
        display(df[df.index.isin(indexs)].sort_values(['user_id', 'client_event_time']))

# %%
for i, df in enumerate(dfs):
    print(f"df {i} : {filelist[i]}\n")
    check_too_close_log(df)
# Out:
# df 0 : click.cancel_plan_button.csv
#
# drop duplicate : 0 \
# 'user_id' - max conut : 5 \
# over 1 : 10.57% \
# 'user_id', 'client_event_time' - max conut : 1 \
#
# 13634    6.254757e+07
# 14740    5.942373e+07
# 17081    5.907468e+07
# Name: client_event_time, dtype: float64
# 2399     91846.818
# 12453    91119.474
# 17484    88814.777
# Name: client_event_time, dtype: float64
#
#
# df 1 : click.content_page_more_review_button.csv
#
# drop duplicate : 1 \
# 'user_id' - max conut : 285 \
# over 1 : 1.33% \
# 'user_id', 'client_event_time' - max conut : 2 \
#           city       client_event_time      country device_family device_type  \
# 1816     Seoul 2022-08-09 14:10:03.284  South Korea       Android     Android
# 82828    Busan 2022-08-09 14:10:03.284  South Korea       Android     Android
# 21769    Seoul 2022-01-18 04:12:34.843  South Korea       Windows     Windows
# 22061  Mapo-gu 2022-01-18 04:12:34.843  South Korea       Windows     Windows
#
#                                   event_type language          os_name  \
# 1816   click.content_page_more_review_button   Korean  Samsung Browser
# 82828  click.content_page_more_review_button   Korean  Samsung Browser
# 21769  click.content_page_more_review_button   Korean           Chrome
# 22061  click.content_page_more_review_button   Korean           Chrome
#
#       os_version platform                           user_id  \
# 1816          17      Web  e981a36d8407fd4cdfe789572e7b619d
# 82828         17      Web  e981a36d8407fd4cdfe789572e7b619d
# 21769         96      Web                               NaN
# 22061         96      Web                               NaN
#
#                              content_id
# 1816   c269eb6df3a374b464f7c18f12fa398f
# 82828  c269eb6df3a374b464f7c18f12fa398f
# 21769  68a3658f1b936bfff3bd6960cd561b0a
# 22061  68a3658f1b936bfff3bd6960cd561b0a
# 92747    5.926830e+07
# 93121    5.228160e+07
# 93329    4.749847e+07
# Name: client_event_time, dtype: float64
# 93746    0.053
# 16180    0.045
# 82828    0.000
# Name: client_event_time, dtype: float64
#
#
# too close log : 291, 0.31%
#              city       client_event_time      country device_family  \
# 14057   Yongin-si 2022-05-31 07:29:29.451  South Korea       Windows
# 34259     Mapo-gu 2022-03-04 13:22:24.682  South Korea           Mac
# 34260     Mapo-gu 2022-03-04 13:22:25.583  South Korea           Mac
# 34264     Mapo-gu 2022-03-04 13:22:31.861  South Korea           Mac
# 34267     Mapo-gu 2022-03-04 13:22:34.924  South Korea           Mac
# ...           ...                     ...          ...           ...
# 51097     Daejeon 2022-02-02 07:30:18.125  South Korea       Windows
# 51099     Daejeon 2022-02-02 07:30:19.566  South Korea       Windows
# 504    Gangnam-gu 2023-04-21 15:22:49.071  South Korea       Windows
# 69308  Gangnam-gu 2022-05-09 03:55:01.717  South Korea           Mac
# 69309  Gangnam-gu 2022-05-09 03:55:02.684  South Korea           Mac
#
#       device_type                             event_type language os_name  \
# 14057     Windows  click.content_page_more_review_button   Korean  Chrome
# 34259         Mac  click.content_page_more_review_button  English  Chrome
# 34260         Mac  click.content_page_more_review_button  English  Chrome
# 34264         Mac  click.content_page_more_review_button  English  Chrome
# 34267         Mac  click.content_page_more_review_button  English  Chrome
# ...           ...                                    ...      ...     ...
# 51097     Windows  click.content_page_more_review_button   Korean  Chrome
# 51099     Windows  click.content_page_more_review_button   Korean  Chrome
# 504       Windows  click.content_page_more_review_button   Korean  Chrome
# 69308         Mac  click.content_page_more_review_button   Korean  Chrome
# 69309         Mac  click.content_page_more_review_button   Korean  Chrome
#
#       os_version platform                           user_id  \
# 14057        101      Web  01f1e7ad72a4038cf9bfb891f1342848
# 34259         98      Web  0386abdf5e2b082d78084a8e325ed4ad
# 34260         98      Web  0386abdf5e2b082d78084a8e325ed4ad
# 34264         98      Web  0386abdf5e2b082d78084a8e325ed4ad
# 34267         98      Web  0386abdf5e2b082d78084a8e325ed4ad
# ...          ...      ...                               ...
# 51097         97      Web  faeaa6ea8b113fe9348a60503160a8d3
# 51099         97      Web  faeaa6ea8b113fe9348a60503160a8d3
# 504    112.0.0.0      Web  fb1ce3bb2441b0d581a266decdd661a4
# 69308        101      Web  ff3f3faf7543abd0b97db79f472f67db
# 69309        101      Web  ff3f3faf7543abd0b97db79f472f67db
#
#                              content_id
# 14057  32cf55a55adcc30ad80b674c0fee2ff4
# 34259  f4be1a0fe0e301b03115591777fddf29
# 34260  f4be1a0fe0e301b03115591777fddf29
# 34264  f4be1a0fe0e301b03115591777fddf29
# 34267  f4be1a0fe0e301b03115591777fddf29
# ...                                 ...
# 51097  e543c38ec7fa6bcd5045049ecc31e5f8
# 51099  e543c38ec7fa6bcd5045049ecc31e5f8
# 504    38df90d4de533d6296b52c6a1d90e26b
# 69308  f4be1a0fe0e301b03115591777fddf29
# 69309  f4be1a0fe0e301b03115591777fddf29
#
# [291 rows x 12 columns]
# df 2 : click.content_page_start_content_button.csv
#
# drop duplicate : 378 \
# 'user_id' - max conut : 254 \
# over 1 : 11.31% \
# 'user_id', 'client_event_time' - max conut : 3 \
#                 city       client_event_time      country device_family  \
# 99160          Seoul 2022-05-06 05:33:30.223  South Korea       Windows
# 121090       Mapo-gu 2022-05-06 05:33:30.223  South Korea       Windows
# 57589      Jongno-gu 2021-12-26 14:28:32.078  South Korea       Android
# 74949      Anyang-si 2021-12-26 14:28:32.078  South Korea       Android
# 57590      Jongno-gu 2021-12-26 14:40:22.619  South Korea       Android
# 74950      Anyang-si 2021-12-26 14:40:22.619  South Korea       Android
# 116912       Dong-gu 2022-02-26 13:20:14.796  South Korea       Android
# 123268        Seo-gu 2022-02-26 13:20:14.796  South Korea       Android
# 134218     Dalseo-gu 2022-02-26 13:20:14.796  South Korea       Android
# 2904    Eunpyeong-gu 2022-11-17 17:20:53.258  South Korea       Windows
#
#        device_type                               event_type language  \
# 99160      Windows  click.content_page_start_content_button   Korean
# 121090     Windows  click.content_page_start_content_button   Korean
# 57589      Android  click.content_page_start_content_button   Korean
# 74949      Android  click.content_page_start_content_button   Korean
# 57590      Android  click.content_page_start_content_button   Korean
# 74950      Android  click.content_page_start_content_button   Korean
# 116912     Android  click.content_page_start_content_button   Korean
# 123268     Android  click.content_page_start_content_button   Korean
# 134218     Android  click.content_page_start_content_button   Korean
# 2904       Windows  click.content_page_start_content_button   Korean
#
#                 os_name os_version platform                           user_id  \
# 99160            Chrome        100      Web  16e39802400a3a48d7f6761d1a2ba214
# 121090           Chrome        100      Web  16e39802400a3a48d7f6761d1a2ba214
# 57589   Samsung Browser         16      Web  35fe6a629c1bd6aa50debb8934416432
# 74949   Samsung Browser         16      Web  35fe6a629c1bd6aa50debb8934416432
# 57590   Samsung Browser         16      Web  35fe6a629c1bd6aa50debb8934416432
# 74950   Samsung Browser         16      Web  35fe6a629c1bd6aa50debb8934416432
# 116912  Samsung Browser         16      Web  b532f801fe996fbba59a5aa9ed99b227
# 123268  Samsung Browser         16      Web  b532f801fe996fbba59a5aa9ed99b227
# 134218  Samsung Browser         16      Web  b532f801fe996fbba59a5aa9ed99b227
# 2904             Chrome  107.0.0.0      Web                               NaN
#
#                               content_id button_name_B button_name_A
# 99160   68a3658f1b936bfff3bd6960cd561b0a           NaN          이어하기
# 121090  68a3658f1b936bfff3bd6960cd561b0a           NaN          이어하기
# 57589   f4be1a0fe0e301b03115591777fddf29           NaN          이어하기
# 74949   f4be1a0fe0e301b03115591777fddf29           NaN          이어하기
# 57590   f4be1a0fe0e301b03115591777fddf29           NaN          이어하기
# 74950   f4be1a0fe0e301b03115591777fddf29           NaN          이어하기
# 116912  f4be1a0fe0e301b03115591777fddf29           NaN          이어하기
# 123268  f4be1a0fe0e301b03115591777fddf29           NaN          이어하기
# 134218  f4be1a0fe0e301b03115591777fddf29           NaN          이어하기
# 2904    621c7ad99b17d2d16832b618d47aea7e    할인받고 구독 시작           NaN
# 160254    6.163596e+07
# 157347    5.965161e+07
# 157695    5.933250e+07
# Name: client_event_time, dtype: float64
# 74950     0.0
# 121090    0.0
# 134218    0.0
# Name: client_event_time, dtype: float64
#
#
# too close log : 3943, 2.29%
#                city       client_event_time        country device_family  \
# 39482         Seoul 2023-05-26 06:06:18.710    South Korea  Apple iPhone
# 130375        Seoul 2022-02-07 06:01:32.163    South Korea       Android
# 37653         Seoul 2023-05-17 01:43:03.130    South Korea       Windows
# 38772        Buk-gu 2023-05-23 12:16:34.631    South Korea       Windows
# 4314      Goyang-si 2023-05-12 03:17:46.045    South Korea           Mac
# ...             ...                     ...            ...           ...
# 51149   Hwaseong-si 2023-06-05 04:30:40.550    South Korea       Windows
# 116436    Songpa-gu 2022-10-30 07:49:48.744    South Korea           Mac
# 158203    Rockville 2023-08-27 03:09:14.199  United States       Windows
# 8813          Seoul 2023-06-03 06:29:35.195    South Korea           Mac
# 125070        Seoul 2022-09-08 23:48:12.617    South Korea  Apple iPhone
#
#                 device_type                               event_type language  \
# 39482   Apple iPhone 14 Pro  click.content_page_start_content_button   Korean
# 130375              Android  click.content_page_start_content_button   Korean
# 37653               Windows  click.content_page_start_content_button   Korean
# 38772               Windows  click.content_page_start_content_button   Korean
# 4314                    Mac  click.content_page_start_content_button   Korean
# ...                     ...                                      ...      ...
# 51149               Windows  click.content_page_start_content_button   Korean
# 116436                  Mac  click.content_page_start_content_button   Korean
# 158203              Windows  click.content_page_start_content_button  English
# 8813                    Mac  click.content_page_start_content_button   Korean
# 125070         Apple iPhone  click.content_page_start_content_button  English
#
#                os_name      os_version platform  \
# 39482        Instagram  283.0.0.16.103      Web
# 130375  Chrome WebView              90      Web
# 37653             Edge   113.0.1774.42      Web
# 38772             Edge   113.0.1774.50      Web
# 4314            Chrome       113.0.0.0      Web
# ...                ...             ...      ...
# 51149           Chrome       113.0.0.0      Web
# 116436          Chrome              98      Web
# 158203          Chrome       116.0.0.0      Web
# 8813            Safari            16.5      Web
# 125070   Mobile Safari              15      Web
#
#                                  user_id                        content_id  \
# 39482   000634ec5553ca63f77c61690353a0be  445fac33232adcb3d1cdab7d8a579430
# 130375  001cc7303b6b6d1cdf369589a53b45bb  c269eb6df3a374b464f7c18f12fa398f
# 37653   00246fef1a90451e4a3ac7c69b1e9b07  f491517f4737a60d661cd1fcacc702c0
# 38772   00246fef1a90451e4a3ac7c69b1e9b07  c269eb6df3a374b464f7c18f12fa398f
# 4314    00407142251a1d41ec06320a3890d629  c269eb6df3a374b464f7c18f12fa398f
# ...                                  ...                               ...
# 51149   ff1cae4c3d8938b99a6d8783467aded4  445fac33232adcb3d1cdab7d8a579430
# 116436  ff8ce46f26e5898f4fdbe1b25f8c30dc  5acd4977e14d5edc6a408ae0d468ca4e
# 158203  ff917e8b6bcf53a48bd1b1efae5d00f5  9aa7628a347707fb155943041e2cb524
# 8813    ffbf309d7d275b5c984276b6d77052ef  f4be1a0fe0e301b03115591777fddf29
# 125070  fff219b952002818462faa3746343f09  afe201c04b426366e0f8e9e2207c78c2
#
#        button_name_B button_name_A
# 39482       콘텐츠 구독하기           NaN
# 130375           NaN      무료로 시작하기
# 37653       콘텐츠 이어보기           NaN
# 38772       콘텐츠 구독하기           NaN
# 4314        콘텐츠 구독하기           NaN
# ...              ...           ...
# 51149       콘텐츠 구독하기           NaN
# 116436           NaN           NaN
# 158203      콘텐츠 구독하기           NaN
# 8813        콘텐츠 이어보기           NaN
# 125070           NaN           NaN
#
# [3943 rows x 14 columns]
# df 3 : click.lesson_page_related_question_box.csv
#
# drop duplicate : 84 \
# 'user_id' - max conut : 3828 \
# over 1 : 2.27% \
# 'user_id', 'client_event_time' - max conut : 2 \
#             city       client_event_time      country device_family  \
# 682097     Seoul 2022-05-04 01:04:56.803  South Korea       Windows
# 1021069  Mapo-gu 2022-05-04 01:04:56.803  South Korea       Windows
# 682098     Seoul 2022-05-04 01:05:31.407  South Korea       Windows
# 1021070  Mapo-gu 2022-05-04 01:05:31.407  South Korea       Windows
# 635465   Mapo-gu 2022-05-06 06:39:41.113  South Korea       Windows
# 682099     Seoul 2022-05-06 06:39:41.113  South Korea       Windows
# 635466   Mapo-gu 2022-05-06 06:39:55.321  South Korea       Windows
# 682100     Seoul 2022-05-06 06:39:55.321  South Korea       Windows
# 635467   Mapo-gu 2022-05-06 06:40:14.505  South Korea       Windows
# 682101     Seoul 2022-05-06 06:40:14.505  South Korea       Windows
#
#         device_type                              event_type language os_name  \
# 682097      Windows  click.lesson_page_related_question_box   Korean  Chrome
# 1021069     Windows  click.lesson_page_related_question_box   Korean  Chrome
# 682098      Windows  click.lesson_page_related_question_box   Korean  Chrome
# 1021070     Windows  click.lesson_page_related_question_box   Korean  Chrome
# 635465      Windows  click.lesson_page_related_question_box   Korean  Chrome
# 682099      Windows  click.lesson_page_related_question_box   Korean  Chrome
# 635466      Windows  click.lesson_page_related_question_box   Korean  Chrome
# 682100      Windows  click.lesson_page_related_question_box   Korean  Chrome
# 635467      Windows  click.lesson_page_related_question_box   Korean  Chrome
# 682101      Windows  click.lesson_page_related_question_box   Korean  Chrome
#
#         os_version platform                           user_id  \
# 682097          99      Web  16e39802400a3a48d7f6761d1a2ba214
# 1021069         99      Web  16e39802400a3a48d7f6761d1a2ba214
# 682098          99      Web  16e39802400a3a48d7f6761d1a2ba214
# 1021070         99      Web  16e39802400a3a48d7f6761d1a2ba214
# 635465         100      Web  16e39802400a3a48d7f6761d1a2ba214
# 682099         100      Web  16e39802400a3a48d7f6761d1a2ba214
# 635466         100      Web  16e39802400a3a48d7f6761d1a2ba214
# 682100         100      Web  16e39802400a3a48d7f6761d1a2ba214
# 635467         100      Web  16e39802400a3a48d7f6761d1a2ba214
# 682101         100      Web  16e39802400a3a48d7f6761d1a2ba214
#
#                               question_id                        content_id  \
# 682097   0b28d6a4bb7bc3cb8bb6b81530f909ca  68a3658f1b936bfff3bd6960cd561b0a
# 1021069  0b28d6a4bb7bc3cb8bb6b81530f909ca  68a3658f1b936bfff3bd6960cd561b0a
# 682098   adff87e0c3c9e81516931aceebee3e78  68a3658f1b936bfff3bd6960cd561b0a
# 1021070  adff87e0c3c9e81516931aceebee3e78  68a3658f1b936bfff3bd6960cd561b0a
# 635465   bc1ca8296f1d74a6a491882c371b09bb  68a3658f1b936bfff3bd6960cd561b0a
# 682099   bc1ca8296f1d74a6a491882c371b09bb  68a3658f1b936bfff3bd6960cd561b0a
# 635466   07665e22f8e778b1087b2b034945ac1d  68a3658f1b936bfff3bd6960cd561b0a
# 682100   07665e22f8e778b1087b2b034945ac1d  68a3658f1b936bfff3bd6960cd561b0a
# 635467   ad89be67aeeba2d148a2556c18c0f8fb  68a3658f1b936bfff3bd6960cd561b0a
# 682101   ad89be67aeeba2d148a2556c18c0f8fb  68a3658f1b936bfff3bd6960cd561b0a
#
#                                 lesson_id
# 682097   1238493aafb242e6bb8b6891271fa8a9
# 1021069  1238493aafb242e6bb8b6891271fa8a9
# 682098   1238493aafb242e6bb8b6891271fa8a9
# 1021070  1238493aafb242e6bb8b6891271fa8a9
# 635465   50c9c2132fc891b215cf5ab9647f2476
# 682099   50c9c2132fc891b215cf5ab9647f2476
# 635466   50c9c2132fc891b215cf5ab9647f2476
# 682100   50c9c2132fc891b215cf5ab9647f2476
# 635467   50c9c2132fc891b215cf5ab9647f2476
# 682101   50c9c2132fc891b215cf5ab9647f2476
# 1298815    6.061697e+07
# 1332685    6.028445e+07
# 1336197    6.025929e+07
# Name: client_event_time, dtype: float64
# 418502     0.0
# 418503     0.0
# 1021070    0.0
# Name: client_event_time, dtype: float64
#
#
# too close log : 46927, 3.4%
#                   city       client_event_time      country device_family  \
# 1096804  Pyeongtaek-si 2022-11-18 01:48:47.370  South Korea       Windows
# 881760     Gwangmyeong 2022-01-03 16:00:46.275  South Korea           Mac
# 881761     Gwangmyeong 2022-01-03 16:00:46.758  South Korea           Mac
# 462730      Gangbuk-gu 2022-04-04 05:13:52.372  South Korea       Windows
# 794030           Seoul 2022-01-04 10:29:27.700  South Korea           Mac
# ...                ...                     ...          ...           ...
# 808576       Songpa-gu 2022-01-22 03:04:30.264  South Korea       Windows
# 898127       Songpa-gu 2022-01-23 07:59:36.917  South Korea       Windows
# 375477       Songpa-gu 2022-01-26 03:43:31.375  South Korea       Windows
# 459822       Songpa-gu 2022-01-26 04:28:55.558  South Korea       Windows
# 240055       Songpa-gu 2022-01-26 05:27:20.823  South Korea       Windows
#
#         device_type                              event_type language os_name  \
# 1096804     Windows  click.lesson_page_related_question_box   Korean  Chrome
# 881760          Mac  click.lesson_page_related_question_box   Korean  Chrome
# 881761          Mac  click.lesson_page_related_question_box   Korean  Chrome
# 462730      Windows  click.lesson_page_related_question_box   Korean  Chrome
# 794030          Mac  click.lesson_page_related_question_box   Korean  Safari
# ...             ...                                     ...      ...     ...
# 808576      Windows  click.lesson_page_related_question_box   Korean    Edge
# 898127      Windows  click.lesson_page_related_question_box   Korean    Edge
# 375477      Windows  click.lesson_page_related_question_box   Korean    Edge
# 459822      Windows  click.lesson_page_related_question_box   Korean    Edge
# 240055      Windows  click.lesson_page_related_question_box   Korean    Edge
#
#         os_version platform                           user_id  \
# 1096804  107.0.0.0      Web  0003c0ede663b9e3b55d9dc3f7e8690f
# 881760          96      Web  000773425ea95bf12501964471e230ba
# 881761          96      Web  000773425ea95bf12501964471e230ba
# 462730          99      Web  0008a61888a167f7c68df68e9e76dcf7
# 794030          14      Web  0011e6528fca2d6c0b576cf6d8493639
# ...            ...      ...                               ...
# 808576          97      Web  fffcae39952c396123f9a3c0808a2183
# 898127          97      Web  fffcae39952c396123f9a3c0808a2183
# 375477          97      Web  fffcae39952c396123f9a3c0808a2183
# 459822          97      Web  fffcae39952c396123f9a3c0808a2183
# 240055          97      Web  fffcae39952c396123f9a3c0808a2183
#
#                               question_id                        content_id  \
# 1096804  f082779449d765221edcf903d0652dae  f64c475280676531a31f2f8e0648599c
# 881760                                NaN                               NaN
# 881761                                NaN                               NaN
# 462730   b28f061dcec78adc7de3bff76fbbdd63  c269eb6df3a374b464f7c18f12fa398f
# 794030                                NaN                               NaN
# ...                                   ...                               ...
# 808576                                NaN                               NaN
# 898127                                NaN                               NaN
# 375477                                NaN                               NaN
# 459822                                NaN                               NaN
# 240055                                NaN                               NaN
#
#                                 lesson_id
# 1096804  6b568dde9f9c1b2ad04d72b08e08cf99
# 881760                                NaN
# 881761                                NaN
# 462730   c2b88e494ee633b334aa081cac7b1f02
# 794030                                NaN
# ...                                   ...
# 808576                                NaN
# 898127                                NaN
# 375477                                NaN
# 459822                                NaN
# 240055                                NaN
#
# [46927 rows x 14 columns]
# df 4 : complete.lesson.csv
#
# drop duplicate : 0 \
# 'user_id' - max conut : 1748 \
# over 1 : 1.48% \
# 'user_id', 'client_event_time' - max conut : 2 \
#               city       client_event_time      country device_family  \
# 921930   Yongin-si 2022-11-09 04:03:27.510  South Korea           Mac
# 1598390  Yongin-si 2022-11-09 04:03:27.510  South Korea           Mac
# 151744   Seocho-gu 2022-11-17 02:02:23.897  South Korea           Mac
# 759659   Seocho-gu 2022-11-17 02:02:23.897  South Korea           Mac
#
#         device_type       event_type language os_name os_version platform  \
# 921930          Mac  complete.lesson   Korean  Chrome        107      Web
# 1598390         Mac  complete.lesson   Korean  Chrome        107      Web
# 151744          Mac  complete.lesson  English  Chrome  107.0.0.0      Web
# 759659          Mac  complete.lesson  English  Chrome  107.0.0.0      Web
#
#                                   user_id                        content_id  \
# 921930   43b0c4463cfe98f0e35c27cd4e6542a0  afe201c04b426366e0f8e9e2207c78c2
# 1598390  43b0c4463cfe98f0e35c27cd4e6542a0  afe201c04b426366e0f8e9e2207c78c2
# 151744   d5e0de700e4392e27a067986398e1511  f4be1a0fe0e301b03115591777fddf29
# 759659   d5e0de700e4392e27a067986398e1511  f4be1a0fe0e301b03115591777fddf29
#
#                                 lesson_id
# 921930   9ea1be3c92a8edd9cb3d4fd94a42e7e9
# 1598390  79196e7723938d50c50d28549e66e0d2
# 151744   23d6d66e597b8fb0a706fb0cd12234d6
# 759659   bfb6543cc0e7fa189f9c9a0e533b0f43
# 1995606    6.053286e+07
# 1262731    6.019358e+07
# 838755     5.966404e+07
# Name: client_event_time, dtype: float64
# 1877063    0.001
# 759659     0.000
# 1598390    0.000
# Name: client_event_time, dtype: float64
#
#
# too close log : 934, 0.03%
#                 city       client_event_time      country device_family  \
# 415036        Sydney 2022-04-01 23:53:07.992    Australia           Mac
# 884131     Jongno-gu 2022-02-28 11:43:51.745  South Korea       Windows
# 2681047  Changnyeong 2022-08-05 06:21:09.457  South Korea       Windows
# 872431   Changnyeong 2022-08-05 06:21:15.841  South Korea       Windows
# 1939077  Changnyeong 2022-08-05 06:21:18.607  South Korea       Windows
# ...              ...                     ...          ...           ...
# 2093677    Goyang-si 2022-02-05 01:54:55.083  South Korea       Windows
# 2753324        Daegu 2022-07-01 21:58:35.483  South Korea       Windows
# 1569241  Gangdong-gu 2022-01-02 08:52:52.763  South Korea       Windows
# 382308         Seoul 2022-12-14 08:08:08.975  South Korea       Windows
# 2433579  Seongbuk-gu 2023-09-20 07:02:46.974  South Korea           Mac
#
#         device_type       event_type language os_name os_version platform  \
# 415036          Mac  complete.lesson  English  Chrome         99      Web
# 884131      Windows  complete.lesson   Korean  Chrome         98      Web
# 2681047     Windows  complete.lesson   Korean  Chrome        104      Web
# 872431      Windows  complete.lesson   Korean  Chrome        104      Web
# 1939077     Windows  complete.lesson   Korean  Chrome        104      Web
# ...             ...              ...      ...     ...        ...      ...
# 2093677     Windows  complete.lesson   Korean  Chrome         98      Web
# 2753324     Windows  complete.lesson   Korean  Chrome        103      Web
# 1569241     Windows  complete.lesson   Korean  Chrome         96      Web
# 382308      Windows  complete.lesson   Korean  Chrome  108.0.0.0      Web
# 2433579         Mac  complete.lesson   Korean  Chrome  116.0.0.0      Web
#
#                                   user_id                        content_id  \
# 415036   002109ba574914ed127dcae867110f91  4641438a6c81ef572d997dbdc9100f8b
# 884131   0044b39967b380693517c187aaf75ba8  ff7998135d650dbefb3f479c900cbcc7
# 2681047  004d370605a898527804555b99ff3b4a  61b6463287573f00de13a930805a52d6
# 872431   004d370605a898527804555b99ff3b4a  61b6463287573f00de13a930805a52d6
# 1939077  004d370605a898527804555b99ff3b4a  61b6463287573f00de13a930805a52d6
# ...                                   ...                               ...
# 2093677  fbf58cef9af5e9c087c5318aef192687  7cebec6e79cc981dbf421c5ec2aedd9d
# 2753324  fcfba95911b5b4bf3810419673da7639  ab7068685b7aeac4d6b1a6c0e1c85819
# 1569241  fde46a4aa907c8a667e6ad6214b560cd  03b4a290c08f7fa83933827a994f2e61
# 382308   fe1f1a5866013621dbaacdb45caec398  db1819d3a7a4c4d85dccb3b9e982fbcd
# 2433579  ffc9d92bd89918869c13bab8acab5247  621c7ad99b17d2d16832b618d47aea7e
#
#                                 lesson_id
# 415036   aaf4677f8aec0d234696ff313a1eb586
# 884131   efd15a9acb8c27d70ea88b83c47c0a83
# 2681047  db421b66bfd27eccd0e862e30b4de1be
# 872431   c84ce096d3407c9ce4eebd380df44dbf
# 1939077  f024a88c9328cb19413c04f4cd51f979
# ...                                   ...
# 2093677  1dd275b54ba262b8488a3a9b1bae1e9e
# 2753324  7e321c9a00674f37e5bb650b5d382918
# 1569241  e4b37510a5a95f12355d86c3ef4bfd8c
# 382308   60bc3af1f168a5960bf7e37a06831cb8
# 2433579  71a92c1977097a2c50ec366e34ab75f9
#
# [934 rows x 13 columns]
# df 5 : complete.signup.csv
#
# drop duplicate : 0 \
# 'user_id' - max conut : 1 \
# over 1 : 0.0% \
# 'user_id', 'client_event_time' - max conut : 1 \
#
# Series([], Name: client_event_time, dtype: float64)
# Series([], Name: client_event_time, dtype: float64)
#
#
# df 6 : complete.subscription.csv
#
# drop duplicate : 2 \
# 'user_id' - max conut : 8 \
# over 1 : 2.51% \
# 'user_id', 'client_event_time' - max conut : 1 \
#
# 11965    6.168952e+07
# 12701    5.759283e+07
# 11144    3.994890e+07
# Name: client_event_time, dtype: float64
# 8995    0.002
# 9371    0.001
# 7629    0.001
# Name: client_event_time, dtype: float64
#
#
# too close log : 56, 0.39%
#                   city       client_event_time      country device_family  \
# 4916             Seoul 2022-11-08 09:20:01.878  South Korea           Mac
# 8476        Gangnam-gu 2022-11-11 17:10:01.852  South Korea       Windows
# 6836        Dongjak-gu 2022-11-17 12:30:02.728  South Korea       Windows
# 5186           Cheonan 2022-11-14 10:45:02.908  South Korea       Windows
# 8995         Yongin-si 2022-11-19 12:45:02.194  South Korea       Windows
# 5005              Gumi 2022-11-15 23:15:01.630  South Korea       Windows
# 5339       Gwangjin-gu 2022-11-14 03:25:02.424  South Korea       Windows
# 8474         Seocho-gu 2022-11-13 12:40:02.088  South Korea           Mac
# 9309             Seoul 2022-11-13 15:20:02.176  South Korea       Windows
# 5194             Seoul 2022-11-16 15:55:02.077  South Korea  Apple iPhone
# 9371        Gangnam-gu 2022-11-09 05:36:09.962  South Korea  Apple iPhone
# 3704             Seoul 2022-11-14 02:55:02.244  South Korea  Apple iPhone
# 5069        Siheung-si 2022-11-20 08:19:08.914  South Korea       Windows
# 6013             Seoul 2022-11-15 07:50:11.094  South Korea  Apple iPhone
# 6302   Yeongdeungpo-gu 2022-11-19 23:50:02.679  South Korea       Windows
# 7629             Suwon 2022-11-09 04:50:01.701  South Korea       Windows
# 9943        Gangseo-gu 2022-11-08 07:40:01.856  South Korea       Windows
# 6565            Seo-gu 2022-11-10 07:05:01.598  South Korea       Windows
# 10026            Wonju 2022-11-14 13:50:01.778  South Korea       Windows
# 6825               NaN 2022-11-14 11:15:02.681          NaN           NaN
# 8468        Dongjak-gu 2022-11-10 11:35:01.852  South Korea       Windows
# 5249             Seoul 2022-11-17 03:15:01.879  South Korea           Mac
# 8742           Cheonan 2022-11-15 08:00:01.859  South Korea           Mac
# 5066        Yongsan-gu 2022-11-20 08:44:42.156  South Korea       Windows
# 8159      Seongdong-gu 2022-11-09 10:25:02.398  South Korea       Windows
# 6364             Hanam 2022-11-12 04:25:02.677  South Korea       Windows
# 10247            Seoul 2022-11-16 09:05:01.665  South Korea  Apple iPhone
# 5213      Uijeongbu-si 2022-11-14 09:55:02.443  South Korea       Android
# 4585          Changwon 2022-11-16 07:30:02.537  South Korea       Windows
# 7762      Eunpyeong-gu 2022-11-15 12:00:01.717  South Korea           Mac
# 9284         Songpa-gu 2022-11-17 06:40:03.543  South Korea       Windows
# 8630       Hwaseong-si 2022-11-12 21:07:56.258  South Korea       Windows
# 8823             Seoul 2022-11-12 00:50:02.215  South Korea       Windows
# 7437         Goyang-si 2022-11-14 00:35:01.937  South Korea       Windows
# 3603        Yuseong-gu 2022-11-20 03:45:02.854  South Korea       Windows
# 6977             Seoul 2022-11-19 07:30:02.179  South Korea       Windows
# 6374         Songpa-gu 2022-11-09 13:05:01.882  South Korea       Windows
# 7982          Nowon-gu 2022-11-14 06:30:03.169  South Korea       Windows
# 8847             Seoul 2022-11-21 09:34:14.165  South Korea       Windows
# 10283         Gimpo-si 2022-11-11 01:35:02.019  South Korea       Windows
# 9513         Chuncheon 2022-11-14 07:50:02.044  South Korea       Windows
# 4168       Quezon City 2022-11-15 10:10:02.586  Philippines       Windows
# 9373             Seoul 2022-11-09 05:15:02.692  South Korea           Mac
# 9819             Seoul 2022-11-21 10:23:25.096  South Korea           Mac
# 6201      Geumjeong-gu 2022-11-20 14:11:54.386  South Korea       Windows
# 8236         Gwanak-gu 2022-11-16 05:45:01.933  South Korea       Windows
# 7601        Bucheon-si 2022-11-15 04:00:02.275  South Korea       Windows
# 10060     Eunpyeong-gu 2022-11-11 16:50:04.486  South Korea           Mac
# 6754        Gangnam-gu 2022-11-08 08:45:03.432  South Korea       Windows
# 5738         Gangneung 2022-11-17 04:30:43.430  South Korea       Windows
# 6535       Hwaseong-si 2022-11-20 04:45:01.679  South Korea           Mac
# 6866          Gimpo-si 2022-11-10 12:35:02.074  South Korea       Windows
# 7815           Incheon 2022-11-10 04:55:01.926  South Korea       Windows
# 5441            Nam-gu 2022-11-20 02:16:48.467  South Korea       Windows
# 10014       Yangp'yong 2022-11-16 16:00:02.554  South Korea  Apple iPhone
# 9282             Seoul 2022-11-17 06:20:03.875  South Korea           Mac
#
#         device_type             event_type language         os_name  \
# 4916            Mac  complete.subscription   Korean          Chrome
# 8476        Windows  complete.subscription   Korean          Chrome
# 6836        Windows  complete.subscription   Korean          Chrome
# 5186        Windows  complete.subscription   Korean          Chrome
# 8995        Windows  complete.subscription   Korean          Chrome
# 5005        Windows  complete.subscription   Korean            Edge
# 5339        Windows  complete.subscription   Korean          Chrome
# 8474            Mac  complete.subscription   Korean          Chrome
# 9309        Windows  complete.subscription   Korean            Edge
# 5194   Apple iPhone  complete.subscription   Korean   Mobile Safari
# 9371   Apple iPhone  complete.subscription   Korean   Mobile Safari
# 3704   Apple iPhone  complete.subscription   Korean   Mobile Safari
# 5069        Windows  complete.subscription   Korean          Chrome
# 6013   Apple iPhone  complete.subscription   Korean   Mobile Safari
# 6302        Windows  complete.subscription   Korean         Firefox
# 7629        Windows  complete.subscription   Korean          Chrome
# 9943        Windows  complete.subscription   Korean          Chrome
# 6565        Windows  complete.subscription   Korean          Chrome
# 10026       Windows  complete.subscription   Korean            Edge
# 6825            NaN  complete.subscription      NaN             NaN
# 8468        Windows  complete.subscription   Korean          Chrome
# 5249            Mac  complete.subscription   Korean          Safari
# 8742            Mac  complete.subscription   Korean          Chrome
# 5066        Windows  complete.subscription   Korean          Chrome
# 8159        Windows  complete.subscription   Korean          Chrome
# 6364        Windows  complete.subscription   Korean          Chrome
# 10247  Apple iPhone  complete.subscription   Korean   Mobile Safari
# 5213        Android  complete.subscription   Korean  Chrome WebView
# 4585        Windows  complete.subscription   Korean          Chrome
# 7762            Mac  complete.subscription   Korean          Chrome
# 9284        Windows  complete.subscription   Korean          Chrome
# 8630        Windows  complete.subscription   Korean          Chrome
# 8823        Windows  complete.subscription   Korean          Chrome
# 7437        Windows  complete.subscription   Korean          Chrome
# 3603        Windows  complete.subscription   Korean          Chrome
# 6977        Windows  complete.subscription   Korean          Chrome
# 6374        Windows  complete.subscription   Korean          Chrome
# 7982        Windows  complete.subscription   Korean            Edge
# 8847        Windows  complete.subscription   Korean          Chrome
# 10283       Windows  complete.subscription   Korean          Chrome
# 9513        Windows  complete.subscription   Korean          Chrome
# 4168        Windows  complete.subscription   Korean          Chrome
# 9373            Mac  complete.subscription   Korean          Safari
# 9819            Mac  complete.subscription   Korean          Safari
# 6201        Windows  complete.subscription   Korean          Chrome
# 8236        Windows  complete.subscription   Korean          Chrome
# 7601        Windows  complete.subscription   Korean          Chrome
# 10060           Mac  complete.subscription   Korean          Safari
# 6754        Windows  complete.subscription   Korean          Chrome
# 5738        Windows  complete.subscription   Korean         Firefox
# 6535            Mac  complete.subscription   Korean          Chrome
# 6866        Windows  complete.subscription   Korean          Chrome
# 7815        Windows  complete.subscription   Korean          Chrome
# 5441        Windows  complete.subscription  English          Chrome
# 10014  Apple iPhone  complete.subscription   Korean   Mobile Safari
# 9282            Mac  complete.subscription   Korean          Chrome
#
#       os_version platform                           user_id  plan_price  \
# 4916         106      Web  02a857284f291785a949fbd7ed7d6e91       42960
# 8476         107      Web  08e0a0b1e7ae39f10cba93cfbfec6ec1       15920
# 6836         107      Web  0ec79c4ff05cb031b57225643ded1c97      131600
# 5186         107      Web  12df81eb070929dbc64ebe17fc95176e       15920
# 8995         107      Web  139c1cf233ccae4be971eac38eb105b5       15920
# 5005         107      Web  13b3fce2a05f0e6b75c6714d27e2b38a       15920
# 5339         107      Web  17dbedc75e53644666161f41d17a760d       15920
# 8474         107      Web  1d4cb749775a764c9bee81e9faa84b2e       15920
# 9309         107      Web  21fdeec4cae2b5512f39ac6ed3a4fdcf       15920
# 5194          16      Web  2224ca341fc08e5603c82c0f63d75b70      131600
# 9371          16      Web  23583298989b16fd0e3255c6bd57c115       42960
# 3704          16      Web  2c47885aaf508af388351cccdd4093ce       15920
# 5069   107.0.0.0      Web  2fe40e7191a768e71edd18f11ab30e0c       15920
# 6013          16      Web  332de0c72933a86b9a3e11e84b52beaf      131600
# 6302       106.0      Web  33d43ec83ac1705537c9288a8cb6ca3e      131600
# 7629         107      Web  4003dd15cef2c8928c78d150937d03c8      131600
# 9943         107      Web  43247ed8510ec17f76017cf5bdfc268d       42960
# 6565         107      Web  48ff1d45ffaf8542809b6d1b21011348       15920
# 10026        107      Web  4b01106982ce76a475b30b68b0145a39       15920
# 6825         nan      NaN  51746470fedff498563a90d325455ae9       15920
# 8468         107      Web  569c27d726d89288bfd9cfd9384dfd30      131600
# 5249          16      Web  5bcd8a6c5a4e156148048d685d14ee69       15920
# 8742         107      Web  5e06134985c83e0b6a673dd83f3e1fa9       15920
# 5066   107.0.0.0      Web  60533be904f55092f1d6577ff40afb52      131600
# 8159         107      Web  6747ec959ba6dd321c6b3408670b7903       15920
# 6364         106      Web  798a876cf114419feac2137bfbbb7f61       15920
# 10247         16      Web  7a30f31f51cafadfa80b836a4bbc2eb2      131600
# 5213          90      Web  801fb0fb9788e575ed7e4cae4bf3fec6       15920
# 4585         104      Web  805ad3945616300f4fdfa1e12f02ad6a       15920
# 7762         107      Web  868b776c8d1d3aeb631e4ea099253518       15920
# 9284   107.0.0.0      Web  961a2a42932d76d9a50460e9fe4e68e7       15920
# 8630         107      Web  97e533f41515fc2e09a0907c25fb503c       15920
# 8823         107      Web  9f4bf32dad209b761f0997b5756a5e58      131600
# 7437         107      Web  adbd0538928a96e1dbca67e913050709       15920
# 3603   107.0.0.0      Web  ae66280e5e1a08fd53ea3b5090b0ac5b       15920
# 6977         107      Web  af7691a349e1a15cb685508f87f7a7b0       15920
# 6374         107      Web  b5a6052b41664c26ac40284271fb4df9       15920
# 7982         107      Web  b802d2b54e0a52a26706279075a53035       15920
# 8847   103.0.0.0      Web  ba62572dfde92750cd89365dcebe5c7c       15920
# 10283        107      Web  c3a77fc697fb999c37f084513072112b       15920
# 9513         107      Web  cbdbe9f66e2cd6cb1af1834c20cc1f8d       15920
# 4168         107      Web  cdf55bf68cce297c5691441ca324e297      131600
# 9373          16      Web  d0aec84a6dd8f467892f85264dd842d9       15920
# 9819        16.1      Web  d3b275a3cc4b400f32b502c502ec1357      131600
# 6201   107.0.0.0      Web  dec495819245772bca46774e09a7e8e1       15920
# 8236         107      Web  def9369ecc49594167a2e86dcaaaa4a7       15920
# 7601         107      Web  e9a61830c04d8104c516a010274fd1b3      131600
# 10060         15      Web  ebef7774fdf54d8c8dae3538efcf4c2b       15920
# 6754         107      Web  edccf32df27d89255c8207fe870f50fa       15920
# 5738       107.0      Web  f1b88c0b53f90a53572864671bfc191b       15920
# 6535   107.0.0.0      Web  f2dcad59c4fded2b39da5990a82c8bf2      131600
# 6866         106      Web  f36b8aeb1f9f2b8876a26af3c0514368       15920
# 7815         107      Web  f78a387c263597615e7c6f56fcb96225       15920
# 5441   107.0.0.0      Web  f81309195a86efef36bfb00e300fbe65       15920
# 10014       15.6      Web  fd8b29e3ae8720d42479d2b950c64ffd       15920
# 9282         107      Web  fdd65930c3cb37b64725377df0a7b380       15920
#
#        paid_amount  coupon_discount_amount pg_type
# 4916         42960                       0     NaN
# 8476         15920                       0     NaN
# 6836        131600                       0     NaN
# 5186         15920                       0     NaN
# 8995         15920                       0     NaN
# 5005         15920                       0     NaN
# 5339         15920                       0     NaN
# 8474         15920                       0     NaN
# 9309         15920                       0     NaN
# 5194         78960                   52640     NaN
# 9371         42960                       0     NaN
# 3704         15920                       0     NaN
# 5069         15920                       0     NaN
# 6013        131600                       0     NaN
# 6302        131600                       0     NaN
# 7629        105280                   26320     NaN
# 9943         42960                       0     NaN
# 6565         15920                       0     NaN
# 10026        15920                       0     NaN
# 6825         15920                       0     NaN
# 8468        131600                       0     NaN
# 5249         15920                       0     NaN
# 8742         15920                       0     NaN
# 5066        131600                       0     NaN
# 8159         15920                       0     NaN
# 6364         15920                       0     NaN
# 10247       131600                       0     NaN
# 5213         15920                       0     NaN
# 4585         15920                       0     NaN
# 7762         15920                       0     NaN
# 9284         15920                       0     NaN
# 8630         15920                       0     NaN
# 8823        131600                       0     NaN
# 7437         15920                       0     NaN
# 3603         15920                       0     NaN
# 6977         15920                       0     NaN
# 6374         15920                       0     NaN
# 7982         15920                       0     NaN
# 8847         15920                       0     NaN
# 10283        15920                       0     NaN
# 9513         15920                       0     NaN
# 4168        131600                       0     NaN
# 9373         15920                       0     NaN
# 9819        131600                       0     NaN
# 6201          7960                    7960     NaN
# 8236         15920                       0     NaN
# 7601        131600                       0     NaN
# 10060        15920                       0     NaN
# 6754         15920                       0     NaN
# 5738         15920                       0     NaN
# 6535        131600                       0     NaN
# 6866         15920                       0     NaN
# 7815         12736                    3184     NaN
# 5441         15920                       0     NaN
# 10014        15920                       0     NaN
# 9282         15920                       0     NaN
# df 7 : end.content.csv
#
# drop duplicate : 2 \
# 'user_id' - max conut : 127 \
# over 1 : 16.81% \
# 'user_id', 'client_event_time' - max conut : 1 \
#
# 94978     6.102476e+07
# 116551    6.054349e+07
# 83679     6.005366e+07
# Name: client_event_time, dtype: float64
# 70209    0.001
# 75204    0.001
# 31445    0.001
# Name: client_event_time, dtype: float64
#
#
# too close log : 413, 0.34%
#               city       client_event_time      country device_family  \
# 43245     Nowon-gu 2022-05-15 12:03:11.939  South Korea           Mac
# 67652    Seocho-gu 2022-03-18 00:42:50.059  South Korea       Windows
# 45358    Seocho-gu 2022-04-28 06:18:34.883  South Korea       Windows
# 55783    Yongin-si 2022-11-09 01:39:17.312  South Korea           Mac
# 55784    Yongin-si 2022-11-09 01:39:17.388  South Korea           Mac
# ...            ...                     ...          ...           ...
# 54871    Seocho-gu 2022-11-17 02:02:24.843  South Korea           Mac
# 54872    Seocho-gu 2022-11-17 02:02:24.906  South Korea           Mac
# 56212        Seoul 2022-03-11 06:27:26.023  South Korea           Mac
# 77346  Seongbuk-gu 2022-03-10 08:09:40.982  South Korea       Windows
# 80926      Jung-gu 2022-01-17 07:35:55.408  South Korea       Windows
#
#       device_type   event_type language os_name os_version platform  \
# 43245         Mac  end.content   Korean  Chrome         99      Web
# 67652     Windows  end.content   Korean  Chrome         99      Web
# 45358     Windows  end.content   Korean  Chrome        100      Web
# 55783         Mac  end.content   Korean  Chrome        107      Web
# 55784         Mac  end.content   Korean  Chrome        107      Web
# ...           ...          ...      ...     ...        ...      ...
# 54871         Mac  end.content  English  Chrome  107.0.0.0      Web
# 54872         Mac  end.content  English  Chrome  107.0.0.0      Web
# 56212         Mac  end.content   Korean  Chrome         99      Web
# 77346     Windows  end.content   Korean  Chrome         98      Web
# 80926     Windows  end.content   Korean  Chrome         97      Web
#
#                                 user_id                        content_id
# 43245  0e0332c7d1288e85d86ed5138560d0a9  101e1d0dcc38d9c86156f008a145083e
# 67652  1bf81491a4dbfe81c7d9c578bc9b8499  18992b667be06d6f29ba0008f99d9745
# 45358  1bf81491a4dbfe81c7d9c578bc9b8499  f64c475280676531a31f2f8e0648599c
# 55783  1e561fd0e2ad3f7c78c70ce2b39ed005  38df90d4de533d6296b52c6a1d90e26b
# 55784  1e561fd0e2ad3f7c78c70ce2b39ed005  38df90d4de533d6296b52c6a1d90e26b
# ...                                 ...                               ...
# 54871  d5e0de700e4392e27a067986398e1511  f4be1a0fe0e301b03115591777fddf29
# 54872  d5e0de700e4392e27a067986398e1511  f4be1a0fe0e301b03115591777fddf29
# 56212  eff877d600a267464c25a649f2f77dd5  db82104b9c508953b3d00eea82844a48
# 77346  f7a82a367e81adafdf59b9cb66b0a53c  5d922c8a6e9e437e7735aa1376bd79ff
# 80926  f87a3c16eb776294dec7b3820f55a610  d6227ba76134f6cf821bb98b5f235bd0
#
# [413 rows x 12 columns]
# df 8 : enter.content_page.csv
#
# drop duplicate : 178 \
# 'user_id' - max conut : 29654 \
# over 1 : 2.78% \
# 'user_id', 'client_event_time' - max conut : 3 \
#               city       client_event_time      country         device_family  \
# 143597         NaN 2023-03-17 00:14:20.051  South Korea  Samsung Galaxy Phone
# 377583       Seoul 2023-03-17 00:14:20.051  South Korea  Samsung Galaxy Phone
# 550854        Osan 2022-03-22 10:26:48.450  South Korea                 Linux
# 1103292      Seoul 2022-03-22 10:26:48.450  South Korea                 Linux
# 1276544  Songpa-gu 2022-03-22 10:26:48.450  South Korea                 Linux
# 550855        Osan 2022-03-22 10:28:05.631  South Korea                 Linux
# 1103293      Seoul 2022-03-22 10:28:05.631  South Korea                 Linux
# 1276545  Songpa-gu 2022-03-22 10:28:05.631  South Korea                 Linux
# 550856        Osan 2022-03-22 10:32:44.294  South Korea                 Linux
# 1103294      Seoul 2022-03-22 10:32:44.294  South Korea                 Linux
#
#                        device_type          event_type language  \
# 143597   Samsung Galaxy Z Fold2 5G  enter.content_page   Korean
# 377583   Samsung Galaxy Z Fold2 5G  enter.content_page   Korean
# 550854                       Linux  enter.content_page   Korean
# 1103292                      Linux  enter.content_page   Korean
# 1276544                      Linux  enter.content_page   Korean
# 550855                       Linux  enter.content_page   Korean
# 1103293                      Linux  enter.content_page   Korean
# 1276545                      Linux  enter.content_page   Korean
# 550856                       Linux  enter.content_page   Korean
# 1103294                      Linux  enter.content_page   Korean
#
#                  os_name os_version platform  \
# 143597   Samsung Browser       19.0      Web
# 377583   Samsung Browser       19.0      Web
# 550854   Samsung Browser         16      Web
# 1103292  Samsung Browser         16      Web
# 1276544  Samsung Browser         16      Web
# 550855   Samsung Browser         16      Web
# 1103293  Samsung Browser         16      Web
# 1276545  Samsung Browser         16      Web
# 550856   Samsung Browser         16      Web
# 1103294  Samsung Browser         16      Web
#
#                                   user_id                        content_id
# 143597   06d97f3d72f2e0162caf0ee95eb3ddf0  8a72eed73d3f9d3ab1771548070e7338
# ...
# 740178    Rockville 2022-11-12 05:43:28.229  United States       Windows
# 1226496       Seoul 2022-12-04 15:52:58.692    South Korea  Apple iPhone
# 1169047  Gangnam-gu 2022-05-23 00:30:15.773    South Korea       Windows
# 1223550       Seoul 2022-11-10 22:49:35.737    South Korea       Android
#
#           device_type       event_type language         os_name  \
# 1218101       Windows  enter.main_page   Korean            Edge
# 787469        Windows  enter.main_page   Korean          Chrome
# 1518260  Apple iPhone  enter.main_page   Korean   Mobile Safari
# 1333492           Mac  enter.main_page   Korean          Chrome
# 1333496           Mac  enter.main_page   Korean          Chrome
# ...               ...              ...      ...             ...
# 1494746           Mac  enter.main_page   Korean          Chrome
# 740178        Windows  enter.main_page  English          Chrome
# 1226496  Apple iPhone  enter.main_page   Korean          Chrome
# 1169047       Windows  enter.main_page  English          Chrome
# 1223550       Android  enter.main_page   Korean  Chrome WebView
#
#              os_version platform                           user_id
# 1218101              97      Web  0028f62af7782380e55d2e86d73f25a5
# 787469              103      Web  007014899afb38703146a5678da74814
# 1518260              15      Web  00baaf03ba9a095f009e107d01b7173c
# 1333492             105      Web  00f3b2f8e51cbf56d745604940c1da94
# 1333496             105      Web  00f3b2f8e51cbf56d745604940c1da94
# ...                 ...      ...                               ...
# 1494746             107      Web  ff56eed2eee3e18ef7973a69015ae6ae
# 740178              107      Web  ff917e8b6bcf53a48bd1b1efae5d00f5
# 1226496  107.0.5304.101      Web  ffdfbf03c274a93e5378813532ce3327
# 1169047             101      Web  ffe4420b9073409b447933f036fbfe51
# 1223550             105      Web  fff3e9ffd58cda1d8068d1dab141760a
#
# [3197 rows x 11 columns]
# df 11 : enter.payment_page.csv
#
# drop duplicate : 21 \
# 'user_id' - max conut : 101 \
# over 1 : 21.52% \
# 'user_id', 'client_event_time' - max conut : 2 \
#                city       client_event_time      country  device_family  \
# 26118         Suwon 2023-03-24 10:26:02.694  South Korea  Samsung Phone
# 59936         Seoul 2023-03-24 10:26:02.694  South Korea  Samsung Phone
# 13062  Seongdong-gu 2022-12-26 12:31:16.131  South Korea  Samsung Phone
# 53309     Dobong-gu 2022-12-26 12:31:16.131  South Korea  Samsung Phone
# 85267     Anyang-si 2022-11-17 10:35:36.694  South Korea        Windows
# 86875     Uiwang-si 2022-11-17 10:35:36.694  South Korea        Windows
# 26336         Seoul 2023-06-05 06:24:48.779  South Korea  Samsung Phone
# 40223    Yuseong-gu 2023-06-05 06:24:48.779  South Korea  Samsung Phone
# 33785       Incheon 2023-02-28 15:15:03.105  South Korea            Mac
# 47474     Yeonsu-gu 2023-02-28 15:15:03.105  South Korea            Mac
#
#                   device_type          event_type language          os_name  \
# 26118     Samsung Galaxy S22+  enter.payment_page   Korean        Instagram
# 59936     Samsung Galaxy S22+  enter.payment_page   Korean        Instagram
# 13062  Samsung Galaxy S20+ 5G  enter.payment_page   Korean           Chrome
# 53309  Samsung Galaxy S20+ 5G  enter.payment_page   Korean           Chrome
# 85267                 Windows  enter.payment_page   Korean            Whale
# 86875                 Windows  enter.payment_page   Korean            Whale
# 26336      Samsung Galaxy S22  enter.payment_page   Korean  Samsung Browser
# 40223      Samsung Galaxy S22  enter.payment_page   Korean  Samsung Browser
# 33785                     Mac  enter.payment_page   Korean           Chrome
# 47474                     Mac  enter.payment_page   Korean           Chrome
#
#           os_version platform                           user_id
# 26118  274.0.0.26.90      Web  04c4070b4a6f99e76d6939609fa62958
# 59936  274.0.0.26.90      Web  04c4070b4a6f99e76d6939609fa62958
# 13062      108.0.0.0      Web  07e422686e02a62ffc6cf06f8454e1b2
# 53309      108.0.0.0      Web  07e422686e02a62ffc6cf06f8454e1b2
# 85267    3.17.145.12      Web  2fd7523ead820c380fbe2e7e6000675c
# 86875    3.17.145.12      Web  2fd7523ead820c380fbe2e7e6000675c
# 26336           21.0      Web  50d8561b39af0a585aa5fe29135f9868
# 40223           21.0      Web  50d8561b39af0a585aa5fe29135f9868
# 33785      110.0.0.0      Web  5af7ed9398f4f5a61eedbdd376def391
# 47474      110.0.0.0      Web  5af7ed9398f4f5a61eedbdd376def391
# 162664    3.394027e+07
# 129401    3.384851e+07
# 161582    3.351084e+07
# Name: client_event_time, dtype: float64
# 65712    0.0
# 55765    0.0
# 86875    0.0
# Name: client_event_time, dtype: float64
#
#
# too close log : 23354, 14.15%
#                  city       client_event_time      country device_family  \
# 143127       Gyeongju 2023-11-29 01:07:57.136  South Korea    Apple iPad
# 125445          Seoul 2023-10-15 15:09:35.919  South Korea       Windows
# 158447      Goyang-si 2023-09-20 21:41:03.394  South Korea       Windows
# 92793           Seoul 2023-10-30 19:11:01.197  South Korea  Apple iPhone
# 156235  Pyeongtaek-si 2023-09-27 14:25:36.596  South Korea       Windows
# ...               ...                     ...          ...           ...
# 93161      Gangnam-gu 2023-09-15 07:53:30.960  South Korea       Windows
# 152126         Buk-gu 2023-09-27 04:06:39.371  South Korea       Windows
# 115134     Gangnam-gu 2023-09-11 10:38:24.622  South Korea       Windows
# 142892    Hwaseong-si 2023-11-15 04:45:44.402  South Korea       Windows
# 161092    Hwaseong-si 2023-11-15 05:17:47.168  South Korea       Windows
#
#                  device_type          event_type language        os_name  \
# 143127            Apple iPad  enter.payment_page   Korean  Mobile Safari
# 125445               Windows  enter.payment_page   Korean         Chrome
# 158447               Windows  enter.payment_page   Korean           Edge
# 92793   Apple iPhone 12 Mini  enter.payment_page   Korean      Instagram
# 156235               Windows  enter.payment_page   Korean           Edge
# ...                      ...                 ...      ...            ...
# 93161                Windows  enter.payment_page   Korean         Chrome
# 152126               Windows  enter.payment_page   Korean         Chrome
# 115134               Windows  enter.payment_page   Korean           Edge
# 142892               Windows  enter.payment_page   Korean         Chrome
# 161092               Windows  enter.payment_page   Korean         Chrome
#
#             os_version platform                           user_id
# 143127            15.4      Web  0001f15911b404f3bf5b8571afafa4e4
# 125445       117.0.0.0      Web  0001f28a707789a7d78dc28fd2e84dce
# 158447   116.0.1938.81      Web  0006474e7a888829001df3197bf6d644
# 92793   306.0.0.20.118      Web  000ad2412e2ced1b030a32089d794f5d
# 156235   117.0.2045.43      Web  001cc1d23174316d3752ed5d1ac32e48
# ...                ...      ...                               ...
# 93161        116.0.0.0      Web  fffcca0353b1476fd6f894c214cfb639
# 152126       117.0.0.0      Web  fffe529de03d6187ef7ed765650c8d2b
# 115134   116.0.1938.69      Web  ffffd8d78865a66cb3706977f29d1dec
# 142892       119.0.0.0      Web  ffffd8d78865a66cb3706977f29d1dec
# 161092       119.0.0.0      Web  ffffd8d78865a66cb3706977f29d1dec
#
# [23354 rows x 11 columns]
# df 12 : enter.signup_page.csv
#
# drop duplicate : 39 \
# 'user_id' - max conut : nan \
# over 1 : 0.0% \
# 'user_id', 'client_event_time' - max conut : nan \
#
# Series([], Name: client_event_time, dtype: float64)
# Series([], Name: client_event_time, dtype: float64)
#
#
# df 13 : renew.subscription.csv
#
# drop duplicate : 0 \
# 'user_id' - max conut : 17 \
# over 1 : 19.96% \
# 'user_id', 'client_event_time' - max conut : 1 \
#
# 15899    4.109101e+07
# 15216    3.714870e+07
# 14891    3.680670e+07
# Name: client_event_time, dtype: float64
# 3074    148.658
# 9411    114.000
# 4442     56.954
# Name: client_event_time, dtype: float64
#
#
# df 14 : resubscribe.subscription.csv
#
# drop duplicate : 0 \
# 'user_id' - max conut : 3 \
# over 1 : 3.29% \
# 'user_id', 'client_event_time' - max conut : 1 \
#
# 361    4.036989e+07
# 477    2.867280e+07
# 438    2.851033e+07
# Name: client_event_time, dtype: float64
# 458    5633123.334
# 736    3418259.560
# 93     3010329.346
# Name: client_event_time, dtype: float64
#
#
# df 15 : start.content.csv
#
# drop duplicate : 0 \
# 'user_id' - max conut : 83 \
# over 1 : 13.79% \
# 'user_id', 'client_event_time' - max conut : 1 \
#
# 119286    4.241172e+07
# 74538     4.182159e+07
# 67118     4.145035e+07
# Name: client_event_time, dtype: float64
# 88044     0.002
# 122190    0.002
# 22596     0.001
# Name: client_event_time, dtype: float64
#
#
# too close log : 99, 0.08%
#                 city       client_event_time        country device_family  \
# 115714    Suyeong-gu 2023-10-15 08:36:55.103    South Korea       Windows
# 30277      Jeju City 2023-04-03 16:41:37.377    South Korea  Apple iPhone
# 30278      Jeju City 2023-04-03 16:41:37.875    South Korea  Apple iPhone
# 2816           Seoul 2023-05-07 03:54:05.242    South Korea         Linux
# 117282         Seoul 2023-10-02 06:40:39.715    South Korea       Windows
# ...              ...                     ...            ...           ...
# 112966  Uijeongbu-si 2023-12-19 13:03:52.482    South Korea           Mac
# 112967  Uijeongbu-si 2023-12-19 13:03:52.902    South Korea           Mac
# 112968  Uijeongbu-si 2023-12-19 13:03:52.948    South Korea           Mac
# 54647        Amherst 2022-09-07 10:25:34.069  United States       Windows
# 88682            NaN 2023-08-06 19:06:06.009            NaN           NaN
#
#                 device_type     event_type language   os_name os_version  \
# 115714              Windows  start.content   Korean    Chrome  118.0.0.0
# 30277   Apple iPhone 7 Plus  start.content   Korean  Facebook        nan
# 30278   Apple iPhone 7 Plus  start.content   Korean  Facebook        nan
# 2816                  Linux  start.content   Korean    Chrome  112.0.0.0
# 117282              Windows  start.content   Korean    Chrome  117.0.0.0
# ...                     ...            ...      ...       ...        ...
# 112966                  Mac  start.content   Korean    Chrome  120.0.0.0
# 112967                  Mac  start.content   Korean    Chrome  120.0.0.0
# 112968                  Mac  start.content   Korean    Chrome  120.0.0.0
# 54647               Windows  start.content   Korean    Chrome        104
# 88682                   NaN  start.content      NaN       NaN        nan
#
#        platform                           user_id  \
# 115714      Web  02c6b331129ea8588abca4e1dd41adea
# 30277       Web  065f04b00835f52f288cfc7c4516ccd4
# 30278       Web  065f04b00835f52f288cfc7c4516ccd4
# 2816        Web  0a636d3bc32f16c6410f02a989507aa4
# 117282      Web  0b5fa0fea50b30af6cd6c6d7fc1559a8
# ...         ...                               ...
# 112966      Web  f84c4f83ca1e977a89e0f7f7e6561a48
# 112967      Web  f84c4f83ca1e977a89e0f7f7e6561a48
# 112968      Web  f84c4f83ca1e977a89e0f7f7e6561a48
# 54647       Web  f8868b5573dc20f97a1c65b25a02b7fb
# 88682       NaN  fb0bac2e4fdb7258ad045754be43b80f
#
#                               content_id content_difficulty
# 115714  621c7ad99b17d2d16832b618d47aea7e           advanced
# 30277   f4be1a0fe0e301b03115591777fddf29           beginner
# 30278   f4be1a0fe0e301b03115591777fddf29           beginner
# 2816    e543c38ec7fa6bcd5045049ecc31e5f8           advanced
# 117282  cf76ec385bf471bd774ddebf1749d3d4           advanced
# ...                                  ...                ...
# 112966  f64c475280676531a31f2f8e0648599c       intermediate
# 112967  f64c475280676531a31f2f8e0648599c       intermediate
# 112968  f64c475280676531a31f2f8e0648599c       intermediate
# 54647   7fef928cdccef0185dfb931ef59b37d7           advanced
# 88682   595cb4bbfc83e683b0314ca1312cfbde       intermediate
#
# [99 rows x 13 columns]
# df 16 : start.free_trial.csv
#
# drop duplicate : 0 \
# 'user_id' - max conut : 66 \
# over 1 : 19.31% \
# 'user_id', 'client_event_time' - max conut : 2 \
#              city       client_event_time      country device_family  \
# 5468   Dongjak-gu 2021-12-28 10:57:50.504  South Korea       Android
# 21571       Seoul 2021-12-28 10:57:50.504  South Korea       Android
#
#       device_type        event_type language          os_name os_version  \
# 5468      Android  start.free_trial   Korean  Samsung Browser       16.0
# 21571     Android  start.free_trial   Korean  Samsung Browser       16.0
#
#       platform                           user_id  plan_price plan_type  \
# 5468       Web  f6f2c94b0d55814958f27c64c3df775a         NaN       NaN
# 21571      Web  f6f2c94b0d55814958f27c64c3df775a         NaN       NaN
#
#       trial_type
# 5468           A
# 21571          A
# 981     3.683090e+07
# 1838    3.656525e+07
# 913     3.463205e+07
# Name: client_event_time, dtype: float64
# 25805    0.005
# 25807    0.005
# 21571    0.000
# Name: client_event_time, dtype: float64
#
#
# too close log : 274, 0.89%
#              city       client_event_time      country device_family  \
# 23768       Wonju 2022-05-14 23:59:45.405  South Korea    Apple iPad
# 17494  Bucheon-si 2022-05-19 04:28:49.278  South Korea       Windows
# 26402   Pohang-si 2022-07-06 08:49:18.835  South Korea       Windows
# 6010   Bucheon-si 2022-06-12 11:03:11.101  South Korea       Windows
# 13060       Seoul 2022-02-06 06:52:22.728  South Korea       Windows
# ...           ...                     ...          ...           ...
# 19219       Mokpo 2022-01-11 01:09:20.186  South Korea       Windows
# 14361  Gangbuk-gu 2022-01-12 03:23:22.428  South Korea       Windows
# 14362  Gangbuk-gu 2022-01-12 03:23:22.981  South Korea       Windows
# 24849    Ansan-si 2022-05-24 09:01:46.525  South Korea       Windows
# 26559   Chuncheon 2022-04-26 12:55:48.490  South Korea       Windows
#
#       device_type        event_type language        os_name os_version  \
# 23768  Apple iPad  start.free_trial   Korean  Chrome Mobile      101.0
# 17494     Windows  start.free_trial   Korean         Chrome      101.0
# 26402     Windows  start.free_trial   Korean         Chrome      103.0
# 6010      Windows  start.free_trial   Korean         Chrome      102.0
# 13060     Windows  start.free_trial   Korean         Chrome       98.0
# ...           ...               ...      ...            ...        ...
# 19219     Windows  start.free_trial   Korean         Chrome       96.0
# 14361     Windows  start.free_trial   Korean         Chrome       96.0
# 14362     Windows  start.free_trial   Korean         Chrome       96.0
# 24849     Windows  start.free_trial   Korean           Edge      101.0
# 26559     Windows  start.free_trial   Korean         Chrome      100.0
#
#       platform                           user_id  plan_price plan_type  \
# 23768      Web  01b0b7e0e256a75c5a2b1e7d703abf3a         NaN       NaN
# 17494      Web  0432b6494167d2c64d3e1cb7297bf020         NaN       NaN
# 26402      Web  087b7dbeba41ae6062f6cb58d6257cf8         NaN       NaN
# 6010       Web  0901aaa049091a0e60f7367aaecd673e         NaN       NaN
# 13060      Web  0a40d8cfc9c8fde661acfa0d8aff3410         NaN       NaN
# ...        ...                               ...         ...       ...
# 19219      Web  fb1dbb308f066b69f4160a8e7ef719d3         NaN       NaN
# 14361      Web  fd9f20cab43785801d910f7d40a3614f         NaN       NaN
# 14362      Web  fd9f20cab43785801d910f7d40a3614f         NaN       NaN
# 24849      Web  fe78f01346074dd83a401ba68b23002c         NaN       NaN
# 26559      Web  fed315fca830193a3b6c9c691b3f77f9         NaN       NaN
#
#       trial_type
# 23768          A
# 17494          A
# 26402          A
# 6010           A
# 13060          A
# ...          ...
# 19219          A
# 14361          A
# 14362          A
# 24849          A
# 26559          A
#
# [274 rows x 14 columns]

# %% [markdown]
# #### 공통 컬럼 설명
# -
# - user_id: 고유 ID
# - event_type: 이벤트 타입
# - client_event_time: 이벤트 발생시간
# -
# - platform : nan - 아마도 App / Web - Web
# - device_type : 652 종류
# - device_family : 1120 종류 - 너무 많음, 중요도 떨어짐
# - device_carrier : 없음? 확인필요 중요도 떨어짐
# -
# - language : 71 종류
# - country : 189 종류
# - city : 4340 종류 - 너무 많음, 중요도 떨어짐
# -
# - os_name : 44 종류
# - os_version : 3104 종류 - 너무 많음, 중요도 떨어짐
# -
# - ( device_type, device_family ) : 690 종류
# - ( country, city ) : 4412 종류

# %% [markdown]
# #### [0] : click.cancel_plan_button.csv
#
# - 설명 : 구독 취소 버튼 클릭
# - 트리거 : 구독 취소 버튼을 클릭했다면 구독 취소가 이루어진 것으로 간주

# %%
# df
file_no = 0
df = dfs[file_no].copy()
print(filelist[file_no])
# Out:
# click.cancel_plan_button.csv

# %%
# dropna in core_cols
print('before dropna :', df.shape[0], 'entries')
df = df.dropna(subset=core_cols)
print('after dropna  :', df.shape[0], 'entries')
# Out:
# before dropna : 17895 entries
# after dropna  : 16853 entries

# %%
# 
display(df.info())
display(df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16853 entries, 0 to 17894
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   city               16708 non-null  object
#  1   client_event_time  16853 non-null  datetime64[ns]
#  2   country            16851 non-null  object
#  3   device_family      16853 non-null  object
#  4   device_type        16561 non-null  object
#  5   event_type         16853 non-null  object
#  6   language           16853 non-null  object
#  7   os_name            16853 non-null  object
#  8   os_version         16853 non-null  object
#  9   platform           16853 non-null  object
#  10  user_id            16853 non-null  object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 1.5+ MB
# None
#            city       client_event_time      country device_family  \
# 0         Daegu 2023-04-10 14:57:48.556  South Korea       Windows
# 1         Seoul 2023-03-12 08:26:16.224  South Korea    Apple iPad
# 2  Uijeongbu-si 2023-03-12 08:23:04.955  South Korea       Windows
# 3     Dobong-gu 2023-03-12 08:32:39.271  South Korea       Windows
# 4  Geumjeong-gu 2023-04-12 11:36:28.311  South Korea       Windows
#
#   device_type                event_type language        os_name os_version  \
# 0     Windows  click.cancel_plan_button   Korean         Chrome  111.0.0.0
# 1  Apple iPad  click.cancel_plan_button  English  Mobile Safari       16.3
# 2     Windows  click.cancel_plan_button   Korean         Chrome  110.0.0.0
# 3     Windows  click.cancel_plan_button   Korean         Chrome  110.0.0.0
# 4     Windows  click.cancel_plan_button   Korean         Chrome  111.0.0.0
#
#   platform                           user_id
# 0      Web  9e59ecf9a8fbe9051bd0d54f4b702f30
# 1      Web  4ed4d8f12c45504a148bfff0f2e9466e
# 2      Web  b6a1bba3cc4139d7dc821561319221e6
# 3      Web  40acc1ddfc012f3d2f58a3de95e9e748
# 4      Web  bdffe1f18684704d4ea2d7eebcaed180

# %%
check_too_close_log(df)
# Out:
# drop duplicate : 0 \
# 'user_id' - max conut : 5 \
# over 1 : 11.22% \
# 'user_id', 'client_event_time' - max conut : 1 \
#
# 13634    6.254757e+07
# 14740    5.942373e+07
# 17081    5.907468e+07
# Name: client_event_time, dtype: float64
# 2399     91846.818
# 12453    91119.474
# 17484    88814.777
# Name: client_event_time, dtype: float64

# %% [markdown]
# #### result
# core dropna : 17895 -> 16853 \
# \
# drop duplicate : 0 \
# 'user_id' - max conut : 5 \
# over 1 : 11.22% \
# 'user_id', 'client_event_time' unique \
# \
# no pareto

# %% [markdown]
# #### [1] : click.content_page_more_review_button.csv
#
# - 설명 : 콘텐츠 후기 더보기 버튼 클릭
# - 트리거 :

# %%
# df
file_no = 1
df = dfs[file_no].copy()
print(filelist[file_no])
# Out:
# click.content_page_more_review_button.csv

# %%
# 
display(df.info())
display(df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93962 entries, 0 to 93961
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   city               93792 non-null  object
#  1   client_event_time  93962 non-null  datetime64[ns]
#  2   country            93944 non-null  object
#  3   device_family      93962 non-null  object
#  4   device_type        93909 non-null  object
#  5   event_type         93962 non-null  object
#  6   language           93962 non-null  object
#  7   os_name            93962 non-null  object
#  8   os_version         93962 non-null  object
#  9   platform           93962 non-null  object
#  10  user_id            10702 non-null  object
#  11  content_id         93938 non-null  object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 8.6+ MB
# None
#            city       client_event_time         country device_family  \
# 0        Seo-gu 2023-04-10 14:10:01.402     South Korea       Windows
# 1        London 2023-01-24 21:37:43.417  United Kingdom       Windows
# 2  Eunpyeong-gu 2023-01-31 14:44:16.897     South Korea       Windows
# 3         Seoul 2023-01-31 14:30:36.568     South Korea  Apple iPhone
# 4         Seoul 2023-02-12 03:24:32.337     South Korea       Windows
#
#     device_type                             event_type language  \
# 0       Windows  click.content_page_more_review_button   Korean
# 1       Windows  click.content_page_more_review_button   Korean
# 2       Windows  click.content_page_more_review_button   Korean
# 3  Apple iPhone  click.content_page_more_review_button   Korean
# 4       Windows  click.content_page_more_review_button   Korean
#
#          os_name   os_version platform                           user_id  \
# 0         Chrome    112.0.0.0      Web  558fe7e8c06b8505f11b33d76f076e56
# 1          Whale  3.18.154.13      Web  e48956538e4df690a5d12adf1e6f2ee3
# 2         Chrome    109.0.0.0      Web  e745da89019e303b122bfceac0521a8f
# 3  Mobile Safari       15.6.1      Web  e2c59d444736eceee9eedba85bd4e209
# 4         Chrome    110.0.0.0      Web  74b66b738185ffdbec960db4a0da330a
#
#                          content_id
# 0  a1eeebeb6c307641b75b94a2a1d5b9aa
# 1  f491517f4737a60d661cd1fcacc702c0
# 2  9aa7628a347707fb155943041e2cb524
# 3  f491517f4737a60d661cd1fcacc702c0
# 4  101e1d0dcc38d9c86156f008a145083e

# %%
df[df['user_id'].isnull()].head(5)
# Out:
#          city       client_event_time      country        device_family  \
# 6       Seoul 2023-02-02 05:52:39.884  South Korea              Windows
# 8   Namyangju 2023-04-11 12:41:15.468  South Korea  Samsung Galaxy Note
# 17  Goyang-si 2023-06-29 02:10:58.638  South Korea              Windows
# 20      Seoul 2023-01-10 01:17:51.437  South Korea         Apple iPhone
# 23      Seoul 2023-02-27 13:00:25.913  South Korea              Windows
#
#               device_type                             event_type language  \
# 6                 Windows  click.content_page_more_review_button   Korean
# 8   Samsung Galaxy Note 8  click.content_page_more_review_button   Korean
# 17                Windows  click.content_page_more_review_button   Korean
# 20        Apple iPhone 13  click.content_page_more_review_button   Korean
# 23                Windows  click.content_page_more_review_button   Korean
#
#       os_name      os_version platform user_id  \
# 6      Chrome       109.0.0.0      Web     NaN
# 8      Chrome       112.0.0.0      Web     NaN
# 17     Chrome       114.0.0.0      Web     NaN
# 20  Instagram  264.3.0.19.104      Web     NaN
# 23     Chrome       110.0.0.0      Web     NaN
#
#                           content_id
# 6   e543c38ec7fa6bcd5045049ecc31e5f8
# 8   220ce7873b8895d0c81c37600b5bd1e7
# 17  c269eb6df3a374b464f7c18f12fa398f
# 20  479926b04fe824bce5bdc7e0f81a2539
# 23  f491517f4737a60d661cd1fcacc702c0

# %%
# dropna in core_cols
print('before dropna :', df.shape[0], 'entries')
df = df.dropna(subset=core_cols)
print('after dropna  :', df.shape[0], 'entries')
# Out:
# before dropna : 93962 entries
# after dropna  : 10702 entries

# %%
# 
display(df.info())
display(df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10702 entries, 0 to 93960
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   city               10627 non-null  object
#  1   client_event_time  10702 non-null  datetime64[ns]
#  2   country            10689 non-null  object
#  3   device_family      10702 non-null  object
#  4   device_type        10679 non-null  object
#  5   event_type         10702 non-null  object
#  6   language           10702 non-null  object
#  7   os_name            10702 non-null  object
#  8   os_version         10702 non-null  object
#  9   platform           10702 non-null  object
#  10  user_id            10702 non-null  object
#  11  content_id         10684 non-null  object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 1.1+ MB
# None
#            city       client_event_time         country device_family  \
# 0        Seo-gu 2023-04-10 14:10:01.402     South Korea       Windows
# 1        London 2023-01-24 21:37:43.417  United Kingdom       Windows
# 2  Eunpyeong-gu 2023-01-31 14:44:16.897     South Korea       Windows
# 3         Seoul 2023-01-31 14:30:36.568     South Korea  Apple iPhone
# 4         Seoul 2023-02-12 03:24:32.337     South Korea       Windows
#
#     device_type                             event_type language  \
# 0       Windows  click.content_page_more_review_button   Korean
# 1       Windows  click.content_page_more_review_button   Korean
# 2       Windows  click.content_page_more_review_button   Korean
# 3  Apple iPhone  click.content_page_more_review_button   Korean
# 4       Windows  click.content_page_more_review_button   Korean
#
#          os_name   os_version platform                           user_id  \
# 0         Chrome    112.0.0.0      Web  558fe7e8c06b8505f11b33d76f076e56
# 1          Whale  3.18.154.13      Web  e48956538e4df690a5d12adf1e6f2ee3
# 2         Chrome    109.0.0.0      Web  e745da89019e303b122bfceac0521a8f
# 3  Mobile Safari       15.6.1      Web  e2c59d444736eceee9eedba85bd4e209
# 4         Chrome    110.0.0.0      Web  74b66b738185ffdbec960db4a0da330a
#
#                          content_id
# 0  a1eeebeb6c307641b75b94a2a1d5b9aa
# 1  f491517f4737a60d661cd1fcacc702c0
# 2  9aa7628a347707fb155943041e2cb524
# 3  f491517f4737a60d661cd1fcacc702c0
# 4  101e1d0dcc38d9c86156f008a145083e

# %%
check_too_close_log(df)
# Out:
# drop duplicate : 0 \
# 'user_id' - max conut : 285 \
# over 1 : 11.69% \
# 'user_id', 'client_event_time' - max conut : 2 \
#         city       client_event_time      country device_family device_type  \
# 1816   Seoul 2022-08-09 14:10:03.284  South Korea       Android     Android
# 82828  Busan 2022-08-09 14:10:03.284  South Korea       Android     Android
#
#                                   event_type language          os_name  \
# 1816   click.content_page_more_review_button   Korean  Samsung Browser
# 82828  click.content_page_more_review_button   Korean  Samsung Browser
#
#       os_version platform                           user_id  \
# 1816          17      Web  e981a36d8407fd4cdfe789572e7b619d
# 82828         17      Web  e981a36d8407fd4cdfe789572e7b619d
#
#                              content_id
# 1816   c269eb6df3a374b464f7c18f12fa398f
# 82828  c269eb6df3a374b464f7c18f12fa398f
# 92747    5.926830e+07
# 93121    5.228160e+07
# 93329    4.749847e+07
# Name: client_event_time, dtype: float64
# 93746    0.053
# 16180    0.045
# 82828    0.000
# Name: client_event_time, dtype: float64
#
#
# too close log : 291, 2.72%
#              city       client_event_time      country device_family  \
# 14057   Yongin-si 2022-05-31 07:29:29.451  South Korea       Windows
# 34259     Mapo-gu 2022-03-04 13:22:24.682  South Korea           Mac
# 34260     Mapo-gu 2022-03-04 13:22:25.583  South Korea           Mac
# 34264     Mapo-gu 2022-03-04 13:22:31.861  South Korea           Mac
# 34267     Mapo-gu 2022-03-04 13:22:34.924  South Korea           Mac
# ...           ...                     ...          ...           ...
# 51097     Daejeon 2022-02-02 07:30:18.125  South Korea       Windows
# 51099     Daejeon 2022-02-02 07:30:19.566  South Korea       Windows
# 504    Gangnam-gu 2023-04-21 15:22:49.071  South Korea       Windows
# 69308  Gangnam-gu 2022-05-09 03:55:01.717  South Korea           Mac
# 69309  Gangnam-gu 2022-05-09 03:55:02.684  South Korea           Mac
#
#       device_type                             event_type language os_name  \
# 14057     Windows  click.content_page_more_review_button   Korean  Chrome
# 34259         Mac  click.content_page_more_review_button  English  Chrome
# 34260         Mac  click.content_page_more_review_button  English  Chrome
# 34264         Mac  click.content_page_more_review_button  English  Chrome
# 34267         Mac  click.content_page_more_review_button  English  Chrome
# ...           ...                                    ...      ...     ...
# 51097     Windows  click.content_page_more_review_button   Korean  Chrome
# 51099     Windows  click.content_page_more_review_button   Korean  Chrome
# 504       Windows  click.content_page_more_review_button   Korean  Chrome
# 69308         Mac  click.content_page_more_review_button   Korean  Chrome
# 69309         Mac  click.content_page_more_review_button   Korean  Chrome
#
#       os_version platform                           user_id  \
# 14057        101      Web  01f1e7ad72a4038cf9bfb891f1342848
# 34259         98      Web  0386abdf5e2b082d78084a8e325ed4ad
# 34260         98      Web  0386abdf5e2b082d78084a8e325ed4ad
# 34264         98      Web  0386abdf5e2b082d78084a8e325ed4ad
# 34267         98      Web  0386abdf5e2b082d78084a8e325ed4ad
# ...          ...      ...                               ...
# 51097         97      Web  faeaa6ea8b113fe9348a60503160a8d3
# 51099         97      Web  faeaa6ea8b113fe9348a60503160a8d3
# 504    112.0.0.0      Web  fb1ce3bb2441b0d581a266decdd661a4
# 69308        101      Web  ff3f3faf7543abd0b97db79f472f67db
# 69309        101      Web  ff3f3faf7543abd0b97db79f472f67db
#
#                              content_id
# 14057  32cf55a55adcc30ad80b674c0fee2ff4
# 34259  f4be1a0fe0e301b03115591777fddf29
# 34260  f4be1a0fe0e301b03115591777fddf29
# 34264  f4be1a0fe0e301b03115591777fddf29
# 34267  f4be1a0fe0e301b03115591777fddf29
# ...                                 ...
# 51097  e543c38ec7fa6bcd5045049ecc31e5f8
# 51099  e543c38ec7fa6bcd5045049ecc31e5f8
# 504    38df90d4de533d6296b52c6a1d90e26b
# 69308  f4be1a0fe0e301b03115591777fddf29
# 69309  f4be1a0fe0e301b03115591777fddf29
#
# [291 rows x 12 columns]

# %%
def pareto(df, column):
    # check column
    print(f"total {column} : {df[column].nunique()}")
    
    # 'count', 'percentage', 'cum_percentage'
    count = df[column].value_counts()
    percentage = (count / count.sum() * 100).round(2)
    cum_percentage = (count.cumsum() / count.sum() * 100).round(2)

    # setting results
    result = pd.concat([count, percentage, cum_percentage], axis=1)
    result.columns = ['count', 'percentage', 'cum_percentage']
    result.reset_index(inplace=True)

    # display
    display(result.head())
    
    temp = result[result['cum_percentage'] > 50].head(1)
    display(temp)
    print(f"over 50% : {round(((temp.index[0]+1) / result.shape[0] * 100), 2)}%")
    
    temp = result[result['cum_percentage'] > 80].head(1)
    display(temp)
    print(f"over 80% : {round(((temp.index[0]+1) / result.shape[0] * 100), 2)}%")
    
    temp = result[result['cum_percentage'] > 95].head(1)
    display(temp)
    print(f"over 95% : {round(((temp.index[0]+1) / result.shape[0] * 100), 2)}%")

# %%
pareto(df, 'content_id')
# Out:
# total content_id : 74
#                          content_id  count  percentage  cum_percentage
# 0  f4be1a0fe0e301b03115591777fddf29    904        8.46            8.46
# 1  c269eb6df3a374b464f7c18f12fa398f    573        5.36           13.82
# 2  f491517f4737a60d661cd1fcacc702c0    568        5.32           19.14
# 3  b314d5aba64a0aab40602cb72a4a1504    461        4.31           23.46
# 4  595cb4bbfc83e683b0314ca1312cfbde    387        3.62           27.08
#                           content_id  count  percentage  cum_percentage
# 13  479926b04fe824bce5bdc7e0f81a2539    218        2.04           50.02
# over 50% : 18.92%
#                           content_id  count  percentage  cum_percentage
# 34  ecde9a1b01763f791c3a185d53b5f394    112        1.05           80.39
# over 80% : 47.3%
#                           content_id  count  percentage  cum_percentage
# 52  c7c5e94311c8d7ab7323a14a84339d09     60        0.56           95.04
# over 95% : 71.62%

# %% [markdown]
# #### results [1] : click.content_page_more_review_button.csv
#
# core dropna : 93962 -> 10702\
# user_id            10702\
# \
# drop duplicate : 0 \
# 'user_id' - max conut : 285 \
# over 1 : 11.69% \
# 'user_id', 'client_event_time' - max conut : 2 \
# \
# pareto : \
# \
# total content_id : 74 type\
# over 50% : 18.92% \
# over 80% : 47.3% \
# over 95% : 71.62%

# %% [markdown]
# #### [2] : click.content_page_start_content_button.csv
#
# - 설명 : 콘텐츠 수강하기 버튼 클릭
# - 트리거 :

# %%
# df
file_no = 2
df = dfs[file_no].copy()
print(filelist[file_no])
# Out:
# click.content_page_start_content_button.csv

# %%
# 
display(df.info())
display(df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172911 entries, 0 to 172910
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   city               169437 non-null  object
#  1   client_event_time  172911 non-null  datetime64[ns]
#  2   country            171495 non-null  object
#  3   device_family      172911 non-null  object
#  4   device_type        171581 non-null  object
#  5   event_type         172911 non-null  object
#  6   language           172911 non-null  object
#  7   os_name            172911 non-null  object
#  8   os_version         172911 non-null  object
#  9   platform           172911 non-null  object
#  10  user_id            128361 non-null  object
#  11  content_id         172699 non-null  object
#  12  button_name_B      86242 non-null   object
#  13  button_name_A      38951 non-null   object
# dtypes: datetime64[ns](1), object(13)
# memory usage: 18.5+ MB
# None
#           city       client_event_time      country device_family device_type  \
# 0      Daejeon 2023-04-05 21:14:38.432  South Korea       Windows     Windows
# 1  Seongnam-si 2023-04-10 14:57:20.033  South Korea       Windows     Windows
# 2   Yangp'yong 2023-04-10 14:28:29.515  South Korea       Windows     Windows
# 3       Seo-gu 2023-04-10 14:09:30.564  South Korea       Windows     Windows
# 4       Seo-gu 2023-04-10 14:10:52.368  South Korea       Windows     Windows
#
#                                 event_type language os_name     os_version  \
# 0  click.content_page_start_content_button   Korean    Edge  111.0.1661.62
# 1  click.content_page_start_content_button   Korean    Edge  112.0.1722.34
# 2  click.content_page_start_content_button   Korean  Chrome      111.0.0.0
# 3  click.content_page_start_content_button   Korean  Chrome      112.0.0.0
# 4  click.content_page_start_content_button   Korean  Chrome      112.0.0.0
#
#   platform                           user_id  \
# 0      Web  41362ad5ebcade2bb1b78344a53e7ccf
# 1      Web  f7155af01d277f11b1c7d05cf772c686
# 2      Web  1b05f9fe82b80771323caa1cd5683143
# 3      Web  353528475f2bd85934263421ccd579b3
# 4      Web  353528475f2bd85934263421ccd579b3
#
#                          content_id button_name_B button_name_A
# 0  445fac33232adcb3d1cdab7d8a579430      콘텐츠 구독하기           NaN
# 1  18992b667be06d6f29ba0008f99d9745      콘텐츠 이어보기           NaN
# 2  dfbdae782996c25daed7517b8835f3aa      콘텐츠 이어보기           NaN
# 3  a1eeebeb6c307641b75b94a2a1d5b9aa      콘텐츠 이어보기           NaN
# 4  7de35a9d8f14c68e5f2a8788dda5f72e      콘텐츠 구독하기           NaN

# %%
# dropna in core_cols
print('before dropna :', df.shape[0], 'entries')
non_id_df = df[df['user_id'].isnull()]
df = df.dropna(subset=core_cols)
print('after dropna  :', df.shape[0], 'entries')
# Out:
# before dropna : 172911 entries
# after dropna  : 128361 entries

# %%
# too_close_log
check_too_close_log(df)
# Out:
# drop duplicate : 377 \
# 'user_id' - max conut : 254 \
# over 1 : 15.24% \
# 'user_id', 'client_event_time' - max conut : 3 \
#              city       client_event_time      country device_family  \
# 99160       Seoul 2022-05-06 05:33:30.223  South Korea       Windows
# 121090    Mapo-gu 2022-05-06 05:33:30.223  South Korea       Windows
# 57589   Jongno-gu 2021-12-26 14:28:32.078  South Korea       Android
# 74949   Anyang-si 2021-12-26 14:28:32.078  South Korea       Android
# 57590   Jongno-gu 2021-12-26 14:40:22.619  South Korea       Android
# 74950   Anyang-si 2021-12-26 14:40:22.619  South Korea       Android
# 116912    Dong-gu 2022-02-26 13:20:14.796  South Korea       Android
# 123268     Seo-gu 2022-02-26 13:20:14.796  South Korea       Android
# 134218  Dalseo-gu 2022-02-26 13:20:14.796  South Korea       Android
#
#        device_type                               event_type language  \
# 99160      Windows  click.content_page_start_content_button   Korean
# 121090     Windows  click.content_page_start_content_button   Korean
# 57589      Android  click.content_page_start_content_button   Korean
# 74949      Android  click.content_page_start_content_button   Korean
# 57590      Android  click.content_page_start_content_button   Korean
# 74950      Android  click.content_page_start_content_button   Korean
# 116912     Android  click.content_page_start_content_button   Korean
# 123268     Android  click.content_page_start_content_button   Korean
# 134218     Android  click.content_page_start_content_button   Korean
#
#                 os_name os_version platform                           user_id  \
# 99160            Chrome        100      Web  16e39802400a3a48d7f6761d1a2ba214
# 121090           Chrome        100      Web  16e39802400a3a48d7f6761d1a2ba214
# 57589   Samsung Browser         16      Web  35fe6a629c1bd6aa50debb8934416432
# 74949   Samsung Browser         16      Web  35fe6a629c1bd6aa50debb8934416432
# 57590   Samsung Browser         16      Web  35fe6a629c1bd6aa50debb8934416432
# 74950   Samsung Browser         16      Web  35fe6a629c1bd6aa50debb8934416432
# 116912  Samsung Browser         16      Web  b532f801fe996fbba59a5aa9ed99b227
# 123268  Samsung Browser         16      Web  b532f801fe996fbba59a5aa9ed99b227
# 134218  Samsung Browser         16      Web  b532f801fe996fbba59a5aa9ed99b227
#
#                               content_id button_name_B button_name_A
# 99160   68a3658f1b936bfff3bd6960cd561b0a           NaN          이어하기
# 121090  68a3658f1b936bfff3bd6960cd561b0a           NaN          이어하기
# 57589   f4be1a0fe0e301b03115591777fddf29           NaN          이어하기
# 74949   f4be1a0fe0e301b03115591777fddf29           NaN          이어하기
# 57590   f4be1a0fe0e301b03115591777fddf29           NaN          이어하기
# 74950   f4be1a0fe0e301b03115591777fddf29           NaN          이어하기
# 116912  f4be1a0fe0e301b03115591777fddf29           NaN          이어하기
# 123268  f4be1a0fe0e301b03115591777fddf29           NaN          이어하기
# 134218  f4be1a0fe0e301b03115591777fddf29           NaN          이어하기
# 160254    6.163596e+07
# 157347    5.965161e+07
# 157695    5.933250e+07
# Name: client_event_time, dtype: float64
# 74950     0.0
# 121090    0.0
# 134218    0.0
# Name: client_event_time, dtype: float64
#
#
# too close log : 3943, 3.08%
#                city       client_event_time        country device_family  \
# 39482         Seoul 2023-05-26 06:06:18.710    South Korea  Apple iPhone
# 130375        Seoul 2022-02-07 06:01:32.163    South Korea       Android
# 37653         Seoul 2023-05-17 01:43:03.130    South Korea       Windows
# 38772        Buk-gu 2023-05-23 12:16:34.631    South Korea       Windows
# 4314      Goyang-si 2023-05-12 03:17:46.045    South Korea           Mac
# ...             ...                     ...            ...           ...
# 51149   Hwaseong-si 2023-06-05 04:30:40.550    South Korea       Windows
# 116436    Songpa-gu 2022-10-30 07:49:48.744    South Korea           Mac
# 158203    Rockville 2023-08-27 03:09:14.199  United States       Windows
# 8813          Seoul 2023-06-03 06:29:35.195    South Korea           Mac
# 125070        Seoul 2022-09-08 23:48:12.617    South Korea  Apple iPhone
#
#                 device_type                               event_type language  \
# 39482   Apple iPhone 14 Pro  click.content_page_start_content_button   Korean
# 130375              Android  click.content_page_start_content_button   Korean
# 37653               Windows  click.content_page_start_content_button   Korean
# 38772               Windows  click.content_page_start_content_button   Korean
# 4314                    Mac  click.content_page_start_content_button   Korean
# ...                     ...                                      ...      ...
# 51149               Windows  click.content_page_start_content_button   Korean
# 116436                  Mac  click.content_page_start_content_button   Korean
# 158203              Windows  click.content_page_start_content_button  English
# 8813                    Mac  click.content_page_start_content_button   Korean
# 125070         Apple iPhone  click.content_page_start_content_button  English
#
#                os_name      os_version platform  \
# 39482        Instagram  283.0.0.16.103      Web
# 130375  Chrome WebView              90      Web
# 37653             Edge   113.0.1774.42      Web
# 38772             Edge   113.0.1774.50      Web
# 4314            Chrome       113.0.0.0      Web
# ...                ...             ...      ...
# 51149           Chrome       113.0.0.0      Web
# 116436          Chrome              98      Web
# 158203          Chrome       116.0.0.0      Web
# 8813            Safari            16.5      Web
# 125070   Mobile Safari              15      Web
#
#                                  user_id                        content_id  \
# 39482   000634ec5553ca63f77c61690353a0be  445fac33232adcb3d1cdab7d8a579430
# 130375  001cc7303b6b6d1cdf369589a53b45bb  c269eb6df3a374b464f7c18f12fa398f
# 37653   00246fef1a90451e4a3ac7c69b1e9b07  f491517f4737a60d661cd1fcacc702c0
# 38772   00246fef1a90451e4a3ac7c69b1e9b07  c269eb6df3a374b464f7c18f12fa398f
# 4314    00407142251a1d41ec06320a3890d629  c269eb6df3a374b464f7c18f12fa398f
# ...                                  ...                               ...
# 51149   ff1cae4c3d8938b99a6d8783467aded4  445fac33232adcb3d1cdab7d8a579430
# 116436  ff8ce46f26e5898f4fdbe1b25f8c30dc  5acd4977e14d5edc6a408ae0d468ca4e
# 158203  ff917e8b6bcf53a48bd1b1efae5d00f5  9aa7628a347707fb155943041e2cb524
# 8813    ffbf309d7d275b5c984276b6d77052ef  f4be1a0fe0e301b03115591777fddf29
# 125070  fff219b952002818462faa3746343f09  afe201c04b426366e0f8e9e2207c78c2
#
#        button_name_B button_name_A
# 39482       콘텐츠 구독하기           NaN
# 130375           NaN      무료로 시작하기
# 37653       콘텐츠 이어보기           NaN
# 38772       콘텐츠 구독하기           NaN
# 4314        콘텐츠 구독하기           NaN
# ...              ...           ...
# 51149       콘텐츠 구독하기           NaN
# 116436           NaN           NaN
# 158203      콘텐츠 구독하기           NaN
# 8813        콘텐츠 이어보기           NaN
# 125070           NaN           NaN
#
# [3943 rows x 14 columns]

# %%
# pareto
for col in df.columns:
    # pass through common columns
    if col in common_cols: continue
    
    # display
    print(f"\n\n{col}")
    pareto(df, col)
# Out:
# content_id
# total content_id : 165
#                          content_id  count  percentage  cum_percentage
# 0  f4be1a0fe0e301b03115591777fddf29  13183       10.28           10.28
# 1  f491517f4737a60d661cd1fcacc702c0  10383        8.10           18.38
# 2  61b6463287573f00de13a930805a52d6   8872        6.92           25.30
# 3  595cb4bbfc83e683b0314ca1312cfbde   5702        4.45           29.75
# 4  c269eb6df3a374b464f7c18f12fa398f   5191        4.05           33.80
#                           content_id  count  percentage  cum_percentage
# 10  445fac33232adcb3d1cdab7d8a579430   2619        2.04           50.72
# over 50% : 6.67%
#                           content_id  count  percentage  cum_percentage
# 34  3ca120746c79812b35a345a8a509b5ba    999        0.78           80.28
# over 80% : 21.21%
#                           content_id  count  percentage  cum_percentage
# 64  6c114626032aa4a43c62fd7fcdb19543    337        0.26           95.26
# over 95% : 39.39%
#
#
# button_name_B
# total button_name_B : 7
#   button_name_B  count  percentage  cum_percentage
# 0      콘텐츠 구독하기  31776       51.83           51.83
# 1      콘텐츠 이어보기  25914       42.27           94.09
# 2      무료로 들어보기   1762        2.87           96.97
# 3      무료로 시작하기   1253        2.04           99.01
# 4     최저가 혜택 받기    323        0.53           99.54
#   button_name_B  count  percentage  cum_percentage
# 0      콘텐츠 구독하기  31776       51.83           51.83
# over 50% : 14.29%
#   button_name_B  count  percentage  cum_percentage
# 1      콘텐츠 이어보기  25914       42.27           94.09
# over 80% : 28.57%
#   button_name_B  count  percentage  cum_percentage
# 2      무료로 들어보기   1762        2.87           96.97
# over 95% : 42.86%
#
#
# button_name_A
# total button_name_A : 4
#   button_name_A  count  percentage  cum_percentage
# 0          이어하기  23729       70.49           70.49
# 1          수강하기   3938       11.70           82.18
# 2          수강시작   3716       11.04           93.22
# 3      무료로 시작하기   2282        6.78          100.00
#   button_name_A  count  percentage  cum_percentage
# 0          이어하기  23729       70.49           70.49
# over 50% : 25.0%
#   button_name_A  count  percentage  cum_percentage
# 1          수강하기   3938        11.7           82.18
# over 80% : 50.0%
#   button_name_A  count  percentage  cum_percentage
# 3      무료로 시작하기   2282        6.78           100.0
# over 95% : 100.0%

# %%
# too close log in non_id_df
check_too_close_log(non_id_df)
# Out:
# drop duplicate : 1 \
# 'user_id' - max conut : nan \
# over 1 : 0.0% \
# 'user_id', 'client_event_time' - max conut : nan \
#
# Series([], Name: client_event_time, dtype: float64)
# Series([], Name: client_event_time, dtype: float64)

# %%
# pareto with non_id_df
for col in non_id_df.columns:
    # pass through common columns
    if col in common_cols: continue
    
    # display
    print(f"\n\n{col}")
    pareto(non_id_df, col)
# Out:
# content_id
# total content_id : 121
#                          content_id  count  percentage  cum_percentage
# 0  61b6463287573f00de13a930805a52d6  24528       55.14           55.14
# 1  f4be1a0fe0e301b03115591777fddf29   3093        6.95           62.09
# 2  c269eb6df3a374b464f7c18f12fa398f   2126        4.78           66.87
# 3  68a3658f1b936bfff3bd6960cd561b0a   1037        2.33           69.20
# 4  a914987711c7e2db9fd4bff7555ec87c    855        1.92           71.12
#                          content_id  count  percentage  cum_percentage
# 0  61b6463287573f00de13a930805a52d6  24528       55.14           55.14
# over 50% : 0.83%
#                           content_id  count  percentage  cum_percentage
# 11  7de35a9d8f14c68e5f2a8788dda5f72e    474        1.07           80.77
# over 80% : 9.92%
#                           content_id  count  percentage  cum_percentage
# 47  a22ba84357f14db47d32fa2fbbb4f1e8     82        0.18           95.12
# over 95% : 39.67%
#
#
# button_name_B
# total button_name_B : 8
#   button_name_B  count  percentage  cum_percentage
# 0      무료로 들어보기  11834       47.47           47.47
# 1      콘텐츠 구독하기   9185       36.84           84.31
# 2      콘텐츠 이어보기   1883        7.55           91.87
# 3      무료로 시작하기   1260        5.05           96.92
# 4     최저가 혜택 받기    584        2.34           99.26
#   button_name_B  count  percentage  cum_percentage
# 1      콘텐츠 구독하기   9185       36.84           84.31
# over 50% : 25.0%
#   button_name_B  count  percentage  cum_percentage
# 1      콘텐츠 구독하기   9185       36.84           84.31
# over 80% : 25.0%
#   button_name_B  count  percentage  cum_percentage
# 3      무료로 시작하기   1260        5.05           96.92
# over 95% : 50.0%
#
#
# button_name_A
# total button_name_A : 3
#   button_name_A  count  percentage  cum_percentage
# 0      무료로 시작하기   3812       72.12           72.12
# 1          수강하기   1410       26.67           98.79
# 2          이어하기     64        1.21          100.00
#   button_name_A  count  percentage  cum_percentage
# 0      무료로 시작하기   3812       72.12           72.12
# over 50% : 33.33%
#   button_name_A  count  percentage  cum_percentage
# 1          수강하기   1410       26.67           98.79
# over 80% : 66.67%
#   button_name_A  count  percentage  cum_percentage
# 1          수강하기   1410       26.67           98.79
# over 95% : 66.67%

# %% [markdown]
# #### result [2] : click.content_page_start_content_button.csv
#
# core dropna : 172911 -> 128361\
# user_id            128361 \
# \
# drop duplicate : 377 \
# 'user_id' - max conut : 254 \
# over 1 : 15.24% \
# 'user_id', 'client_event_time' - max conut : 3 \
# \
# too close log : 3943, 3.08% \
# \
# pareto : \
# \
# total content_id : 165 type \
# over 50% : 6.67% \
# over 80% : 21.21% \
# over 95% : 39.39% \
# \
# total button_name_B : 7 type \
# 콘텐츠 구독하기	51.83 \
# 콘텐츠 이어보기	42.27 \
# 무료로 들어보기	2.87 \
# 무료로 시작하기	2.04 \
# 최저가 혜택받기	0.53 \
# \
# over 50% : 14.29% \
# over 80% : 28.57% \
# over 95% : 42.86% \
# \
# total button_name_A : 4 type \
# 이어하기 70.49 \
# 수강하기 11.70 \
# 수강시작 11.04 \
# 무료로 시작하기 6.78 \
# \
# over 50% : 25.0% \
# over 80% : 50.0% \
# over 95% : 100.0% \
# \
# non_id_df pareto : \
# \
# total content_id : 121 type \
# over 50% : 0.83% \
# over 80% : 9.92% \
# over 95% : 39.67% \
# \
# total button_name_B : 8 type \
# 무료로 들어보기 47.47 \
# 콘텐츠 구독하기 36.84 \
# 콘텐츠 이어보기 7.55 \
# 무료로 시작하기 5.05 \
# 최저가 혜택 받기 2.34 \
# \
# over 50% : 25.0% \
# over 80% : 25.0% \
# over 95% : 50.0% \
# \
# total button_name_A : 3 type \
# 무료로 시작하기 72.12 \
# 수강하기 26.67 \
# 이어하기 1.21 \
# \
# over 50% : 33.33% \
# over 80% : 66.67% \
# over 95% : 66.67%

# %% [markdown]
# #### [3] : click.lesson_page_related_question_box.csv
# - 설명 : 레슨 페이지 내 질문 목록 클릭
# - 트리거 :

# %%
# df
file_no = 3
df = dfs[file_no].copy()
print(filelist[file_no])
# Out:
# click.lesson_page_related_question_box.csv

# %%
# 
display(df.info())
display(df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1379136 entries, 0 to 1379135
# Data columns (total 14 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   city               1355675 non-null  object
#  1   client_event_time  1379136 non-null  datetime64[ns]
#  2   country            1364245 non-null  object
#  3   device_family      1379135 non-null  object
#  4   device_type        1372802 non-null  object
#  5   event_type         1379136 non-null  object
#  6   language           1379136 non-null  object
#  7   os_name            1379135 non-null  object
#  8   os_version         1379136 non-null  object
#  9   platform           1379136 non-null  object
#  10  user_id            1326233 non-null  object
#  11  question_id        824789 non-null   object
#  12  content_id         824788 non-null   object
#  13  lesson_id          824789 non-null   object
# dtypes: datetime64[ns](1), object(13)
# memory usage: 147.3+ MB
# None
#         city       client_event_time      country  device_family  \
# 0    Dong-gu 2023-04-05 21:51:48.377  South Korea  Samsung Phone
# 1    Dong-gu 2023-04-05 21:52:21.689  South Korea  Samsung Phone
# 2    Dong-gu 2023-04-05 21:52:42.481  South Korea  Samsung Phone
# 3  Goyang-si 2023-04-05 21:20:15.032  South Korea            Mac
# 4  Goyang-si 2023-04-05 21:21:55.275  South Korea            Mac
#
#              device_type                              event_type language  \
# 0  Samsung Galaxy S21 5G  click.lesson_page_related_question_box  English
# 1  Samsung Galaxy S21 5G  click.lesson_page_related_question_box  English
# 2  Samsung Galaxy S21 5G  click.lesson_page_related_question_box  English
# 3                    Mac  click.lesson_page_related_question_box   Korean
# 4                    Mac  click.lesson_page_related_question_box   Korean
#
#   os_name os_version platform                           user_id  \
# 0  Chrome  111.0.0.0      Web  117f95e12266dcf8f911ae39ff55a800
# 1  Chrome  111.0.0.0      Web  117f95e12266dcf8f911ae39ff55a800
# 2  Chrome  111.0.0.0      Web  117f95e12266dcf8f911ae39ff55a800
# 3  Chrome  111.0.0.0      Web  e1f3ecae035a3c8ae8cf789fbde98995
# 4  Chrome  111.0.0.0      Web  e1f3ecae035a3c8ae8cf789fbde98995
#
#                         question_id                        content_id  \
# 0  c654f9825245640595af9b8aecb150aa  c269eb6df3a374b464f7c18f12fa398f
# 1  898fb79fc740dc8705b52fb32521d5d5  c269eb6df3a374b464f7c18f12fa398f
# 2  9fb80c124d57fd31494738e0af5437a3  c269eb6df3a374b464f7c18f12fa398f
# 3  9016e2246486e852992ccd9ae0eb27ca  c269eb6df3a374b464f7c18f12fa398f
# 4  4ecd552eeded70b3274b8edf3ecacbd9  c269eb6df3a374b464f7c18f12fa398f
#
#                           lesson_id
# 0  e7dbf75457e67ef644d4ae1981b9e01b
# 1  e7dbf75457e67ef644d4ae1981b9e01b
# 2  e7dbf75457e67ef644d4ae1981b9e01b
# 3  395bdf0293b24ec47d5a9e960574f851
# 4  a738c7835388066e2618af1e5ebacb3c

# %%
main_cols = ['question_id', 'content_id', 'lesson_id']

non_user_mask = df['user_id'].isnull()
non_lesson_mask = df['lesson_id'].isnull()

display(df[non_user_mask].info())
display(df[non_user_mask & non_lesson_mask].count())
display(df[~non_user_mask].info())
display(df[(~non_user_mask) & non_lesson_mask].count())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52903 entries, 574 to 1379133
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   city               52510 non-null  object
#  1   client_event_time  52903 non-null  datetime64[ns]
#  2   country            52844 non-null  object
#  3   device_family      52903 non-null  object
#  4   device_type        51586 non-null  object
#  5   event_type         52903 non-null  object
#  6   language           52903 non-null  object
#  7   os_name            52903 non-null  object
#  8   os_version         52903 non-null  object
#  9   platform           52903 non-null  object
#  10  user_id            0 non-null      object
#  11  question_id        51611 non-null  object
#  12  content_id         51611 non-null  object
#  13  lesson_id          51611 non-null  object
# dtypes: datetime64[ns](1), object(13)
# memory usage: 6.1+ MB
# None
# city                 1277
# client_event_time    1292
# country              1292
# device_family        1292
# device_type          1292
# event_type           1292
# language             1292
# os_name              1292
# os_version           1292
# platform             1292
# user_id                 0
# question_id             0
# content_id              0
# lesson_id               0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 1326233 entries, 0 to 1379135
# Data columns (total 14 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   city               1303165 non-null  object
#  1   client_event_time  1326233 non-null  datetime64[ns]
#  2   country            1311401 non-null  object
#  3   device_family      1326232 non-null  object
#  4   device_type        1321216 non-null  object
#  5   event_type         1326233 non-null  object
#  6   language           1326233 non-null  object
#  7   os_name            1326232 non-null  object
#  8   os_version         1326233 non-null  object
#  9   platform           1326233 non-null  object
#  10  user_id            1326233 non-null  object
#  11  question_id        773178 non-null   object
#  12  content_id         773177 non-null   object
#  13  lesson_id          773178 non-null   object
# dtypes: datetime64[ns](1), object(13)
# memory usage: 151.8+ MB
# None
# city                 550150
# client_event_time    553055
# country              553054
# device_family        553055
# device_type          553010
# event_type           553055
# language             553055
# os_name              553055
# os_version           553055
# platform             553055
# user_id              553055
# question_id               0
# content_id                0
# lesson_id                 0
# dtype: int64

# %%
df[(~non_user_mask) & non_lesson_mask].groupby('user_id').size().sort_values(ascending=False)
# Out:
# user_id
# 82c510b51ce662b77a21bf91be093172    2584
# 74c365de4aaecc4f224be12cf686ec83    2576
# 0b9d42aee2cea7b95c782b35e80cfaa5    2060
# 9de691286543de2a316e56a414e7cf4b    1831
# 9a825ca077dc6770eb6b9c49590dc294    1544
#                                     ...
# 493e47b56732e655302301e65dc21790       1
# 49304e230af5dcedf7731c6ac167616c       1
# d65d099eb9c946b99fca05d4bae07d4f       1
# ab6a426d60851d0e6e235ad37477028d       1
# ae8abc690ed6950bf2952e3506c50373       1
# Length: 8721, dtype: int64

# %%
# dropna in main_cols
print('before main_cols dropna :', df.shape[0], 'entries')
df = df.dropna(subset=main_cols)
print('after main_cols dropna  :', df.shape[0], 'entries')

# dropna in core_cols
print('before dropna :', df.shape[0], 'entries')
df = df.dropna(subset=core_cols)
print('after dropna  :', df.shape[0], 'entries')
# Out:
# before main_cols dropna : 1379136 entries
# after main_cols dropna  : 824788 entries
# before dropna : 824788 entries
# after dropna  : 773177 entries

# %%
# too_close_log
check_too_close_log(df)
# Out:
# drop duplicate : 25 \
# 'user_id' - max conut : 3430 \
# over 1 : 3.43% \
# 'user_id', 'client_event_time' - max conut : 2 \
#             city       client_event_time      country device_family  \
# 682097     Seoul 2022-05-04 01:04:56.803  South Korea       Windows
# 1021069  Mapo-gu 2022-05-04 01:04:56.803  South Korea       Windows
# 682098     Seoul 2022-05-04 01:05:31.407  South Korea       Windows
# 1021070  Mapo-gu 2022-05-04 01:05:31.407  South Korea       Windows
# 635465   Mapo-gu 2022-05-06 06:39:41.113  South Korea       Windows
# 682099     Seoul 2022-05-06 06:39:41.113  South Korea       Windows
# 635466   Mapo-gu 2022-05-06 06:39:55.321  South Korea       Windows
# 682100     Seoul 2022-05-06 06:39:55.321  South Korea       Windows
# 635467   Mapo-gu 2022-05-06 06:40:14.505  South Korea       Windows
# 682101     Seoul 2022-05-06 06:40:14.505  South Korea       Windows
#
#         device_type                              event_type language os_name  \
# 682097      Windows  click.lesson_page_related_question_box   Korean  Chrome
# 1021069     Windows  click.lesson_page_related_question_box   Korean  Chrome
# 682098      Windows  click.lesson_page_related_question_box   Korean  Chrome
# 1021070     Windows  click.lesson_page_related_question_box   Korean  Chrome
# 635465      Windows  click.lesson_page_related_question_box   Korean  Chrome
# 682099      Windows  click.lesson_page_related_question_box   Korean  Chrome
# 635466      Windows  click.lesson_page_related_question_box   Korean  Chrome
# 682100      Windows  click.lesson_page_related_question_box   Korean  Chrome
# 635467      Windows  click.lesson_page_related_question_box   Korean  Chrome
# 682101      Windows  click.lesson_page_related_question_box   Korean  Chrome
#
#         os_version platform                           user_id  \
# 682097          99      Web  16e39802400a3a48d7f6761d1a2ba214
# 1021069         99      Web  16e39802400a3a48d7f6761d1a2ba214
# 682098          99      Web  16e39802400a3a48d7f6761d1a2ba214
# 1021070         99      Web  16e39802400a3a48d7f6761d1a2ba214
# 635465         100      Web  16e39802400a3a48d7f6761d1a2ba214
# 682099         100      Web  16e39802400a3a48d7f6761d1a2ba214
# 635466         100      Web  16e39802400a3a48d7f6761d1a2ba214
# 682100         100      Web  16e39802400a3a48d7f6761d1a2ba214
# 635467         100      Web  16e39802400a3a48d7f6761d1a2ba214
# 682101         100      Web  16e39802400a3a48d7f6761d1a2ba214
#
#                               question_id                        content_id  \
# 682097   0b28d6a4bb7bc3cb8bb6b81530f909ca  68a3658f1b936bfff3bd6960cd561b0a
# 1021069  0b28d6a4bb7bc3cb8bb6b81530f909ca  68a3658f1b936bfff3bd6960cd561b0a
# 682098   adff87e0c3c9e81516931aceebee3e78  68a3658f1b936bfff3bd6960cd561b0a
# 1021070  adff87e0c3c9e81516931aceebee3e78  68a3658f1b936bfff3bd6960cd561b0a
# 635465   bc1ca8296f1d74a6a491882c371b09bb  68a3658f1b936bfff3bd6960cd561b0a
# 682099   bc1ca8296f1d74a6a491882c371b09bb  68a3658f1b936bfff3bd6960cd561b0a
# 635466   07665e22f8e778b1087b2b034945ac1d  68a3658f1b936bfff3bd6960cd561b0a
# 682100   07665e22f8e778b1087b2b034945ac1d  68a3658f1b936bfff3bd6960cd561b0a
# 635467   ad89be67aeeba2d148a2556c18c0f8fb  68a3658f1b936bfff3bd6960cd561b0a
# 682101   ad89be67aeeba2d148a2556c18c0f8fb  68a3658f1b936bfff3bd6960cd561b0a
#
#                                 lesson_id
# 682097   1238493aafb242e6bb8b6891271fa8a9
# 1021069  1238493aafb242e6bb8b6891271fa8a9
# 682098   1238493aafb242e6bb8b6891271fa8a9
# 1021070  1238493aafb242e6bb8b6891271fa8a9
# 635465   50c9c2132fc891b215cf5ab9647f2476
# 682099   50c9c2132fc891b215cf5ab9647f2476
# 635466   50c9c2132fc891b215cf5ab9647f2476
# 682100   50c9c2132fc891b215cf5ab9647f2476
# 635467   50c9c2132fc891b215cf5ab9647f2476
# 682101   50c9c2132fc891b215cf5ab9647f2476
# 1347872    5.373651e+07
# 1209377    5.155824e+07
# 1339106    5.106742e+07
# Name: client_event_time, dtype: float64
# 682099     0.0
# 1021070    0.0
# 1021069    0.0
# Name: client_event_time, dtype: float64
#
#
# too close log : 9934, 1.28%
#                   city       client_event_time      country device_family  \
# 1096804  Pyeongtaek-si 2022-11-18 01:48:47.370  South Korea       Windows
# 462730      Gangbuk-gu 2022-04-04 05:13:52.372  South Korea       Windows
# 182834       Seocho-gu 2023-03-16 04:10:04.225  South Korea       Windows
# 76071           Nam-gu 2023-03-04 03:02:12.944  South Korea       Windows
# 1086466         Nam-gu 2022-03-30 11:59:56.623  South Korea       Windows
# ...                ...                     ...          ...           ...
# 343181          Uiwang 2022-06-17 14:19:44.526  South Korea       Android
# 1329045         Nam-gu 2023-11-20 06:19:14.607  South Korea       Windows
# 567107   Dongdaemun-gu 2022-09-06 10:37:01.806  South Korea       Windows
# 334116   Pyeongtaek-si 2022-07-06 10:46:24.263  South Korea           Mac
# 150307     Seongnam-si 2023-01-19 05:15:46.641  South Korea       Windows
#
#         device_type                              event_type language  \
# 1096804     Windows  click.lesson_page_related_question_box   Korean
# 462730      Windows  click.lesson_page_related_question_box   Korean
# 182834      Windows  click.lesson_page_related_question_box   Korean
# 76071       Windows  click.lesson_page_related_question_box   Korean
# 1086466     Windows  click.lesson_page_related_question_box   Korean
# ...             ...                                     ...      ...
# 343181      Android  click.lesson_page_related_question_box   Korean
# 1329045     Windows  click.lesson_page_related_question_box   Korean
# 567107      Windows  click.lesson_page_related_question_box   Korean
# 334116          Mac  click.lesson_page_related_question_box   Korean
# 150307      Windows  click.lesson_page_related_question_box   Korean
#
#                os_name os_version platform                           user_id  \
# 1096804         Chrome  107.0.0.0      Web  0003c0ede663b9e3b55d9dc3f7e8690f
# 462730          Chrome         99      Web  0008a61888a167f7c68df68e9e76dcf7
# 182834          Chrome  110.0.0.0      Web  003d94a1c1aacab781d2f811503fc806
# 76071           Chrome  110.0.0.0      Web  00750a7dbbd08a4656e12de3cfca29e1
# 1086466         Chrome         99      Web  007652bc66e975d889f2c67e10a96de4
# ...                ...        ...      ...                               ...
# 343181   Chrome Mobile        102      Web  ffa0ba9c8fdcceb0013cd7bae98a1137
# 1329045         Chrome  119.0.0.0      Web  ffbc59b51547dfa134d53d9fdb5b3bbd
# 567107          Chrome        105      Web  ffe13db0ad3751c9be06a73aa38bc9fc
# 334116          Chrome        102      Web  fff219b952002818462faa3746343f09
# 150307          Chrome  109.0.0.0      Web  fff3e9ffd58cda1d8068d1dab141760a
#
#                               question_id                        content_id  \
# 1096804  f082779449d765221edcf903d0652dae  f64c475280676531a31f2f8e0648599c
# 462730   b28f061dcec78adc7de3bff76fbbdd63  c269eb6df3a374b464f7c18f12fa398f
# 182834   5074b296d3160893712968533236fce0  7de35a9d8f14c68e5f2a8788dda5f72e
# 76071    100281c4293c52773d79112f8fcdcba3  68a3658f1b936bfff3bd6960cd561b0a
# 1086466  686cbe069f4e86b28a3304b016c60a75  f491517f4737a60d661cd1fcacc702c0
# ...                                   ...                               ...
# 343181   396f955347e5b1b50619fedf1a5ad752  68a3658f1b936bfff3bd6960cd561b0a
# 1329045  168dc39b1d8dd25071b752c6acf3fcd7  f4be1a0fe0e301b03115591777fddf29
# 567107   697b9eb7df84332e294dfee8c661e272  f4be1a0fe0e301b03115591777fddf29
# 334116   f099ecaf5fe0d0da0392ccf913677313  f491517f4737a60d661cd1fcacc702c0
# 150307   eb1ef766e3cd1e2fe731807e5d60db97  7cebec6e79cc981dbf421c5ec2aedd9d
#
#                                 lesson_id
# 1096804  6b568dde9f9c1b2ad04d72b08e08cf99
# 462730   c2b88e494ee633b334aa081cac7b1f02
# 182834   1fdbb6fe35961e1b3d665f0721a842c1
# 76071    70f508c48ababa25afbe3cbea7ea3f49
# 1086466  70f58aeda1228d5e7f8fc118db057478
# ...                                   ...
# 343181   1ccbb1451cd590e160d3951be4e5593d
# 1329045  7be65151a4b1cf91d7ca93b1e2b9ec69
# 567107   3022970a4832e8c927847f63c3fad410
# 334116   dcc27d0a865edfaf0bf3c9d4c59fb43b
# 150307   a7ccb5424862396df12d7438a971d68d
#
# [9934 rows x 14 columns]

# %%
# pareto
for col in df.columns:
    # pass through common columns
    if col in common_cols: continue
    
    # display
    print(f"\n\n{col}")
    pareto(df, col)
# Out:
# question_id
# total question_id : 7770
#                         question_id  count  percentage  cum_percentage
# 0  e568903519ea098d3a507936a0048f85   5926        0.77            0.77
# 1  fa2db8e9aec37d012b721af029e9a831   3372        0.44            1.20
# 2  c61c0aa13a7f972a52fa85c55713691d   3016        0.39            1.59
# 3  c6642c93316f3cf07faae7e124f44c92   2713        0.35            1.94
# 4  225449666eabbdda0841c677f53d7958   2414        0.31            2.26
#                           question_id  count  percentage  cum_percentage
# 699  eaebc99debaa6f83725d74bb9e8ff42a    242        0.03           50.03
# over 50% : 9.01%
#                            question_id  count  percentage  cum_percentage
# 2452  4361e7c2c2301d811f82fc6120f5baf4     79        0.01           80.01
# over 80% : 31.57%
#                            question_id  count  percentage  cum_percentage
# 4665  2e04bdaf0ef8336a76cb7aeaa481d955     32         0.0           95.01
# over 95% : 60.05%
#
#
# content_id
# total content_id : 113
#                          content_id  count  percentage  cum_percentage
# 0  f491517f4737a60d661cd1fcacc702c0  89853       11.62           11.62
# 1  f4be1a0fe0e301b03115591777fddf29  61532        7.96           19.58
# 2  595cb4bbfc83e683b0314ca1312cfbde  60104        7.77           27.35
# 3  c269eb6df3a374b464f7c18f12fa398f  41000        5.30           32.66
# 4  db1819d3a7a4c4d85dccb3b9e982fbcd  33875        4.38           37.04
#                          content_id  count  percentage  cum_percentage
# 8  18992b667be06d6f29ba0008f99d9745  27562        3.56           52.25
# over 50% : 7.96%
#                           content_id  count  percentage  cum_percentage
# 24  db43a841c994231e2795d4df8931af50   8133        1.05           80.26
# over 80% : 22.12%
#                           content_id  count  percentage  cum_percentage
# 46  6ed981e96eb69b7169b85ed3994a4980   2859        0.37           95.06
# over 95% : 41.59%
#
#
# lesson_id
# total lesson_id : 3047
#                           lesson_id  count  percentage  cum_percentage
# 0  bfb6543cc0e7fa189f9c9a0e533b0f43  11155        1.44            1.44
# 1  02968d35dacf2041e4067dc87d9798a2   6374        0.82            2.27
# 2  9e0b12235be198f7d0df892a256deedd   6247        0.81            3.08
# 3  d8576304020cfaf5fed9c37c6bbaaab7   5310        0.69            3.76
# 4  7959a49f1cba70ab23f0c984da609fa9   5136        0.66            4.43
#                             lesson_id  count  percentage  cum_percentage
# 213  f0fc61fe94df8d4b7dc874e979898dc0    751         0.1           50.06
# over 50% : 7.02%
#                             lesson_id  count  percentage  cum_percentage
# 790  11710f807ec1e98be3ea29922dbcc92b    238        0.03           80.03
# over 80% : 25.96%
#                              lesson_id  count  percentage  cum_percentage
# 1575  501ca50ff5f76d8a619aec225022d76d     80        0.01           95.01
# over 95% : 51.72%

# %% [markdown]
# #### results [3] : click.lesson_page_related_question_box.csv
# user_id 가 있는 경우 main_col이 없는 경우가 많았다.\
# : user_id - 553055 / non_user_id - 1292 \
# \
# core dropna : 1379136 -> 824788 -> 773177 \
# main_col            824788 \
# \
# drop duplicate : 25 \
# 'user_id' - max conut : 3430 \
# over 1 : 3.43% \
# 'user_id', 'client_event_time' - max conut : 2 \
# \
# too close log : 9934, 1.28% \
# \
# pareto : \
# \
# total content_id : 113 \
# total lesson_id : 3048 \
# total question_id : 7770 \
# over 50% : 18.92% \
# over 80% : 47.3% \
# over 95% : 71.62%

# %% [markdown]
# #### [4] : complete.lesson.csv
# - 설명 : 레슨 시청 완료
# - 트리거 :

# %%
# df
file_no = 4
df = dfs[file_no].copy()
print(filelist[file_no])
# Out:
# complete.lesson.csv

# %%
#
display(df.info())
display(df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2826056 entries, 0 to 2826055
# Data columns (total 13 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   city               object
#  1   client_event_time  datetime64[ns]
#  2   country            object
#  3   device_family      object
#  4   device_type        object
#  5   event_type         object
#  6   language           object
#  7   os_name            object
#  8   os_version         object
#  9   platform           object
#  10  user_id            object
#  11  content_id         object
#  12  lesson_id          object
# dtypes: datetime64[ns](1), object(12)
# memory usage: 280.3+ MB
# None
#         city       client_event_time      country device_family   device_type  \
# 0  Goyang-si 2022-07-15 07:42:07.150  South Korea       Windows       Windows
# 1      Suwon 2023-12-23 14:17:53.890  South Korea  Apple iPhone  Apple iPhone
# 2    Jung-gu 2022-01-03 13:52:00.803  South Korea       Windows       Windows
# 3        NaN 2022-09-29 16:11:16.184  South Korea       Windows       Windows
# 4  Songpa-gu 2023-04-30 01:13:16.686  South Korea       Windows       Windows
#
#         event_type language os_name os_version platform  \
# 0  complete.lesson   Korean  Chrome        103      Web
# 1  complete.lesson   Korean  WebKit   605.1.15      Web
# 2  complete.lesson   Korean  Chrome         96      Web
# 3  complete.lesson  English    Edge        105      Web
# 4  complete.lesson   Korean  Chrome  112.0.0.0      Web
#
#                             user_id                        content_id  \
# 0  71baf6f9fdf8b6930215685f1cf8ea49  b66cb6ee3ac708fa5c0fd28265c55b36
# 1  0440d59280deefe1ee9f30867fc844fa  e88906bb19b773dcbf2adb5d34c49d9c
# 2  f17054e11e0f3e4e3e026f8fedddfde6  ff7998135d650dbefb3f479c900cbcc7
# 3  5e0c86e7696d9b900124f8581a9b159d  c7c5e94311c8d7ab7323a14a84339d09
# 4  3ba1b259318bd7821cd54a9467cb456b  f491517f4737a60d661cd1fcacc702c0
#
#                           lesson_id
# 0  089303047dc04c29972f8eb33dcd1b92
# 1  7de7e4c4881ff9e452e349f8f4d282cc
# 2  34c27e35aaf6520db2070c0f42faef9f
# 3  a8f9d6d860ce3eb162d80f2e809f8c38
# 4  634669e8bc3e32b38952c40322a5a472

# %%
# dropna in core_cols
print('before dropna :', df.shape[0], 'entries')
df = df.dropna(subset=core_cols)
print('after dropna  :', df.shape[0], 'entries')
# Out:
# before dropna : 2826056 entries
# after dropna  : 2826056 entries

# %%
# too_close_log
check_too_close_log(df)
# Out:
# drop duplicate : 0 \
# 'user_id' - max conut : 1748 \
# over 1 : 1.48% \
# 'user_id', 'client_event_time' - max conut : 2 \
#               city       client_event_time      country device_family  \
# 921930   Yongin-si 2022-11-09 04:03:27.510  South Korea           Mac
# 1598390  Yongin-si 2022-11-09 04:03:27.510  South Korea           Mac
# 151744   Seocho-gu 2022-11-17 02:02:23.897  South Korea           Mac
# 759659   Seocho-gu 2022-11-17 02:02:23.897  South Korea           Mac
#
#         device_type       event_type language os_name os_version platform  \
# 921930          Mac  complete.lesson   Korean  Chrome        107      Web
# 1598390         Mac  complete.lesson   Korean  Chrome        107      Web
# 151744          Mac  complete.lesson  English  Chrome  107.0.0.0      Web
# 759659          Mac  complete.lesson  English  Chrome  107.0.0.0      Web
#
#                                   user_id                        content_id  \
# 921930   43b0c4463cfe98f0e35c27cd4e6542a0  afe201c04b426366e0f8e9e2207c78c2
# 1598390  43b0c4463cfe98f0e35c27cd4e6542a0  afe201c04b426366e0f8e9e2207c78c2
# 151744   d5e0de700e4392e27a067986398e1511  f4be1a0fe0e301b03115591777fddf29
# 759659   d5e0de700e4392e27a067986398e1511  f4be1a0fe0e301b03115591777fddf29
#
#                                 lesson_id
# 921930   9ea1be3c92a8edd9cb3d4fd94a42e7e9
# 1598390  79196e7723938d50c50d28549e66e0d2
# 151744   23d6d66e597b8fb0a706fb0cd12234d6
# 759659   bfb6543cc0e7fa189f9c9a0e533b0f43
# 1995606    6.053286e+07
# 1262731    6.019358e+07
# 838755     5.966404e+07
# Name: client_event_time, dtype: float64
# 1877063    0.001
# 759659     0.000
# 1598390    0.000
# Name: client_event_time, dtype: float64
#
#
# too close log : 934, 0.03%
#                 city       client_event_time      country device_family  \
# 415036        Sydney 2022-04-01 23:53:07.992    Australia           Mac
# 884131     Jongno-gu 2022-02-28 11:43:51.745  South Korea       Windows
# 2681047  Changnyeong 2022-08-05 06:21:09.457  South Korea       Windows
# 872431   Changnyeong 2022-08-05 06:21:15.841  South Korea       Windows
# 1939077  Changnyeong 2022-08-05 06:21:18.607  South Korea       Windows
# ...              ...                     ...          ...           ...
# 2093677    Goyang-si 2022-02-05 01:54:55.083  South Korea       Windows
# 2753324        Daegu 2022-07-01 21:58:35.483  South Korea       Windows
# 1569241  Gangdong-gu 2022-01-02 08:52:52.763  South Korea       Windows
# 382308         Seoul 2022-12-14 08:08:08.975  South Korea       Windows
# 2433579  Seongbuk-gu 2023-09-20 07:02:46.974  South Korea           Mac
#
#         device_type       event_type language os_name os_version platform  \
# 415036          Mac  complete.lesson  English  Chrome         99      Web
# 884131      Windows  complete.lesson   Korean  Chrome         98      Web
# 2681047     Windows  complete.lesson   Korean  Chrome        104      Web
# 872431      Windows  complete.lesson   Korean  Chrome        104      Web
# 1939077     Windows  complete.lesson   Korean  Chrome        104      Web
# ...             ...              ...      ...     ...        ...      ...
# 2093677     Windows  complete.lesson   Korean  Chrome         98      Web
# 2753324     Windows  complete.lesson   Korean  Chrome        103      Web
# 1569241     Windows  complete.lesson   Korean  Chrome         96      Web
# 382308      Windows  complete.lesson   Korean  Chrome  108.0.0.0      Web
# 2433579         Mac  complete.lesson   Korean  Chrome  116.0.0.0      Web
#
#                                   user_id                        content_id  \
# 415036   002109ba574914ed127dcae867110f91  4641438a6c81ef572d997dbdc9100f8b
# 884131   0044b39967b380693517c187aaf75ba8  ff7998135d650dbefb3f479c900cbcc7
# 2681047  004d370605a898527804555b99ff3b4a  61b6463287573f00de13a930805a52d6
# 872431   004d370605a898527804555b99ff3b4a  61b6463287573f00de13a930805a52d6
# 1939077  004d370605a898527804555b99ff3b4a  61b6463287573f00de13a930805a52d6
# ...                                   ...                               ...
# 2093677  fbf58cef9af5e9c087c5318aef192687  7cebec6e79cc981dbf421c5ec2aedd9d
# 2753324  fcfba95911b5b4bf3810419673da7639  ab7068685b7aeac4d6b1a6c0e1c85819
# 1569241  fde46a4aa907c8a667e6ad6214b560cd  03b4a290c08f7fa83933827a994f2e61
# 382308   fe1f1a5866013621dbaacdb45caec398  db1819d3a7a4c4d85dccb3b9e982fbcd
# 2433579  ffc9d92bd89918869c13bab8acab5247  621c7ad99b17d2d16832b618d47aea7e
#
#                                 lesson_id
# 415036   aaf4677f8aec0d234696ff313a1eb586
# 884131   efd15a9acb8c27d70ea88b83c47c0a83
# 2681047  db421b66bfd27eccd0e862e30b4de1be
# 872431   c84ce096d3407c9ce4eebd380df44dbf
# 1939077  f024a88c9328cb19413c04f4cd51f979
# ...                                   ...
# 2093677  1dd275b54ba262b8488a3a9b1bae1e9e
# 2753324  7e321c9a00674f37e5bb650b5d382918
# 1569241  e4b37510a5a95f12355d86c3ef4bfd8c
# 382308   60bc3af1f168a5960bf7e37a06831cb8
# 2433579  71a92c1977097a2c50ec366e34ab75f9
#
# [934 rows x 13 columns]

# %%
# pareto
for col in df.columns:
    # pass through common columns
    if col in common_cols: continue
    
    # display
    print(f"\n\n{col}")
    pareto(df, col)
# Out:
# content_id
# total content_id : 166
#                          content_id   count  percentage  cum_percentage
# 0  f491517f4737a60d661cd1fcacc702c0  222850        7.89            7.89
# 1  c269eb6df3a374b464f7c18f12fa398f  182936        6.47           14.36
# 2  f4be1a0fe0e301b03115591777fddf29  152317        5.39           19.75
# 3  db1819d3a7a4c4d85dccb3b9e982fbcd  112441        3.98           23.73
# 4  595cb4bbfc83e683b0314ca1312cfbde  109934        3.89           27.62
#                           content_id  count  percentage  cum_percentage
# 13  b66cb6ee3ac708fa5c0fd28265c55b36  66911        2.37           52.16
# over 50% : 8.43%
#                           content_id  count  percentage  cum_percentage
# 34  220ce7873b8895d0c81c37600b5bd1e7  25781        0.91           80.85
# over 80% : 21.08%
#                           content_id  count  percentage  cum_percentage
# 59  6c114626032aa4a43c62fd7fcdb19543   8704        0.31           95.28
# over 95% : 36.14%
#
#
# lesson_id
# total lesson_id : 5016
#                           lesson_id  count  percentage  cum_percentage
# 0  bfb6543cc0e7fa189f9c9a0e533b0f43  11441        0.40            0.40
# 1  633d1b30ed699e261ea338ad28952338  11114        0.39            0.80
# 2  a6a8c4b3f5b40b8a96c8f6db10e43bf8  10643        0.38            1.17
# 3  7be65151a4b1cf91d7ca93b1e2b9ec69  10041        0.36            1.53
# 4  17e921513ea63e9dafa11cd84eed32b9   9855        0.35            1.88
#                             lesson_id  count  percentage  cum_percentage
# 531  61d44109db9831456f8eaeaba124b16d   1412        0.05           50.05
# over 50% : 10.61%
#                              lesson_id  count  percentage  cum_percentage
# 1572  6764cf4dbcc41ec59311555fa7c2e25c    553        0.02           80.02
# over 80% : 31.36%
#                              lesson_id  count  percentage  cum_percentage
# 2763  05ec4e33bfe757a219efab9355d67335    205        0.01           95.01
# over 95% : 55.1%

# %%
df.isna().sum()
# Out:
# city                 99628
# client_event_time        0
# country              78088
# device_family        27979
# device_type          42379
# event_type               0
# language             27967
# os_name              28114
# os_version               0
# platform             27967
# user_id                  0
# content_id               0
# lesson_id                0
# dtype: int64

# %% [markdown]
# #### results [4] : complete.lesson.csv
# core dropna : 5405069  -> 5405069
# \
# drop duplicate : 5 \
# 'user_id' - max conut : 3345 \
# over 1 : 0.84% \
# 'user_id', 'client_event_time' - max conut : 2 \
# \
# df.isna().sum() \
# city                 189679 \
# client_event_time         0 \
# country              148360 \
# device_family         53035 \
# device_type           80829 \
# event_type                0 \
# language              53014 \
# os_name               53291 \
# os_version            54076 \
# platform              53014 \
# user_id                   0 \
# content_id                0 \
# lesson_id                 0 \
# \
# too close log : 2807, 0.05% \
# \
# pareto : \
# \
# total content_id : 168 \
# over 50% : 8.33% \
# over 80% : 20.83% \
# over 95% : 35.71% \
# total lesson_id : 5050 \
# over 50% : 10.53% \
# over 80% : 31.19% \
# over 95% : 54.75%

# %% [markdown]
# #### [5] : complete.signup.csv
# - 설명 : 회원가입 완료

# %%
# df
file_no = 5
df = dfs[file_no].copy()
print(filelist[file_no])
# Out:
# complete.signup.csv

# %%
#
display(df.info())
display(df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145133 entries, 0 to 145132
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   city               44774 non-null   object
#  1   client_event_time  145133 non-null  datetime64[ns]
#  2   country            45756 non-null   object
#  3   device_family      45767 non-null   object
#  4   device_type        44659 non-null   object
#  5   event_type         145133 non-null  object
#  6   language           45767 non-null   object
#  7   os_name            45745 non-null   object
#  8   os_version         145133 non-null  object
#  9   platform           45767 non-null   object
#  10  user_id            145133 non-null  object
#  11  type               144958 non-null  object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 13.3+ MB
# None
#      city       client_event_time      country device_family   device_type  \
# 0     NaN 2023-04-05 21:33:26.068          NaN           NaN           NaN
# 1     NaN 2023-04-05 21:45:18.672          NaN           NaN           NaN
# 2  Seo-gu 2023-04-10 14:47:56.424  South Korea       Windows       Windows
# 3   Suwon 2023-04-10 14:25:45.920  South Korea  Apple iPhone  Apple iPhone
# 4     NaN 2023-04-10 14:09:50.698          NaN           NaN           NaN
#
#         event_type language        os_name os_version platform  \
# 0  complete.signup      NaN            NaN        nan      NaN
# 1  complete.signup      NaN            NaN        nan      NaN
# 2  complete.signup   Korean         Chrome  111.0.0.0      Web
# 3  complete.signup   Korean  Mobile Safari       16.3      Web
# 4  complete.signup      NaN            NaN        nan      NaN
#
#                             user_id   type
# 0  74d17c27a41656e7788b0c81d9f76cda  kakao
# 1  06b6868000a5d576180aca47896d6cce  kakao
# 2  e131c319972bd580146c5a2faba26613  kakao
# 3  e3b8bfa80d866f296aad139e09023ef3  naver
# 4  5208a60918f18562ac9d668a35b20303  kakao

# %%
# dropna in core_cols
print('before dropna :', df.shape[0], 'entries')
df = df.dropna(subset=core_cols)
print('after dropna  :', df.shape[0], 'entries')
# Out:
# before dropna : 145133 entries
# after dropna  : 145133 entries

# %%
# too_close_log
check_too_close_log(df)
# Out:
# drop duplicate : 0 \
# 'user_id' - max conut : 1 \
# over 1 : 0.0% \
# 'user_id', 'client_event_time' - max conut : 1 \
#
# Series([], Name: client_event_time, dtype: float64)
# Series([], Name: client_event_time, dtype: float64)

# %%
# pareto
for col in df.columns:
    # pass through common columns
    if col in common_cols: continue
    
    # display
    print(f"\n\n{col}")
    pareto(df, col)
# Out:
# type
# total type : 6
#        type  count  percentage  cum_percentage
# 0     kakao  89484       61.73           61.73
# 1    google  21465       14.81           76.54
# 2     naver  19440       13.41           89.95
# 3     email  14126        9.74           99.69
# 4  facebook    442        0.30          100.00
#     type  count  percentage  cum_percentage
# 0  kakao  89484       61.73           61.73
# over 50% : 16.67%
#     type  count  percentage  cum_percentage
# 2  naver  19440       13.41           89.95
# over 80% : 50.0%
#     type  count  percentage  cum_percentage
# 3  email  14126        9.74           99.69
# over 95% : 66.67%

# %% [markdown]
# #### pre-defined and database info - [5]

# %%
print(f'num of users : {df["user_id"].nunique()}')
# Out:
# num of users : 145133

# %%
mask = df.isna().any(axis = 1)
non_info_user = list(df.loc[mask, 'user_id'].values)
info_user = list(df.loc[~mask, 'user_id'].values)
info_user[:5]
# Out:
# ['e131c319972bd580146c5a2faba26613',
#  'e3b8bfa80d866f296aad139e09023ef3',
#  '43264caf4d797e1c485a8b1f588dc5ce',
#  '9f9a65b7615301fba1a2b449278d54be',
#  'e9dd1b9bc5f155f30b20bc19a99bcc93']

# %% [markdown]
# #### results [5] : complete.signup.csv
# \
# core dropna : 145133
# \
# drop duplicate : 0 \
# 'user_id' - unique \
# over 1 : 0.0% \
# 'user_id', 'client_event_time' - unique \
# \
# pareto : \
# \
# total type : 6 \
# kakao   61.73 \
# google  14.81 \
# naver   13.41 \
# email   9.74 \
# facebook 0.30 \
# \
# over 50% : 16.67% \
# over 80% : 50.0% \
# over 95% : 66.67%

# %% [markdown]
# #### [6] : complete.subscription.csv
# - 설명 : 첫 결제 완료
# - 트리거 :

# %%
# df
file_no = 6
df = dfs[file_no].copy()
print(filelist[file_no])
# Out:
# complete.subscription.csv

# %%
#
display(df.info())
display(df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14289 entries, 0 to 14288
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   city                    13757 non-null  object
#  1   client_event_time       14289 non-null  datetime64[ns]
#  2   country                 13906 non-null  object
#  3   device_family           13914 non-null  object
#  4   device_type             13764 non-null  object
#  5   event_type              14289 non-null  object
#  6   language                13914 non-null  object
#  7   os_name                 13908 non-null  object
#  8   os_version              14289 non-null  object
#  9   platform                13914 non-null  object
#  10  user_id                 14289 non-null  object
#  11  plan_price              14289 non-null  int64
#  12  paid_amount             14289 non-null  int64
#  13  coupon_discount_amount  14289 non-null  int64
#  14  pg_type                 1642 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(11)
# memory usage: 1.6+ MB
# None
#            city       client_event_time      country device_family  \
# 0      Nowon-gu 2023-04-05 21:40:04.000  South Korea       Windows
# 1         Seoul 2023-04-10 14:20:03.008  South Korea  Apple iPhone
# 2       Yangsan 2023-03-12 08:46:14.026  South Korea       Windows
# 3  Geumjeong-gu 2023-04-12 11:35:01.865  South Korea       Windows
# 4   Gwangmyeong 2023-05-31 01:25:55.820  South Korea           Mac
#
#     device_type             event_type language        os_name     os_version  \
# 0       Windows  complete.subscription   Korean           Edge  111.0.1661.62
# 1  Apple iPhone  complete.subscription   Korean  Mobile Safari           16.3
# 2       Windows  complete.subscription   Korean         Chrome      111.0.0.0
# 3       Windows  complete.subscription   Korean         Chrome      111.0.0.0
# 4           Mac  complete.subscription   Korean         Chrome      113.0.0.0
#
#   platform                           user_id  plan_price  paid_amount  \
# 0      Web  1116a2ae90ca6b06f85feba27ad51ef0       15920        15920
# 1      Web  c0f5678df8967163e6e2c464ed006791      131600       131600
# 2      Web  79421b5d038205ad7adbb1e2c3b89741      131600       119756
# 3      Web  bdffe1f18684704d4ea2d7eebcaed180      131600       131600
# 4      Web  d4f54ecf6c4d7bf8742f80505f02d6dc       15920        15920
#
#    coupon_discount_amount pg_type
# 0                       0     NaN
# 1                       0     NaN
# 2                   11844     NaN
# 3                       0     NaN
# 4                       0     NaN

# %%
# dropna in core_cols
print('before dropna :', df.shape[0], 'entries')
df = df.dropna(subset=core_cols)
print('after dropna  :', df.shape[0], 'entries')
# Out:
# before dropna : 14289 entries
# after dropna  : 14289 entries

# %%
# too_close_log
check_too_close_log(df)
# Out:
# drop duplicate : 2 \
# 'user_id' - max conut : 8 \
# over 1 : 2.51% \
# 'user_id', 'client_event_time' - max conut : 1 \
#
# 11965    6.168952e+07
# 12701    5.759283e+07
# 11144    3.994890e+07
# Name: client_event_time, dtype: float64
# 8995    0.002
# 9371    0.001
# 7629    0.001
# Name: client_event_time, dtype: float64
#
#
# too close log : 56, 0.39%
#                   city       client_event_time      country device_family  \
# 4916             Seoul 2022-11-08 09:20:01.878  South Korea           Mac
# 8476        Gangnam-gu 2022-11-11 17:10:01.852  South Korea       Windows
# 6836        Dongjak-gu 2022-11-17 12:30:02.728  South Korea       Windows
# 5186           Cheonan 2022-11-14 10:45:02.908  South Korea       Windows
# 8995         Yongin-si 2022-11-19 12:45:02.194  South Korea       Windows
# 5005              Gumi 2022-11-15 23:15:01.630  South Korea       Windows
# 5339       Gwangjin-gu 2022-11-14 03:25:02.424  South Korea       Windows
# 8474         Seocho-gu 2022-11-13 12:40:02.088  South Korea           Mac
# 9309             Seoul 2022-11-13 15:20:02.176  South Korea       Windows
# 5194             Seoul 2022-11-16 15:55:02.077  South Korea  Apple iPhone
# 9371        Gangnam-gu 2022-11-09 05:36:09.962  South Korea  Apple iPhone
# 3704             Seoul 2022-11-14 02:55:02.244  South Korea  Apple iPhone
# 5069        Siheung-si 2022-11-20 08:19:08.914  South Korea       Windows
# 6013             Seoul 2022-11-15 07:50:11.094  South Korea  Apple iPhone
# 6302   Yeongdeungpo-gu 2022-11-19 23:50:02.679  South Korea       Windows
# 7629             Suwon 2022-11-09 04:50:01.701  South Korea       Windows
# 9943        Gangseo-gu 2022-11-08 07:40:01.856  South Korea       Windows
# 6565            Seo-gu 2022-11-10 07:05:01.598  South Korea       Windows
# 10026            Wonju 2022-11-14 13:50:01.778  South Korea       Windows
# 6825               NaN 2022-11-14 11:15:02.681          NaN           NaN
# 8468        Dongjak-gu 2022-11-10 11:35:01.852  South Korea       Windows
# 5249             Seoul 2022-11-17 03:15:01.879  South Korea           Mac
# 8742           Cheonan 2022-11-15 08:00:01.859  South Korea           Mac
# 5066        Yongsan-gu 2022-11-20 08:44:42.156  South Korea       Windows
# 8159      Seongdong-gu 2022-11-09 10:25:02.398  South Korea       Windows
# 6364             Hanam 2022-11-12 04:25:02.677  South Korea       Windows
# 10247            Seoul 2022-11-16 09:05:01.665  South Korea  Apple iPhone
# 5213      Uijeongbu-si 2022-11-14 09:55:02.443  South Korea       Android
# 4585          Changwon 2022-11-16 07:30:02.537  South Korea       Windows
# 7762      Eunpyeong-gu 2022-11-15 12:00:01.717  South Korea           Mac
# 9284         Songpa-gu 2022-11-17 06:40:03.543  South Korea       Windows
# 8630       Hwaseong-si 2022-11-12 21:07:56.258  South Korea       Windows
# 8823             Seoul 2022-11-12 00:50:02.215  South Korea       Windows
# 7437         Goyang-si 2022-11-14 00:35:01.937  South Korea       Windows
# 3603        Yuseong-gu 2022-11-20 03:45:02.854  South Korea       Windows
# 6977             Seoul 2022-11-19 07:30:02.179  South Korea       Windows
# 6374         Songpa-gu 2022-11-09 13:05:01.882  South Korea       Windows
# 7982          Nowon-gu 2022-11-14 06:30:03.169  South Korea       Windows
# 8847             Seoul 2022-11-21 09:34:14.165  South Korea       Windows
# 10283         Gimpo-si 2022-11-11 01:35:02.019  South Korea       Windows
# 9513         Chuncheon 2022-11-14 07:50:02.044  South Korea       Windows
# 4168       Quezon City 2022-11-15 10:10:02.586  Philippines       Windows
# 9373             Seoul 2022-11-09 05:15:02.692  South Korea           Mac
# 9819             Seoul 2022-11-21 10:23:25.096  South Korea           Mac
# 6201      Geumjeong-gu 2022-11-20 14:11:54.386  South Korea       Windows
# 8236         Gwanak-gu 2022-11-16 05:45:01.933  South Korea       Windows
# 7601        Bucheon-si 2022-11-15 04:00:02.275  South Korea       Windows
# 10060     Eunpyeong-gu 2022-11-11 16:50:04.486  South Korea           Mac
# 6754        Gangnam-gu 2022-11-08 08:45:03.432  South Korea       Windows
# 5738         Gangneung 2022-11-17 04:30:43.430  South Korea       Windows
# 6535       Hwaseong-si 2022-11-20 04:45:01.679  South Korea           Mac
# 6866          Gimpo-si 2022-11-10 12:35:02.074  South Korea       Windows
# 7815           Incheon 2022-11-10 04:55:01.926  South Korea       Windows
# 5441            Nam-gu 2022-11-20 02:16:48.467  South Korea       Windows
# 10014       Yangp'yong 2022-11-16 16:00:02.554  South Korea  Apple iPhone
# 9282             Seoul 2022-11-17 06:20:03.875  South Korea           Mac
#
#         device_type             event_type language         os_name  \
# 4916            Mac  complete.subscription   Korean          Chrome
# 8476        Windows  complete.subscription   Korean          Chrome
# 6836        Windows  complete.subscription   Korean          Chrome
# 5186        Windows  complete.subscription   Korean          Chrome
# 8995        Windows  complete.subscription   Korean          Chrome
# 5005        Windows  complete.subscription   Korean            Edge
# 5339        Windows  complete.subscription   Korean          Chrome
# 8474            Mac  complete.subscription   Korean          Chrome
# 9309        Windows  complete.subscription   Korean            Edge
# 5194   Apple iPhone  complete.subscription   Korean   Mobile Safari
# 9371   Apple iPhone  complete.subscription   Korean   Mobile Safari
# 3704   Apple iPhone  complete.subscription   Korean   Mobile Safari
# 5069        Windows  complete.subscription   Korean          Chrome
# 6013   Apple iPhone  complete.subscription   Korean   Mobile Safari
# 6302        Windows  complete.subscription   Korean         Firefox
# 7629        Windows  complete.subscription   Korean          Chrome
# 9943        Windows  complete.subscription   Korean          Chrome
# 6565        Windows  complete.subscription   Korean          Chrome
# 10026       Windows  complete.subscription   Korean            Edge
# 6825            NaN  complete.subscription      NaN             NaN
# 8468        Windows  complete.subscription   Korean          Chrome
# 5249            Mac  complete.subscription   Korean          Safari
# 8742            Mac  complete.subscription   Korean          Chrome
# 5066        Windows  complete.subscription   Korean          Chrome
# 8159        Windows  complete.subscription   Korean          Chrome
# 6364        Windows  complete.subscription   Korean          Chrome
# 10247  Apple iPhone  complete.subscription   Korean   Mobile Safari
# 5213        Android  complete.subscription   Korean  Chrome WebView
# 4585        Windows  complete.subscription   Korean          Chrome
# 7762            Mac  complete.subscription   Korean          Chrome
# 9284        Windows  complete.subscription   Korean          Chrome
# 8630        Windows  complete.subscription   Korean          Chrome
# 8823        Windows  complete.subscription   Korean          Chrome
# 7437        Windows  complete.subscription   Korean          Chrome
# 3603        Windows  complete.subscription   Korean          Chrome
# 6977        Windows  complete.subscription   Korean          Chrome
# 6374        Windows  complete.subscription   Korean          Chrome
# 7982        Windows  complete.subscription   Korean            Edge
# 8847        Windows  complete.subscription   Korean          Chrome
# 10283       Windows  complete.subscription   Korean          Chrome
# 9513        Windows  complete.subscription   Korean          Chrome
# 4168        Windows  complete.subscription   Korean          Chrome
# 9373            Mac  complete.subscription   Korean          Safari
# 9819            Mac  complete.subscription   Korean          Safari
# 6201        Windows  complete.subscription   Korean          Chrome
# 8236        Windows  complete.subscription   Korean          Chrome
# 7601        Windows  complete.subscription   Korean          Chrome
# 10060           Mac  complete.subscription   Korean          Safari
# 6754        Windows  complete.subscription   Korean          Chrome
# 5738        Windows  complete.subscription   Korean         Firefox
# 6535            Mac  complete.subscription   Korean          Chrome
# 6866        Windows  complete.subscription   Korean          Chrome
# 7815        Windows  complete.subscription   Korean          Chrome
# 5441        Windows  complete.subscription  English          Chrome
# 10014  Apple iPhone  complete.subscription   Korean   Mobile Safari
# 9282            Mac  complete.subscription   Korean          Chrome
#
#       os_version platform                           user_id  plan_price  \
# 4916         106      Web  02a857284f291785a949fbd7ed7d6e91       42960
# 8476         107      Web  08e0a0b1e7ae39f10cba93cfbfec6ec1       15920
# 6836         107      Web  0ec79c4ff05cb031b57225643ded1c97      131600
# 5186         107      Web  12df81eb070929dbc64ebe17fc95176e       15920
# 8995         107      Web  139c1cf233ccae4be971eac38eb105b5       15920
# 5005         107      Web  13b3fce2a05f0e6b75c6714d27e2b38a       15920
# 5339         107      Web  17dbedc75e53644666161f41d17a760d       15920
# 8474         107      Web  1d4cb749775a764c9bee81e9faa84b2e       15920
# 9309         107      Web  21fdeec4cae2b5512f39ac6ed3a4fdcf       15920
# 5194          16      Web  2224ca341fc08e5603c82c0f63d75b70      131600
# 9371          16      Web  23583298989b16fd0e3255c6bd57c115       42960
# 3704          16      Web  2c47885aaf508af388351cccdd4093ce       15920
# 5069   107.0.0.0      Web  2fe40e7191a768e71edd18f11ab30e0c       15920
# 6013          16      Web  332de0c72933a86b9a3e11e84b52beaf      131600
# 6302       106.0      Web  33d43ec83ac1705537c9288a8cb6ca3e      131600
# 7629         107      Web  4003dd15cef2c8928c78d150937d03c8      131600
# 9943         107      Web  43247ed8510ec17f76017cf5bdfc268d       42960
# 6565         107      Web  48ff1d45ffaf8542809b6d1b21011348       15920
# 10026        107      Web  4b01106982ce76a475b30b68b0145a39       15920
# 6825         nan      NaN  51746470fedff498563a90d325455ae9       15920
# 8468         107      Web  569c27d726d89288bfd9cfd9384dfd30      131600
# 5249          16      Web  5bcd8a6c5a4e156148048d685d14ee69       15920
# 8742         107      Web  5e06134985c83e0b6a673dd83f3e1fa9       15920
# 5066   107.0.0.0      Web  60533be904f55092f1d6577ff40afb52      131600
# 8159         107      Web  6747ec959ba6dd321c6b3408670b7903       15920
# 6364         106      Web  798a876cf114419feac2137bfbbb7f61       15920
# 10247         16      Web  7a30f31f51cafadfa80b836a4bbc2eb2      131600
# 5213          90      Web  801fb0fb9788e575ed7e4cae4bf3fec6       15920
# 4585         104      Web  805ad3945616300f4fdfa1e12f02ad6a       15920
# 7762         107      Web  868b776c8d1d3aeb631e4ea099253518       15920
# 9284   107.0.0.0      Web  961a2a42932d76d9a50460e9fe4e68e7       15920
# 8630         107      Web  97e533f41515fc2e09a0907c25fb503c       15920
# 8823         107      Web  9f4bf32dad209b761f0997b5756a5e58      131600
# 7437         107      Web  adbd0538928a96e1dbca67e913050709       15920
# 3603   107.0.0.0      Web  ae66280e5e1a08fd53ea3b5090b0ac5b       15920
# 6977         107      Web  af7691a349e1a15cb685508f87f7a7b0       15920
# 6374         107      Web  b5a6052b41664c26ac40284271fb4df9       15920
# 7982         107      Web  b802d2b54e0a52a26706279075a53035       15920
# 8847   103.0.0.0      Web  ba62572dfde92750cd89365dcebe5c7c       15920
# 10283        107      Web  c3a77fc697fb999c37f084513072112b       15920
# 9513         107      Web  cbdbe9f66e2cd6cb1af1834c20cc1f8d       15920
# 4168         107      Web  cdf55bf68cce297c5691441ca324e297      131600
# 9373          16      Web  d0aec84a6dd8f467892f85264dd842d9       15920
# 9819        16.1      Web  d3b275a3cc4b400f32b502c502ec1357      131600
# 6201   107.0.0.0      Web  dec495819245772bca46774e09a7e8e1       15920
# 8236         107      Web  def9369ecc49594167a2e86dcaaaa4a7       15920
# 7601         107      Web  e9a61830c04d8104c516a010274fd1b3      131600
# 10060         15      Web  ebef7774fdf54d8c8dae3538efcf4c2b       15920
# 6754         107      Web  edccf32df27d89255c8207fe870f50fa       15920
# 5738       107.0      Web  f1b88c0b53f90a53572864671bfc191b       15920
# 6535   107.0.0.0      Web  f2dcad59c4fded2b39da5990a82c8bf2      131600
# 6866         106      Web  f36b8aeb1f9f2b8876a26af3c0514368       15920
# 7815         107      Web  f78a387c263597615e7c6f56fcb96225       15920
# 5441   107.0.0.0      Web  f81309195a86efef36bfb00e300fbe65       15920
# 10014       15.6      Web  fd8b29e3ae8720d42479d2b950c64ffd       15920
# 9282         107      Web  fdd65930c3cb37b64725377df0a7b380       15920
#
#        paid_amount  coupon_discount_amount pg_type
# 4916         42960                       0     NaN
# 8476         15920                       0     NaN
# 6836        131600                       0     NaN
# 5186         15920                       0     NaN
# 8995         15920                       0     NaN
# 5005         15920                       0     NaN
# 5339         15920                       0     NaN
# 8474         15920                       0     NaN
# 9309         15920                       0     NaN
# 5194         78960                   52640     NaN
# 9371         42960                       0     NaN
# 3704         15920                       0     NaN
# 5069         15920                       0     NaN
# 6013        131600                       0     NaN
# 6302        131600                       0     NaN
# 7629        105280                   26320     NaN
# 9943         42960                       0     NaN
# 6565         15920                       0     NaN
# 10026        15920                       0     NaN
# 6825         15920                       0     NaN
# 8468        131600                       0     NaN
# 5249         15920                       0     NaN
# 8742         15920                       0     NaN
# 5066        131600                       0     NaN
# 8159         15920                       0     NaN
# 6364         15920                       0     NaN
# 10247       131600                       0     NaN
# 5213         15920                       0     NaN
# 4585         15920                       0     NaN
# 7762         15920                       0     NaN
# 9284         15920                       0     NaN
# 8630         15920                       0     NaN
# 8823        131600                       0     NaN
# 7437         15920                       0     NaN
# 3603         15920                       0     NaN
# 6977         15920                       0     NaN
# 6374         15920                       0     NaN
# 7982         15920                       0     NaN
# 8847         15920                       0     NaN
# 10283        15920                       0     NaN
# 9513         15920                       0     NaN
# 4168        131600                       0     NaN
# 9373         15920                       0     NaN
# 9819        131600                       0     NaN
# 6201          7960                    7960     NaN
# 8236         15920                       0     NaN
# 7601        131600                       0     NaN
# 10060        15920                       0     NaN
# 6754         15920                       0     NaN
# 5738         15920                       0     NaN
# 6535        131600                       0     NaN
# 6866         15920                       0     NaN
# 7815         12736                    3184     NaN
# 5441         15920                       0     NaN
# 10014        15920                       0     NaN
# 9282         15920                       0     NaN

# %%
# pareto
for col in df.columns:
    # pass through common columns
    if col in common_cols: continue
    
    # display
    print(f"\n\n{col}")
    pareto(df, col)
# Out:
# plan_price
# total plan_price : 12
#    plan_price  count  percentage  cum_percentage
# 0       15920   7704       53.92           53.92
# 1      131600   1892       13.24           67.16
# 2       79200   1217        8.52           75.67
# 3       42960   1130        7.91           83.58
# 4       95520    870        6.09           89.67
#    plan_price  count  percentage  cum_percentage
# 0       15920   7704       53.92           53.92
# over 50% : 8.33%
#    plan_price  count  percentage  cum_percentage
# 3       42960   1130        7.91           83.58
# over 80% : 33.33%
#    plan_price  count  percentage  cum_percentage
# 6       95200    346        2.42           96.03
# over 95% : 58.33%
#
#
# paid_amount
# total paid_amount : 41
#    paid_amount  count  percentage  cum_percentage
# 0        15920   5735       40.14           40.14
# 1       131600   1340        9.38           49.51
# 2        79200   1217        8.52           58.03
# 3        95520    853        5.97           64.00
# 4         3960    793        5.55           69.55
#    paid_amount  count  percentage  cum_percentage
# 2        79200   1217        8.52           58.03
# over 50% : 7.32%
#    paid_amount  count  percentage  cum_percentage
# 7        83200    565        3.95           83.66
# over 80% : 19.51%
#     paid_amount  count  percentage  cum_percentage
# 13        91200    221        1.55           95.36
# over 95% : 34.15%
#
#
# coupon_discount_amount
# total coupon_discount_amount : 33
#    coupon_discount_amount  count  percentage  cum_percentage
# 0                       0  11364       79.53           79.53
# 1                   11960    793        5.55           85.08
# 2                    2388    706        4.94           90.02
# 3                   19740    295        2.06           92.08
# 4                    6444    252        1.76           93.85
#    coupon_discount_amount  count  percentage  cum_percentage
# 0                       0  11364       79.53           79.53
# over 50% : 3.03%
#    coupon_discount_amount  count  percentage  cum_percentage
# 1                   11960    793        5.55           85.08
# over 80% : 6.06%
#    coupon_discount_amount  count  percentage  cum_percentage
# 5                    1592    217        1.52           95.37
# over 95% : 18.18%
#
#
# pg_type
# total pg_type : 2
#   pg_type  count  percentage  cum_percentage
# 0       A   1029       62.67           62.67
# 1       B    613       37.33          100.00
#   pg_type  count  percentage  cum_percentage
# 0       A   1029       62.67           62.67
# over 50% : 50.0%
#   pg_type  count  percentage  cum_percentage
# 1       B    613       37.33           100.0
# over 80% : 100.0%
#   pg_type  count  percentage  cum_percentage
# 1       B    613       37.33           100.0
# over 95% : 100.0%

# %% [markdown]
# #### ======== pre-defined and database info ========

# %%
temp = df.groupby('user_id').size()
over1_first_subscript_user = list(temp[temp > 1].index)
over1_first_subscript_user[:5]
# Out:
# ['018e9f53c73beed1d161a392126d513b',
#  '01ee9c8e8858d201d0ae72cc2757546c',
#  '02a857284f291785a949fbd7ed7d6e91',
#  '046469242e1de011419057a9511925c3',
#  '04e3ed921de9a3cb187256ece5cf81bc']

# %% [markdown]
# #### results [6] : complete.subscription.csv
# \
# core dropna : 14289
# \
# drop duplicate : 2 \
# 'user_id' - max conut : 8 \
# over 1 : 2.51% \
# 'user_id', 'client_event_time' - unique \
# \
# too close log : 56, 0.39% \
# \
# pareto : \
# \
# total plan_price : 12 \
# \
# over 50% : 8.33% \
# over 80% : 33.33% \
# over 95% : 58.33% \
# \
# total paid_amount : 41 \
# \
# over 50% : 7.32% \
# over 80% : 19.51% \
# over 95% : 34.15% \
# \
# total paid_amount : 33 \
# \
# over 50% : 3.03% \
# over 80% : 6.06% \
# over 95% : 18.18% \
# \
# total pg_type : 2

# %% [markdown]
# #### [7] : end.content.csv
# - 설명 : 콘텐츠 시청 완료
# - 트리거 : 콘텐츠 내 모든 레슨를 시청하면 해당 테이블에 로그가 쌓임

# %%
# df
file_no = 7
df = dfs[file_no].copy()
print(filelist[file_no])
# Out:
# end.content.csv

# %%
#
display(df.info())
display(df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120582 entries, 0 to 120581
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   city               116280 non-null  object
#  1   client_event_time  120582 non-null  datetime64[ns]
#  2   country            117182 non-null  object
#  3   device_family      119391 non-null  object
#  4   device_type        118866 non-null  object
#  5   event_type         120582 non-null  object
#  6   language           119392 non-null  object
#  7   os_name            119387 non-null  object
#  8   os_version         120582 non-null  object
#  9   platform           119392 non-null  object
#  10  user_id            120582 non-null  object
#  11  content_id         120582 non-null  object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 11.0+ MB
# None
#           city       client_event_time      country device_family device_type  \
# 0     Yokohama 2023-04-10 14:02:10.600        Japan       Windows     Windows
# 1        Seoul 2023-04-10 14:21:26.466  South Korea       Windows     Windows
# 2  Seongbuk-gu 2023-04-10 14:37:04.440  South Korea       Windows     Windows
# 3       Seo-gu 2023-04-10 14:37:19.909  South Korea       Windows     Windows
# 4       Seo-gu 2023-04-10 14:08:58.968  South Korea       Windows     Windows
#
#     event_type  language os_name os_version platform  \
# 0  end.content  Japanese  Chrome  111.0.0.0      Web
# 1  end.content    Korean  Chrome  111.0.0.0      Web
# 2  end.content    Korean  Chrome  111.0.0.0      Web
# 3  end.content    Korean  Chrome  111.0.0.0      Web
# 4  end.content    Korean  Chrome  112.0.0.0      Web
#
#                             user_id                        content_id
# 0  3fd801c6192296cf7b85efc01bd547b9  a914987711c7e2db9fd4bff7555ec87c
# 1  85a332649d34bc7b5ebdec7660b1d57d  f64c475280676531a31f2f8e0648599c
# 2  2bf8cb1d9c5d4556f5165c2aaf804f2e  7fef928cdccef0185dfb931ef59b37d7
# 3  831813f54c0d55c17db612f0ea311c93  68a3658f1b936bfff3bd6960cd561b0a
# 4  353528475f2bd85934263421ccd579b3  a1eeebeb6c307641b75b94a2a1d5b9aa

# %%
# dropna in core_cols
print('before dropna :', df.shape[0], 'entries')
df = df.dropna(subset=core_cols)
print('after dropna  :', df.shape[0], 'entries')
# Out:
# before dropna : 120582 entries
# after dropna  : 120582 entries

# %%
# too_close_log
check_too_close_log(df)
# Out:
# drop duplicate : 2 \
# 'user_id' - max conut : 127 \
# over 1 : 16.81% \
# 'user_id', 'client_event_time' - max conut : 1 \
#
# 94978     6.102476e+07
# 116551    6.054349e+07
# 83679     6.005366e+07
# Name: client_event_time, dtype: float64
# 70209    0.001
# 75204    0.001
# 31445    0.001
# Name: client_event_time, dtype: float64
#
#
# too close log : 413, 0.34%
#               city       client_event_time      country device_family  \
# 43245     Nowon-gu 2022-05-15 12:03:11.939  South Korea           Mac
# 67652    Seocho-gu 2022-03-18 00:42:50.059  South Korea       Windows
# 45358    Seocho-gu 2022-04-28 06:18:34.883  South Korea       Windows
# 55783    Yongin-si 2022-11-09 01:39:17.312  South Korea           Mac
# 55784    Yongin-si 2022-11-09 01:39:17.388  South Korea           Mac
# ...            ...                     ...          ...           ...
# 54871    Seocho-gu 2022-11-17 02:02:24.843  South Korea           Mac
# 54872    Seocho-gu 2022-11-17 02:02:24.906  South Korea           Mac
# 56212        Seoul 2022-03-11 06:27:26.023  South Korea           Mac
# 77346  Seongbuk-gu 2022-03-10 08:09:40.982  South Korea       Windows
# 80926      Jung-gu 2022-01-17 07:35:55.408  South Korea       Windows
#
#       device_type   event_type language os_name os_version platform  \
# 43245         Mac  end.content   Korean  Chrome         99      Web
# 67652     Windows  end.content   Korean  Chrome         99      Web
# 45358     Windows  end.content   Korean  Chrome        100      Web
# 55783         Mac  end.content   Korean  Chrome        107      Web
# 55784         Mac  end.content   Korean  Chrome        107      Web
# ...           ...          ...      ...     ...        ...      ...
# 54871         Mac  end.content  English  Chrome  107.0.0.0      Web
# 54872         Mac  end.content  English  Chrome  107.0.0.0      Web
# 56212         Mac  end.content   Korean  Chrome         99      Web
# 77346     Windows  end.content   Korean  Chrome         98      Web
# 80926     Windows  end.content   Korean  Chrome         97      Web
#
#                                 user_id                        content_id
# 43245  0e0332c7d1288e85d86ed5138560d0a9  101e1d0dcc38d9c86156f008a145083e
# 67652  1bf81491a4dbfe81c7d9c578bc9b8499  18992b667be06d6f29ba0008f99d9745
# 45358  1bf81491a4dbfe81c7d9c578bc9b8499  f64c475280676531a31f2f8e0648599c
# 55783  1e561fd0e2ad3f7c78c70ce2b39ed005  38df90d4de533d6296b52c6a1d90e26b
# 55784  1e561fd0e2ad3f7c78c70ce2b39ed005  38df90d4de533d6296b52c6a1d90e26b
# ...                                 ...                               ...
# 54871  d5e0de700e4392e27a067986398e1511  f4be1a0fe0e301b03115591777fddf29
# 54872  d5e0de700e4392e27a067986398e1511  f4be1a0fe0e301b03115591777fddf29
# 56212  eff877d600a267464c25a649f2f77dd5  db82104b9c508953b3d00eea82844a48
# 77346  f7a82a367e81adafdf59b9cb66b0a53c  5d922c8a6e9e437e7735aa1376bd79ff
# 80926  f87a3c16eb776294dec7b3820f55a610  d6227ba76134f6cf821bb98b5f235bd0
#
# [413 rows x 12 columns]

# %%
# pareto
for col in df.columns:
    # pass through common columns
    if col in common_cols: continue
    
    # display
    print(f"\n\n{col}")
    pareto(df, col)
# Out:
# content_id
# total content_id : 160
#                          content_id  count  percentage  cum_percentage
# 0  f4be1a0fe0e301b03115591777fddf29  16053       13.31           13.31
# 1  f491517f4737a60d661cd1fcacc702c0   8090        6.71           20.02
# 2  595cb4bbfc83e683b0314ca1312cfbde   6631        5.50           25.52
# 3  61b6463287573f00de13a930805a52d6   6254        5.19           30.71
# 4  68a3658f1b936bfff3bd6960cd561b0a   5505        4.57           35.27
#                          content_id  count  percentage  cum_percentage
# 9  db1819d3a7a4c4d85dccb3b9e982fbcd   3159        2.62           50.48
# over 50% : 6.25%
#                           content_id  count  percentage  cum_percentage
# 31  b8d4ec0133e5ce485055bfd69cd28abd    940        0.78           80.18
# over 80% : 20.0%
#                           content_id  count  percentage  cum_percentage
# 65  7102ec0223c06a3a14a7556274d86b7d    217        0.18           95.13
# over 95% : 41.25%

# %% [markdown]
# #### ======== pre-defined and database info ========

# %%
file_no = 7
df = dfs[file_no].copy()

# simple version of content_end_df
com_content_end_df = df[['user_id', 'client_event_time', 'content_id']]
com_content_end_df
# Out:
#                                  user_id       client_event_time  \
# 0       3fd801c6192296cf7b85efc01bd547b9 2023-04-10 14:02:10.600
# 1       85a332649d34bc7b5ebdec7660b1d57d 2023-04-10 14:21:26.466
# 2       2bf8cb1d9c5d4556f5165c2aaf804f2e 2023-04-10 14:37:04.440
# 3       831813f54c0d55c17db612f0ea311c93 2023-04-10 14:37:19.909
# 4       353528475f2bd85934263421ccd579b3 2023-04-10 14:08:58.968
# ...                                  ...                     ...
# 120577  86453faaa4d0da97c471665e8d35642b 2023-10-10 05:21:55.287
# 120578  a0a63b8416b759f2524918094a04d1bf 2023-10-10 05:52:23.524
# 120579  e209e09abc061bd69f3116ff23dcb56b 2023-10-10 05:43:45.139
# 120580  e962f191e86d935bc3cf7a566156a11a 2023-10-10 05:13:17.274
# 120581  465eb0e5c339bcc42ec3f4f14c4d00b0 2023-10-10 05:22:54.927
#
#                               content_id
# 0       a914987711c7e2db9fd4bff7555ec87c
# 1       f64c475280676531a31f2f8e0648599c
# 2       7fef928cdccef0185dfb931ef59b37d7
# 3       68a3658f1b936bfff3bd6960cd561b0a
# 4       a1eeebeb6c307641b75b94a2a1d5b9aa
# ...                                  ...
# 120577  710ffb5be9f89772b7baa9f62c9c8805
# 120578  101e1d0dcc38d9c86156f008a145083e
# 120579  f4be1a0fe0e301b03115591777fddf29
# 120580  61b6463287573f00de13a930805a52d6
# 120581  f4be1a0fe0e301b03115591777fddf29
#
# [120582 rows x 3 columns]

# %% [markdown]
# #### results [7] : end.content.csv
# \
# core dropna : 120582
# \
# drop duplicate : 2 \
# 'user_id' - max conut : 127 \
# over 1 : 16.81% \
# 'user_id', 'client_event_time' - unique \
# \
# too close log : 413, 0.34% \
# \
# pareto : \
# \
# total content_id : 160 \
# \
# over 50% : 6.25% \
# over 80% : 20.0% \
# over 95% : 41.25%

# %% [markdown]
# #### [8] : enter.content_page.csv
# - 설명 : 콘텐츠 개별 페이지 진입
# - 트리거 :

# %%
# df
file_no = 8
df = dfs[file_no].copy()
print(filelist[file_no])
# Out:
# enter.content_page.csv

# %%
#
display(df.info())
display(df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1914257 entries, 0 to 1914256
# Data columns (total 12 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   city               object
#  1   client_event_time  datetime64[ns]
#  2   country            object
#  3   device_family      object
#  4   device_type        object
#  5   event_type         object
#  6   language           object
#  7   os_name            object
#  8   os_version         object
#  9   platform           object
#  10  user_id            object
#  11  content_id         object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 175.3+ MB
# None
#           city       client_event_time      country        device_family  \
# 0        Seoul 2023-04-05 21:40:35.740  South Korea         Apple iPhone
# 1  Hwaseong-si 2023-04-05 21:01:59.950  South Korea  Samsung Galaxy Note
# 2      Daejeon 2023-04-05 21:13:12.038  South Korea              Windows
# 3      Daejeon 2023-04-05 21:14:25.355  South Korea              Windows
# 4        Seoul 2023-04-05 21:44:23.759  South Korea        Samsung Phone
#
#                  device_type          event_type language          os_name  \
# 0               Apple iPhone  enter.content_page   Korean           Chrome
# 1  Samsung Galaxy Note10+ 5G  enter.content_page   Korean           Chrome
# 2                    Windows  enter.content_page   Korean             Edge
# 3                    Windows  enter.content_page   Korean             Edge
# 4   Samsung Galaxy S20 FE 5G  enter.content_page   Korean  Samsung Browser
#
#        os_version platform                           user_id  \
# 0  108.0.5359.112      Web  d57aba7b4527e71b96135deaaec57def
# 1       111.0.0.0      Web                               NaN
# 2   111.0.1661.62      Web  41362ad5ebcade2bb1b78344a53e7ccf
# 3   111.0.1661.62      Web  41362ad5ebcade2bb1b78344a53e7ccf
# 4            14.2      Web                               NaN
#
#                          content_id
# 0  220ce7873b8895d0c81c37600b5bd1e7
# 1  ecde9a1b01763f791c3a185d53b5f394
# 2  b8d4ec0133e5ce485055bfd69cd28abd
# 3  445fac33232adcb3d1cdab7d8a579430
# 4  7cebec6e79cc981dbf421c5ec2aedd9d

# %%
df.isna().sum()
# Out:
# city                  30757
# client_event_time         0
# country                7570
# device_family           639
# device_type           23651
# event_type                0
# language                  0
# os_name                 149
# os_version                0
# platform                  0
# user_id              465168
# content_id                0
# dtype: int64

# %%
# dropna in core_cols
print('before dropna :', df.shape[0], 'entries')
non_id_df = df[df['user_id'].isnull()]
df = df.dropna(subset=core_cols)
print('after dropna  :', df.shape[0], 'entries')
# Out:
# before dropna : 1914257 entries
# after dropna  : 1449089 entries

# %%
# too_close_log
check_too_close_log(df)
# Out:
# drop duplicate : 55 \
# 'user_id' - max conut : 29654 \
# over 1 : 3.67% \
# 'user_id', 'client_event_time' - max conut : 3 \
#               city       client_event_time      country         device_family  \
# 143597         NaN 2023-03-17 00:14:20.051  South Korea  Samsung Galaxy Phone
# 377583       Seoul 2023-03-17 00:14:20.051  South Korea  Samsung Galaxy Phone
# 550854        Osan 2022-03-22 10:26:48.450  South Korea                 Linux
# 1103292      Seoul 2022-03-22 10:26:48.450  South Korea                 Linux
# 1276544  Songpa-gu 2022-03-22 10:26:48.450  South Korea                 Linux
# 550855        Osan 2022-03-22 10:28:05.631  South Korea                 Linux
# 1103293      Seoul 2022-03-22 10:28:05.631  South Korea                 Linux
# 1276545  Songpa-gu 2022-03-22 10:28:05.631  South Korea                 Linux
# 550856        Osan 2022-03-22 10:32:44.294  South Korea                 Linux
# 1103294      Seoul 2022-03-22 10:32:44.294  South Korea                 Linux
#
#                        device_type          event_type language  \
# 143597   Samsung Galaxy Z Fold2 5G  enter.content_page   Korean
# 377583   Samsung Galaxy Z Fold2 5G  enter.content_page   Korean
# 550854                       Linux  enter.content_page   Korean
# 1103292                      Linux  enter.content_page   Korean
# 1276544                      Linux  enter.content_page   Korean
# 550855                       Linux  enter.content_page   Korean
# 1103293                      Linux  enter.content_page   Korean
# 1276545                      Linux  enter.content_page   Korean
# 550856                       Linux  enter.content_page   Korean
# 1103294                      Linux  enter.content_page   Korean
#
#                  os_name os_version platform  \
# 143597   Samsung Browser       19.0      Web
# 377583   Samsung Browser       19.0      Web
# 550854   Samsung Browser         16      Web
# 1103292  Samsung Browser         16      Web
# 1276544  Samsung Browser         16      Web
# 550855   Samsung Browser         16      Web
# 1103293  Samsung Browser         16      Web
# 1276545  Samsung Browser         16      Web
# 550856   Samsung Browser         16      Web
# 1103294  Samsung Browser         16      Web
#
#                                   user_id                        content_id
# 143597   06d97f3d72f2e0162caf0ee95eb3ddf0  8a72eed73d3f9d3ab1771548070e7338
# 377583   06d97f3d72f2e0162caf0ee95eb3ddf0  8a72eed73d3f9d3ab1771548070e7338
# 550854   0f0ca10ec2fb620a371ba3530446bcdc  db1819d3a7a4c4d85dccb3b9e982fbcd
# 1103292  0f0ca10ec2fb620a371ba3530446bcdc  db1819d3a7a4c4d85dccb3b9e982fbcd
# 1276544  0f0ca10ec2fb620a371ba3530446bcdc  db1819d3a7a4c4d85dccb3b9e982fbcd
# 550855   0f0ca10ec2fb620a371ba3530446bcdc  db1819d3a7a4c4d85dccb3b9e982fbcd
# 1103293  0f0ca10ec2fb620a371ba3530446bcdc  db1819d3a7a4c4d85dccb3b9e982fbcd
# 1276545  0f0ca10ec2fb620a371ba3530446bcdc  db1819d3a7a4c4d85dccb3b9e982fbcd
# 550856   0f0ca10ec2fb620a371ba3530446bcdc  db1819d3a7a4c4d85dccb3b9e982fbcd
# 1103294  0f0ca10ec2fb620a371ba3530446bcdc  db1819d3a7a4c4d85dccb3b9e982fbcd
# 1559244    6.225764e+07
# 1724516    6.163596e+07
# 1622275    6.151296e+07
# Name: client_event_time, dtype: float64
# 1316312    0.0
# 1103296    0.0
# 1300448    0.0
# Name: client_event_time, dtype: float64
#
#
# too close log : 6526, 0.45%
#                     city       client_event_time      country device_family  \
# 65709         Yuseong-gu 2023-06-08 08:38:32.733  South Korea       Windows
# 1517264            Iksan 2023-10-24 14:46:24.767  South Korea       Windows
# 1895756          Daejeon 2023-11-02 15:37:56.379  South Korea       Windows
# 1734419  Yeongdeungpo-gu 2023-11-02 12:57:56.455  South Korea       Windows
# 1897686        Songpa-gu 2023-10-10 12:47:45.591  South Korea       Windows
# ...                  ...                     ...          ...           ...
# 1772281  Yeongdeungpo-gu 2023-11-01 17:10:33.808  South Korea       Windows
# 843817           Saha-gu 2022-07-20 12:16:56.025  South Korea       Windows
# 1605170           Buk-gu 2023-08-08 04:28:55.950  South Korea       Windows
# 1535061           Buk-gu 2023-11-06 07:15:35.330  South Korea       Windows
# 1593618           Buk-gu 2023-11-10 07:35:49.761  South Korea       Windows
#
#         device_type          event_type language os_name     os_version  \
# 65709       Windows  enter.content_page   Korean  Chrome      114.0.0.0
# 1517264     Windows  enter.content_page   Korean    Edge  118.0.2088.61
# 1895756     Windows  enter.content_page   Korean  Chrome      118.0.0.0
# 1734419     Windows  enter.content_page   Korean  Chrome      118.0.0.0
# 1897686     Windows  enter.content_page   Korean  Chrome      117.0.0.0
# ...             ...                 ...      ...     ...            ...
# 1772281     Windows  enter.content_page   Korean  Chrome      118.0.0.0
# 843817      Windows  enter.content_page   Korean    Edge            103
# 1605170     Windows  enter.content_page   Korean  Chrome      115.0.0.0
# 1535061     Windows  enter.content_page   Korean  Chrome      119.0.0.0
# 1593618     Windows  enter.content_page   Korean  Chrome      119.0.0.0
#
#         platform                           user_id  \
# 65709        Web  006007f28d3675663793a887d8eb9b40
# 1517264      Web  007f9ad21d82744c2890a8a8abf17ef2
# 1895756      Web  008c9caf457e064fc2987aea637f34a6
# 1734419      Web  009e388a4a3b03d84d046c68da496bb1
# 1897686      Web  00a28b83758aaae5a0c1733e37096e3d
# ...          ...                               ...
# 1772281      Web  ff9bb243eff83d84e2cb289ff629aba8
# 843817       Web  ffe2fc3d0ca5c4d725dbe8d1d4b343ce
# 1605170      Web  fffe529de03d6187ef7ed765650c8d2b
# 1535061      Web  fffe529de03d6187ef7ed765650c8d2b
# 1593618      Web  fffe529de03d6187ef7ed765650c8d2b
#
#                                content_id
# 65709    595cb4bbfc83e683b0314ca1312cfbde
# 1517264  f491517f4737a60d661cd1fcacc702c0
# 1895756  3ca120746c79812b35a345a8a509b5ba
# 1734419  db1819d3a7a4c4d85dccb3b9e982fbcd
# 1897686  8a72eed73d3f9d3ab1771548070e7338
# ...                                   ...
# 1772281  db1819d3a7a4c4d85dccb3b9e982fbcd
# 843817   18992b667be06d6f29ba0008f99d9745
# 1605170  c269eb6df3a374b464f7c18f12fa398f
# 1535061  f491517f4737a60d661cd1fcacc702c0
# 1593618  289ae01387d36327c04b176c6d62a626
#
# [6526 rows x 12 columns]

# %%
# pareto
for col in df.columns:
    # pass through common columns
    if col in common_cols: continue
    
    # display
    print(f"\n\n{col}")
    pareto(df, col)
# Out:
# content_id
# total content_id : 207
#                          content_id   count  percentage  cum_percentage
# 0  f4be1a0fe0e301b03115591777fddf29  119337        8.24            8.24
# 1  f491517f4737a60d661cd1fcacc702c0   90779        6.26           14.50
# 2  595cb4bbfc83e683b0314ca1312cfbde   86101        5.94           20.44
# 3  61b6463287573f00de13a930805a52d6   54772        3.78           24.22
# 4  b314d5aba64a0aab40602cb72a4a1504   51559        3.56           27.78
#                           content_id  count  percentage  cum_percentage
# 14  f64c475280676531a31f2f8e0648599c  24790        1.71           50.61
# over 50% : 7.25%
#                           content_id  count  percentage  cum_percentage
# 41  f351e92bba7aadae94d04c85c3fb1834   9962        0.69            80.4
# over 80% : 20.29%
#                           content_id  count  percentage  cum_percentage
# 74  3b883765ba3731d00686a78af35a6dbb   3056        0.21           95.05
# over 95% : 36.23%

# %%
# too close log in non_id_df
check_too_close_log(non_id_df)
# Out:
# drop duplicate : 123 \
# 'user_id' - max conut : nan \
# over 1 : 0.0% \
# 'user_id', 'client_event_time' - max conut : nan \
#
# Series([], Name: client_event_time, dtype: float64)
# Series([], Name: client_event_time, dtype: float64)

# %%
# pareto with non_id_df
for col in non_id_df.columns:
    # pass through common columns
    if col in common_cols: continue
    
    # display
    print(f"\n\n{col}")
    pareto(non_id_df, col)
# Out:
# content_id
# total content_id : 174
#                          content_id   count  percentage  cum_percentage
# 0  61b6463287573f00de13a930805a52d6  131686       28.31           28.31
# 1  f4be1a0fe0e301b03115591777fddf29   41240        8.87           37.17
# 2  c269eb6df3a374b464f7c18f12fa398f   25381        5.46           42.63
# 3  7cebec6e79cc981dbf421c5ec2aedd9d   18972        4.08           46.71
# 4  68a3658f1b936bfff3bd6960cd561b0a   13518        2.91           49.62
#                          content_id  count  percentage  cum_percentage
# 5  f491517f4737a60d661cd1fcacc702c0  10841        2.33           51.95
# over 50% : 3.45%
#                           content_id  count  percentage  cum_percentage
# 30  db43a841c994231e2795d4df8931af50   2911        0.63           80.32
# over 80% : 17.82%
#                           content_id  count  percentage  cum_percentage
# 68  03b4a290c08f7fa83933827a994f2e61   1071        0.23           95.19
# over 95% : 39.66%

# %% [markdown]
# #### ======== pre-defined and database info ========

# %% [markdown]
# #### results [8] : enter.content_page.csv
# \
# core dropna : 1914257 -> 1449089
# \
# drop duplicate : 55 \
# 'user_id' - max conut : 29654 \
# over 1 : 3.67% \
# 'user_id', 'client_event_time' - max conut : 3 \
# \
# too close log : 6526, 0.45% \
# \
# pareto : \
# \
# total content_id : 207 \
# \
# over 50% : 7.25% \
# over 80% : 20.29% \
# over 95% : 36.23% \
# \
# non_id pareto : \
# \
# total content_id : 174 \
# \
# over 50% : 3.45% \
# over 80% : 17.82% \
# over 95% : 39.66%

# %% [markdown]
# #### [9] : enter.lesson_page-002.csv
# - 설명 : 레슨 시작
# - 콘텐츠는 여러 개의 레슨으로 구성되어 있습니다.

# %%
# df
file_no = 9
df = dfs[file_no].copy()
print(filelist[file_no])
# Out:
# enter.lesson_page-002.csv

# %%
#
display(df.info())
display(df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3642014 entries, 0 to 3642013
# Data columns (total 15 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   city               object
#  1   client_event_time  datetime64[ns]
#  2   country            object
#  3   device_family      object
#  4   device_type        object
#  5   event_type         object
#  6   language           object
#  7   os_name            object
#  8   os_version         object
#  9   platform           object
#  10  user_id            object
#  11  content_id         object
#  12  is_trial           object
#  13  lesson_id          object
#  14  is_free_trial      object
# dtypes: datetime64[ns](1), object(14)
# memory usage: 416.8+ MB
# None
#           city       client_event_time      country device_family device_type  \
# 0    Namyangju 2022-02-04 12:31:30.518  South Korea       Windows     Windows
# 1      Cheonan 2022-09-07 14:31:25.240  South Korea       Windows     Windows
# 2      Jung-gu 2023-02-28 14:41:58.094  South Korea       Windows     Windows
# 3  Jungnang-gu 2023-05-23 07:31:00.659  South Korea       Windows     Windows
# 4        Seoul 2023-08-28 05:43:44.680  South Korea           Mac         Mac
#
#           event_type language os_name     os_version platform  \
# 0  enter.lesson_page   Korean  Chrome             98      Web
# 1  enter.lesson_page   Korean  Chrome            104      Web
# 2  enter.lesson_page   Korean    Edge  110.0.1587.57      Web
# 3  enter.lesson_page   Korean  Chrome      113.0.0.0      Web
# 4  enter.lesson_page   Korean  Safari           16.1      Web
#
#                             user_id                        content_id  \
# 0  12f04ddae2401065a1d459dda334bda4  68a3658f1b936bfff3bd6960cd561b0a
# 1  f7fdfac59d75566dfcab079dff3d3e86  38df90d4de533d6296b52c6a1d90e26b
# 2  634b3a67436012dfa1a4163b72a8a77e  f491517f4737a60d661cd1fcacc702c0
# 3  1d5cad893a2cd87d368338a0756b26bb  68a3658f1b936bfff3bd6960cd561b0a
# 4  6db0726d3aabd02543fa46b7a3f7f950  621c7ad99b17d2d16832b618d47aea7e
#
#   is_trial                         lesson_id is_free_trial
# 0      NaN  bf62c1501eafeb537cee65fae75a416f           NaN
# 1      NaN  83a15fa3e7695142a84dd41283650810         False
# 2    False  e941d4d5f1b575fd1467f2e0ea97bafc           NaN
# 3    False  ba37fc9c4e1c1d65c93e2b28017f3f37           NaN
# 4    False  8ea17ed7e2e036cc7efc10eb7d7ba7a7           NaN

# %%
# check null
df_len = df.shape[0]
result = df.isna().sum()
(result / df_len * 100).round(2)
# Out:
# city                  2.58
# client_event_time     0.00
# country               1.72
# device_family         0.03
# device_type           0.67
# event_type            0.00
# language              0.00
# os_name               0.00
# os_version            0.00
# platform              0.00
# user_id               7.31
# content_id            0.00
# is_trial             35.08
# lesson_id             0.00
# is_free_trial        89.40
# dtype: float64

# %%
# dropna in core_cols
print('before dropna :', df.shape[0], 'entries')
non_id_df = df[df['user_id'].isnull()]
df = df.dropna(subset=core_cols)
print('after dropna  :', df.shape[0], 'entries')
# Out:
# before dropna : 3642014 entries
# after dropna  : 3375727 entries

# %%
# too_close_log
check_too_close_log(df)
# Out:
# drop duplicate : 0 \
# 'user_id' - max conut : 6788 \
# over 1 : 1.54% \
# 'user_id', 'client_event_time' - max conut : 2 \
#                city       client_event_time      country device_family  \
# 680147   Gijang-gun 2022-04-10 05:24:24.901  South Korea         Linux
# 3612169   Songpa-gu 2022-04-10 05:24:24.901  South Korea         Linux
# 1806683   Songpa-gu 2022-04-10 05:30:11.188  South Korea         Linux
# 2435052  Gijang-gun 2022-04-10 05:30:11.188  South Korea         Linux
# 1928042   Songpa-gu 2022-04-17 04:34:12.774  South Korea         Linux
# 3515970  Gijang-gun 2022-04-17 04:34:12.774  South Korea         Linux
# 2842924     Mapo-gu 2022-05-06 06:39:02.988  South Korea       Windows
# 3357286       Seoul 2022-05-06 06:39:02.988  South Korea       Windows
# 2469506     Mapo-gu 2022-05-06 06:40:47.799  South Korea       Windows
# 3538334       Seoul 2022-05-06 06:40:47.799  South Korea       Windows
#
#         device_type         event_type language          os_name os_version  \
# 680147        Linux  enter.lesson_page   Korean  Samsung Browser         16
# 3612169       Linux  enter.lesson_page   Korean  Samsung Browser         16
# 1806683       Linux  enter.lesson_page   Korean  Samsung Browser         16
# 2435052       Linux  enter.lesson_page   Korean  Samsung Browser         16
# 1928042       Linux  enter.lesson_page   Korean  Samsung Browser         16
# 3515970       Linux  enter.lesson_page   Korean  Samsung Browser         16
# 2842924     Windows  enter.lesson_page   Korean           Chrome        100
# 3357286     Windows  enter.lesson_page   Korean           Chrome        100
# 2469506     Windows  enter.lesson_page   Korean           Chrome        100
# 3538334     Windows  enter.lesson_page   Korean           Chrome        100
#
#         platform                           user_id  \
# 680147       Web  0f0ca10ec2fb620a371ba3530446bcdc
# 3612169      Web  0f0ca10ec2fb620a371ba3530446bcdc
# 1806683      Web  0f0ca10ec2fb620a371ba3530446bcdc
# 2435052      Web  0f0ca10ec2fb620a371ba3530446bcdc
# 1928042      Web  0f0ca10ec2fb620a371ba3530446bcdc
# 3515970      Web  0f0ca10ec2fb620a371ba3530446bcdc
# 2842924      Web  16e39802400a3a48d7f6761d1a2ba214
# 3357286      Web  16e39802400a3a48d7f6761d1a2ba214
# 2469506      Web  16e39802400a3a48d7f6761d1a2ba214
# 3538334      Web  16e39802400a3a48d7f6761d1a2ba214
#
#                                content_id is_trial  \
# 680147   621c7ad99b17d2d16832b618d47aea7e      NaN
# 3612169  621c7ad99b17d2d16832b618d47aea7e      NaN
# 1806683  db1819d3a7a4c4d85dccb3b9e982fbcd      NaN
# 2435052  db1819d3a7a4c4d85dccb3b9e982fbcd      NaN
# 1928042  db1819d3a7a4c4d85dccb3b9e982fbcd      NaN
# 3515970  db1819d3a7a4c4d85dccb3b9e982fbcd      NaN
# 2842924  68a3658f1b936bfff3bd6960cd561b0a      NaN
# 3357286  68a3658f1b936bfff3bd6960cd561b0a      NaN
# 2469506  68a3658f1b936bfff3bd6960cd561b0a      NaN
# 3538334  68a3658f1b936bfff3bd6960cd561b0a      NaN
#
#                                 lesson_id is_free_trial
# 680147   2540764afd85b1efded64b0e3ef545f5           NaN
# 3612169  2540764afd85b1efded64b0e3ef545f5           NaN
# 1806683  1d8001503573593525c1bb7d4ff1fd14           NaN
# 2435052  1d8001503573593525c1bb7d4ff1fd14           NaN
# 1928042  94d7605167c5e300aa4d6b145fa9ba8a           NaN
# 3515970  94d7605167c5e300aa4d6b145fa9ba8a           NaN
# 2842924  1ec838a253800869b1724bbb1da49376         False
# 3357286  1ec838a253800869b1724bbb1da49376         False
# 2469506  0934eafafaf2aeeaab6d312bca7d7f2a         False
# 3538334  0934eafafaf2aeeaab6d312bca7d7f2a         False
# 3200831    6.245523e+07
# 819137     6.056214e+07
# 2745922    6.037527e+07
# Name: client_event_time, dtype: float64
# 3612169    0.0
# 2392969    0.0
# 456697     0.0
# Name: client_event_time, dtype: float64
#
#
# too close log : 73374, 2.17%
#                   city       client_event_time      country device_family  \
# 3350673  Pyeongtaek-si 2022-12-08 00:27:13.257  South Korea       Windows
# 2238373  Pyeongtaek-si 2022-12-15 13:37:29.411  South Korea       Windows
# 11569    Pyeongtaek-si 2023-02-24 06:42:08.165  South Korea       Windows
# 2845493            NaN 2022-12-13 09:05:32.201          NaN       Windows
# 2513569            NaN 2022-12-14 05:05:59.445          NaN       Windows
# ...                ...                     ...          ...           ...
# 3261861     Suyeong-gu 2023-03-24 05:38:26.813  South Korea       Windows
# 997850      Suyeong-gu 2023-03-24 05:39:20.302  South Korea       Windows
# 176920      Suyeong-gu 2023-03-24 05:39:56.911  South Korea       Windows
# 572262     Busanjin-gu 2023-03-29 14:28:09.648  South Korea       Windows
# 1963087    Busanjin-gu 2023-03-29 14:30:57.055  South Korea       Windows
#
#         device_type         event_type language os_name os_version platform  \
# 3350673     Windows  enter.lesson_page   Korean  Chrome  106.0.0.0      Web
# 2238373     Windows  enter.lesson_page   Korean  Chrome  108.0.0.0      Web
# 11569       Windows  enter.lesson_page   Korean  Chrome  109.0.0.0      Web
# 2845493     Windows  enter.lesson_page   Korean  Chrome  108.0.0.0      Web
# 2513569     Windows  enter.lesson_page   Korean  Chrome  108.0.0.0      Web
# ...             ...                ...      ...     ...        ...      ...
# 3261861     Windows  enter.lesson_page   Korean  Chrome  111.0.0.0      Web
# 997850      Windows  enter.lesson_page   Korean  Chrome  111.0.0.0      Web
# 176920      Windows  enter.lesson_page   Korean  Chrome  111.0.0.0      Web
# 572262      Windows  enter.lesson_page   Korean  Chrome  111.0.0.0      Web
# 1963087     Windows  enter.lesson_page   Korean  Chrome  111.0.0.0      Web
#
#                                   user_id                        content_id  \
# 3350673  0003c0ede663b9e3b55d9dc3f7e8690f  f64c475280676531a31f2f8e0648599c
# 2238373  0003c0ede663b9e3b55d9dc3f7e8690f  f64c475280676531a31f2f8e0648599c
# 11569    0003c0ede663b9e3b55d9dc3f7e8690f  d0bce5e5af242d6d60e16b68b4febf2e
# 2845493  000722d5152d121ef57d8246dff4ac91  f4be1a0fe0e301b03115591777fddf29
# 2513569  000722d5152d121ef57d8246dff4ac91  f491517f4737a60d661cd1fcacc702c0
# ...                                   ...                               ...
# 3261861  fffe529de03d6187ef7ed765650c8d2b  18992b667be06d6f29ba0008f99d9745
# 997850   fffe529de03d6187ef7ed765650c8d2b  18992b667be06d6f29ba0008f99d9745
# 176920   fffe529de03d6187ef7ed765650c8d2b  18992b667be06d6f29ba0008f99d9745
# 572262   fffe529de03d6187ef7ed765650c8d2b  18992b667be06d6f29ba0008f99d9745
# 1963087  fffe529de03d6187ef7ed765650c8d2b  18992b667be06d6f29ba0008f99d9745
#
#         is_trial                         lesson_id is_free_trial
# 3350673      NaN  10309afa1e52015b7cab11a50569ea64           NaN
# 2238373      NaN  c56fc2664d26120115338308af97dd62           NaN
# 11569      False  5d4323b5eeb5422e63b0146289a83b69           NaN
# 2845493      NaN  3022970a4832e8c927847f63c3fad410           NaN
# 2513569      NaN  ad01992e03e1be73ccf9f400ddac598a           NaN
# ...          ...                               ...           ...
# 3261861    False  60401c7af421962a67aeccd6f9ee5d79           NaN
# 997850     False  60401c7af421962a67aeccd6f9ee5d79           NaN
# 176920     False  60401c7af421962a67aeccd6f9ee5d79           NaN
# 572262     False  e0904cb1ba66454e5ba518c7da25a0b2           NaN
# 1963087    False  e0904cb1ba66454e5ba518c7da25a0b2           NaN
#
# [73374 rows x 15 columns]

# %%
# pareto
for col in df.columns:
    # pass through common columns
    if col in common_cols: continue
    
    # display
    print(f"\n\n{col}")
    pareto(df, col)
# Out:
# content_id
# total content_id : 178
#                          content_id   count  percentage  cum_percentage
# 0  f491517f4737a60d661cd1fcacc702c0  309580        9.17            9.17
# 1  f4be1a0fe0e301b03115591777fddf29  200804        5.95           15.12
# 2  c269eb6df3a374b464f7c18f12fa398f  196848        5.83           20.95
# 3  595cb4bbfc83e683b0314ca1312cfbde  177011        5.24           26.19
# 4  db1819d3a7a4c4d85dccb3b9e982fbcd  164253        4.87           31.06
#                           content_id  count  percentage  cum_percentage
# 11  68a3658f1b936bfff3bd6960cd561b0a  84502         2.5           51.59
# over 50% : 6.74%
#                           content_id  count  percentage  cum_percentage
# 30  a1eeebeb6c307641b75b94a2a1d5b9aa  29510        0.87           80.73
# over 80% : 17.42%
#                           content_id  count  percentage  cum_percentage
# 56  5fc64d786416b980cfda86afd69e4516  10732        0.32           95.07
# over 95% : 32.02%
#
#
# is_trial
# total is_trial : 2
#    is_trial    count  percentage  cum_percentage
# 0     False  2087886       99.18           99.18
# 1      True    17320        0.82          100.00
#    is_trial    count  percentage  cum_percentage
# 0     False  2087886       99.18           99.18
# over 50% : 50.0%
#    is_trial    count  percentage  cum_percentage
# 0     False  2087886       99.18           99.18
# over 80% : 50.0%
#    is_trial    count  percentage  cum_percentage
# 0     False  2087886       99.18           99.18
# over 95% : 50.0%
#
#
# lesson_id
# total lesson_id : 5222
#                           lesson_id  count  percentage  cum_percentage
# 0  bfb6543cc0e7fa189f9c9a0e533b0f43  22623        0.67            0.67
# 1  02968d35dacf2041e4067dc87d9798a2  17535        0.52            1.19
# 2  b42c9bb32f5024900cbed7623eecd272  16954        0.50            1.69
# 3  4b6cc370e587d711780ed4591634d443  16009        0.47            2.17
# 4  4b4c27b285ef525c39051ed3ac2bd497  15701        0.47            2.63
#                             lesson_id  count  percentage  cum_percentage
# 374  3f5fdf60166a1adf7832b712d3aee06c   1988        0.06           50.05
# over 50% : 7.18%
#                              lesson_id  count  percentage  cum_percentage
# 1303  153f1d7f5cf27cbbf584b149a0e2f15f    622        0.02           80.02
# over 80% : 24.97%
#                              lesson_id  count  percentage  cum_percentage
# 2569  58fd11323dbb8607e379855d170123ce    226        0.01           95.01
# over 95% : 49.21%
#
#
# is_free_trial
# total is_free_trial : 2
#    is_free_trial   count  percentage  cum_percentage
# 0          False  372027        96.9            96.9
# 1           True   11898         3.1           100.0
#    is_free_trial   count  percentage  cum_percentage
# 0          False  372027        96.9            96.9
# over 50% : 50.0%
#    is_free_trial   count  percentage  cum_percentage
# 0          False  372027        96.9            96.9
# over 80% : 50.0%
#    is_free_trial   count  percentage  cum_percentage
# 0          False  372027        96.9            96.9
# over 95% : 50.0%

# %% [markdown]
# #### ======== pre-defined and database info ========

# %%
df['is_free_trial'].fillna('unknown', inplace=True)
df['is_trial'].fillna('unknown', inplace=True)

df.loc[df['is_free_trial'] == 'unknown', 'is_free_trial'] = 2
df.loc[df['is_free_trial'] == 'True', 'is_free_trial'] = 1
df.loc[df['is_free_trial'] == 'False', 'is_free_trial'] = 0
df.loc[df['is_trial'] == 'unknown', 'is_trial'] = 2
df.loc[df['is_trial'] == 'True', 'is_trial'] = 1
df.loc[df['is_trial'] == 'False', 'is_trial'] = 0

df['is_free_trial'] = df['is_free_trial'].astype(int)
df['is_trial'] = df['is_trial'].astype(int)

com_content_lesson_df = df[['user_id', 'client_event_time', 'content_id', 'lesson_id', 'is_free_trial', 'is_trial']]
com_content_lesson_df.info()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7356\2825950670.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['is_free_trial'].fillna('unknown', inplace=True)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7356\2825950670.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['is_trial'].fillna('unknown', inplace=True)
# <class 'pandas.core.frame.DataFrame'>
# Index: 3375727 entries, 0 to 3642013
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   user_id            object
#  1   client_event_time  datetime64[ns]
#  2   content_id         object
#  3   lesson_id          object
#  4   is_free_trial      int32
#  5   is_trial           int32
# dtypes: datetime64[ns](1), int32(2), object(3)
# memory usage: 154.5+ MB

# %% [markdown]
# #### results [9] : enter.lesson_page-002.csv
# \
# core dropna : 21029707  -> 19491178
# \
# drop duplicate : 621 \
# 'user_id' - max conut : 38951 \
# over 1 : 0.45% \
# 'user_id', 'client_event_time' - max conut : 3 \
# \
# too close log : 2258807, 11.59% \
# \
# pareto : \
# \
# total content_id : 181 \
# \
# over 50% : 6.63% \
# over 80% : 17.13% \
# over 95% : 31.49% \
# \
# total is_trial : 2 \
# \
# False	99.19 \
# True	0.81 \
# \
# total lesson_id : 5477 \
# \
# over 50% : 6.83% \
# over 80% : 23.83% \
# over 95% : 46.96% \
# \
# total is_free_trial : 2 \
# \
# False	96.89 \
# True	3.11 \

# %% [markdown]
# #### [10] : enter.main_page.csv
# - 설명 : 서비스 메인페이지 진입

# %%
# df
file_no = 10
df = dfs[file_no].copy()
print(filelist[file_no])
# Out:
# enter.main_page.csv

# %%
#
display(df.info())
display(df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2133548 entries, 0 to 2133547
# Data columns (total 11 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   city               object
#  1   client_event_time  datetime64[ns]
#  2   country            object
#  3   device_family      object
#  4   device_type        object
#  5   event_type         object
#  6   language           object
#  7   os_name            object
#  8   os_version         object
#  9   platform           object
#  10  user_id            object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 179.1+ MB
# None
#             city       client_event_time      country        device_family  \
# 0    Seongnam-si 2023-04-05 21:55:06.140  South Korea        Samsung Phone
# 1  Dongdaemun-gu 2023-04-05 21:04:28.967  South Korea                  Mac
# 2    Hwaseong-si 2023-04-05 21:01:31.258  South Korea  Samsung Galaxy Note
# 3    Hwaseong-si 2023-04-05 21:02:50.374  South Korea  Samsung Galaxy Note
# 4          Seoul 2023-04-05 21:30:33.727  South Korea        Samsung Phone
#
#                  device_type       event_type language os_name os_version  \
# 0      Samsung Galaxy S21 5G  enter.main_page   Korean   Whale    1.0.0.0
# 1                        Mac  enter.main_page   Korean  Chrome  111.0.0.0
# 2  Samsung Galaxy Note10+ 5G  enter.main_page   Korean  Chrome  111.0.0.0
# 3  Samsung Galaxy Note10+ 5G  enter.main_page   Korean  Chrome  111.0.0.0
# 4      Samsung Galaxy A51 5G  enter.main_page   Korean  Chrome  112.0.0.0
#
#   platform                           user_id
# 0      Web                               NaN
# 1      Web  b2b31f00b82edc6419b25324a7ae41a4
# 2      Web                               NaN
# 3      Web                               NaN
# 4      Web                               NaN

# %%
# dropna in core_cols
print('before dropna :', df.shape[0], 'entries')
non_id_df = df[df['user_id'].isnull()]
df = df.dropna(subset=core_cols)
print('after dropna  :', df.shape[0], 'entries')
# Out:
# before dropna : 2133548 entries
# after dropna  : 522516 entries

# %%
# too_close_log
check_too_close_log(df)
# Out:
# drop duplicate : 255 \
# 'user_id' - max conut : 3808 \
# over 1 : 9.65% \
# 'user_id', 'client_event_time' - max conut : 3 \
#                     city       client_event_time      country  device_family  \
# 1494619       Gangnam-gu 2022-08-16 08:31:53.060  South Korea        Android
# 1587990          Mapo-gu 2022-08-16 08:31:53.060  South Korea        Android
# 604462        Dongjak-gu 2022-06-02 18:50:43.620  South Korea        Android
# 1106767       Gangnam-gu 2022-06-02 18:50:43.620  South Korea        Android
# 648698   Yeongdeungpo-gu 2022-03-28 13:03:51.602  South Korea        Android
# 691356         Seocho-gu 2022-03-28 13:03:51.602  South Korea        Android
# 934291             Suwon 2022-02-24 02:04:12.437  South Korea        Windows
# 1533211          Mapo-gu 2022-02-24 02:04:12.437  South Korea        Windows
# 180239             Seoul 2022-12-14 07:59:45.946  South Korea  Samsung Phone
# 1316996           Sejong 2022-12-14 07:59:45.946  South Korea  Samsung Phone
#
#                       device_type       event_type language         os_name  \
# 1494619                   Android  enter.main_page   Korean  Chrome WebView
# 1587990                   Android  enter.main_page   Korean  Chrome WebView
# 604462                    Android  enter.main_page   Korean   Chrome Mobile
# 1106767                   Android  enter.main_page   Korean   Chrome Mobile
# 648698                    Android  enter.main_page   Korean   Chrome Mobile
# 691356                    Android  enter.main_page   Korean   Chrome Mobile
# 934291                    Windows  enter.main_page   Korean          Chrome
# 1533211                   Windows  enter.main_page   Korean          Chrome
# 180239   Samsung Galaxy Note20 5G  enter.main_page   Korean          Chrome
# 1316996  Samsung Galaxy Note20 5G  enter.main_page   Korean          Chrome
#
#         os_version platform                           user_id
# 1494619         90      Web  010a4a8efd5fd2528719b5bd8098286a
# 1587990         90      Web  010a4a8efd5fd2528719b5bd8098286a
# 604462         101      Web  052b0005b4863a3bcfd479cad3fd921d
# 1106767        101      Web  052b0005b4863a3bcfd479cad3fd921d
# 648698          99      Web  07e422686e02a62ffc6cf06f8454e1b2
# 691356          99      Web  07e422686e02a62ffc6cf06f8454e1b2
# 934291          98      Web  09501b14e654c6c1f6257ab777907ab9
# 1533211         98      Web  09501b14e654c6c1f6257ab777907ab9
# 180239   108.0.0.0      Web  09aed0bc261bc42c9a95c4f566b6bc03
# 1316996  108.0.0.0      Web  09aed0bc261bc42c9a95c4f566b6bc03
# 1999661    5.853050e+07
# 1911373    5.835063e+07
# 1963371    5.834320e+07
# Name: client_event_time, dtype: float64
# 1267345    0.0
# 919450     0.0
# 939044     0.0
# Name: client_event_time, dtype: float64
#
#
# too close log : 3197, 0.61%
#                city       client_event_time        country device_family  \
# 1218101       Seoul 2022-01-16 10:49:31.490    South Korea       Windows
# 787469      Cheonan 2022-07-26 05:06:28.634    South Korea       Windows
# 1518260       Seoul 2022-08-22 18:25:27.706    South Korea  Apple iPhone
# 1333492  Dongjak-gu 2022-11-10 09:10:18.935    South Korea           Mac
# 1333496  Dongjak-gu 2022-11-10 09:10:40.316    South Korea           Mac
# ...             ...                     ...            ...           ...
# 1494746     Incheon 2022-11-11 10:25:40.384    South Korea           Mac
# 740178    Rockville 2022-11-12 05:43:28.229  United States       Windows
# 1226496       Seoul 2022-12-04 15:52:58.692    South Korea  Apple iPhone
# 1169047  Gangnam-gu 2022-05-23 00:30:15.773    South Korea       Windows
# 1223550       Seoul 2022-11-10 22:49:35.737    South Korea       Android
#
#           device_type       event_type language         os_name  \
# 1218101       Windows  enter.main_page   Korean            Edge
# 787469        Windows  enter.main_page   Korean          Chrome
# 1518260  Apple iPhone  enter.main_page   Korean   Mobile Safari
# 1333492           Mac  enter.main_page   Korean          Chrome
# 1333496           Mac  enter.main_page   Korean          Chrome
# ...               ...              ...      ...             ...
# 1494746           Mac  enter.main_page   Korean          Chrome
# 740178        Windows  enter.main_page  English          Chrome
# 1226496  Apple iPhone  enter.main_page   Korean          Chrome
# 1169047       Windows  enter.main_page  English          Chrome
# 1223550       Android  enter.main_page   Korean  Chrome WebView
#
#              os_version platform                           user_id
# 1218101              97      Web  0028f62af7782380e55d2e86d73f25a5
# 787469              103      Web  007014899afb38703146a5678da74814
# 1518260              15      Web  00baaf03ba9a095f009e107d01b7173c
# 1333492             105      Web  00f3b2f8e51cbf56d745604940c1da94
# 1333496             105      Web  00f3b2f8e51cbf56d745604940c1da94
# ...                 ...      ...                               ...
# 1494746             107      Web  ff56eed2eee3e18ef7973a69015ae6ae
# 740178              107      Web  ff917e8b6bcf53a48bd1b1efae5d00f5
# 1226496  107.0.5304.101      Web  ffdfbf03c274a93e5378813532ce3327
# 1169047             101      Web  ffe4420b9073409b447933f036fbfe51
# 1223550             105      Web  fff3e9ffd58cda1d8068d1dab141760a
#
# [3197 rows x 11 columns]

# %%
# pareto
for col in df.columns:
    # pass through common columns
    if col in common_cols: continue
    
    # display
    print(f"\n\n{col}")
    pareto(df, col)

# %%
# check null
df_len = df.shape[0]
result = df.isna().sum()
(result / df_len * 100).round(2)
# Out:
# city                 1.00
# client_event_time    0.00
# country              0.07
# device_family        0.00
# device_type          0.27
# event_type           0.00
# language             0.00
# os_name              0.00
# os_version           0.00
# platform             0.00
# user_id              0.00
# dtype: float64

# %%
# check null with non_id_df
df_len = non_id_df.shape[0]
result = non_id_df.isna().sum()
(result / df_len * 100).round(2)
# Out:
# city                   3.21
# client_event_time      0.00
# country                0.09
# device_family          0.17
# device_type            3.64
# event_type             0.00
# language               0.00
# os_name                0.14
# os_version             0.00
# platform               0.00
# user_id              100.00
# dtype: float64

# %% [markdown]
# #### ======== pre-defined and database info ========

# %%
non_id_enter_main = non_id_df

# %% [markdown]
# #### results [10] : enter.main_page.csv
# \
# core dropna : 2133548  -> 522516
# \
# drop duplicate : 255 \
# 'user_id' - max conut : 3808 \
# over 1 : 9.65% \
# 'user_id', 'client_event_time' - max conut : 3 \
# \
# too close log : 3197, 0.61% \
# \
# check null : \
# \
# city                 1.00 \
# client_event_time    0.00 \
# country              0.07 \
# device_family        0.00 \
# device_type          0.27 \
# event_type           0.00 \
# language             0.00 \
# os_name              0.00 \
# os_version           0.05 \
# platform             0.00 \
# user_id              0.00 \
# \
# check null with non_id_df : \
# \
# city                   3.21 \
# client_event_time      0.00 \
# country                0.09 \
# device_family          0.17 \
# device_type            3.64 \
# event_type             0.00 \
# language               0.00 \
# os_name                0.14 \
# os_version             0.84 \
# platform               0.00 \
# user_id              100.00

# %% [markdown]
# #### [11] : enter.payment_page.csv
# - 설명 : enter.payment_page

# %%
# df
file_no = 11
df = dfs[file_no].copy()
print(filelist[file_no])
# Out:
# enter.payment_page.csv

# %%
#
display(df.info())
display(df.head(5))
display(df.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165061 entries, 0 to 165060
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   city               162362 non-null  object
#  1   client_event_time  165061 non-null  datetime64[ns]
#  2   country            164899 non-null  object
#  3   device_family      165060 non-null  object
#  4   device_type        159066 non-null  object
#  5   event_type         165061 non-null  object
#  6   language           165061 non-null  object
#  7   os_name            165061 non-null  object
#  8   os_version         165061 non-null  object
#  9   platform           165061 non-null  object
#  10  user_id            158834 non-null  object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 13.9+ MB
# None
#       city       client_event_time      country  device_family  \
# 0    Seoul 2023-04-05 21:31:27.602  South Korea  Samsung Phone
# 1    Wonju 2023-04-05 21:33:30.699  South Korea        Windows
# 2  Daejeon 2023-04-05 21:05:28.337  South Korea        Windows
# 3    Seoul 2023-04-05 21:45:27.935  South Korea            Mac
# 4    Seoul 2023-04-05 21:46:50.632  South Korea            Mac
#
#              device_type          event_type language os_name     os_version  \
# 0  Samsung Galaxy A51 5G  enter.payment_page   Korean  Chrome      112.0.0.0
# 1                Windows  enter.payment_page   Korean  Chrome      111.0.0.0
# 2                Windows  enter.payment_page   Korean    Edge  111.0.1661.62
# 3                    Mac  enter.payment_page   Korean  Safari         15.6.1
# 4                    Mac  enter.payment_page   Korean  Safari         15.6.1
#
#   platform                           user_id
# 0      Web  8ee58bcaa05b234cdbf84167c0983385
# 1      Web  74d17c27a41656e7788b0c81d9f76cda
# 2      Web  62cfa08370da60b8db4495baaff62806
# 3      Web  06b6868000a5d576180aca47896d6cce
# 4      Web  06b6868000a5d576180aca47896d6cce
# Index(['city', 'client_event_time', 'country', 'device_family', 'device_type',
#        'event_type', 'language', 'os_name', 'os_version', 'platform',
#        'user_id'],
#       dtype='object')

# %%
# dropna in core_cols
print('before dropna :', df.shape[0], 'entries')
df = df.dropna(subset=core_cols[1:])
print('after dropna  :', df.shape[0], 'entries')
# Out:
# before dropna : 165061 entries
# after dropna  : 165061 entries

# %%
# too_close_log
check_too_close_log(df)
# Out:
# drop duplicate : 21 \
# 'user_id' - max conut : 101 \
# over 1 : 21.52% \
# 'user_id', 'client_event_time' - max conut : 2 \
#                city       client_event_time      country  device_family  \
# 26118         Suwon 2023-03-24 10:26:02.694  South Korea  Samsung Phone
# 59936         Seoul 2023-03-24 10:26:02.694  South Korea  Samsung Phone
# 13062  Seongdong-gu 2022-12-26 12:31:16.131  South Korea  Samsung Phone
# 53309     Dobong-gu 2022-12-26 12:31:16.131  South Korea  Samsung Phone
# 85267     Anyang-si 2022-11-17 10:35:36.694  South Korea        Windows
# 86875     Uiwang-si 2022-11-17 10:35:36.694  South Korea        Windows
# 26336         Seoul 2023-06-05 06:24:48.779  South Korea  Samsung Phone
# 40223    Yuseong-gu 2023-06-05 06:24:48.779  South Korea  Samsung Phone
# 33785       Incheon 2023-02-28 15:15:03.105  South Korea            Mac
# 47474     Yeonsu-gu 2023-02-28 15:15:03.105  South Korea            Mac
#
#                   device_type          event_type language          os_name  \
# 26118     Samsung Galaxy S22+  enter.payment_page   Korean        Instagram
# 59936     Samsung Galaxy S22+  enter.payment_page   Korean        Instagram
# 13062  Samsung Galaxy S20+ 5G  enter.payment_page   Korean           Chrome
# 53309  Samsung Galaxy S20+ 5G  enter.payment_page   Korean           Chrome
# 85267                 Windows  enter.payment_page   Korean            Whale
# 86875                 Windows  enter.payment_page   Korean            Whale
# 26336      Samsung Galaxy S22  enter.payment_page   Korean  Samsung Browser
# 40223      Samsung Galaxy S22  enter.payment_page   Korean  Samsung Browser
# 33785                     Mac  enter.payment_page   Korean           Chrome
# 47474                     Mac  enter.payment_page   Korean           Chrome
#
#           os_version platform                           user_id
# 26118  274.0.0.26.90      Web  04c4070b4a6f99e76d6939609fa62958
# 59936  274.0.0.26.90      Web  04c4070b4a6f99e76d6939609fa62958
# 13062      108.0.0.0      Web  07e422686e02a62ffc6cf06f8454e1b2
# 53309      108.0.0.0      Web  07e422686e02a62ffc6cf06f8454e1b2
# 85267    3.17.145.12      Web  2fd7523ead820c380fbe2e7e6000675c
# 86875    3.17.145.12      Web  2fd7523ead820c380fbe2e7e6000675c
# 26336           21.0      Web  50d8561b39af0a585aa5fe29135f9868
# 40223           21.0      Web  50d8561b39af0a585aa5fe29135f9868
# 33785      110.0.0.0      Web  5af7ed9398f4f5a61eedbdd376def391
# 47474      110.0.0.0      Web  5af7ed9398f4f5a61eedbdd376def391
# 162664    3.394027e+07
# 129401    3.384851e+07
# 161582    3.351084e+07
# Name: client_event_time, dtype: float64
# 65712    0.0
# 55765    0.0
# 86875    0.0
# Name: client_event_time, dtype: float64
#
#
# too close log : 23354, 14.15%
#                  city       client_event_time      country device_family  \
# 143127       Gyeongju 2023-11-29 01:07:57.136  South Korea    Apple iPad
# 125445          Seoul 2023-10-15 15:09:35.919  South Korea       Windows
# 158447      Goyang-si 2023-09-20 21:41:03.394  South Korea       Windows
# 92793           Seoul 2023-10-30 19:11:01.197  South Korea  Apple iPhone
# 156235  Pyeongtaek-si 2023-09-27 14:25:36.596  South Korea       Windows
# ...               ...                     ...          ...           ...
# 93161      Gangnam-gu 2023-09-15 07:53:30.960  South Korea       Windows
# 152126         Buk-gu 2023-09-27 04:06:39.371  South Korea       Windows
# 115134     Gangnam-gu 2023-09-11 10:38:24.622  South Korea       Windows
# 142892    Hwaseong-si 2023-11-15 04:45:44.402  South Korea       Windows
# 161092    Hwaseong-si 2023-11-15 05:17:47.168  South Korea       Windows
#
#                  device_type          event_type language        os_name  \
# 143127            Apple iPad  enter.payment_page   Korean  Mobile Safari
# 125445               Windows  enter.payment_page   Korean         Chrome
# 158447               Windows  enter.payment_page   Korean           Edge
# 92793   Apple iPhone 12 Mini  enter.payment_page   Korean      Instagram
# 156235               Windows  enter.payment_page   Korean           Edge
# ...                      ...                 ...      ...            ...
# 93161                Windows  enter.payment_page   Korean         Chrome
# 152126               Windows  enter.payment_page   Korean         Chrome
# 115134               Windows  enter.payment_page   Korean           Edge
# 142892               Windows  enter.payment_page   Korean         Chrome
# 161092               Windows  enter.payment_page   Korean         Chrome
#
#             os_version platform                           user_id
# 143127            15.4      Web  0001f15911b404f3bf5b8571afafa4e4
# 125445       117.0.0.0      Web  0001f28a707789a7d78dc28fd2e84dce
# 158447   116.0.1938.81      Web  0006474e7a888829001df3197bf6d644
# 92793   306.0.0.20.118      Web  000ad2412e2ced1b030a32089d794f5d
# 156235   117.0.2045.43      Web  001cc1d23174316d3752ed5d1ac32e48
# ...                ...      ...                               ...
# 93161        116.0.0.0      Web  fffcca0353b1476fd6f894c214cfb639
# 152126       117.0.0.0      Web  fffe529de03d6187ef7ed765650c8d2b
# 115134   116.0.1938.69      Web  ffffd8d78865a66cb3706977f29d1dec
# 142892       119.0.0.0      Web  ffffd8d78865a66cb3706977f29d1dec
# 161092       119.0.0.0      Web  ffffd8d78865a66cb3706977f29d1dec
#
# [23354 rows x 11 columns]

# %%
# pareto
for col in df.columns:
    # pass through common columns
    if col in common_cols: continue
    
    # display
    print(f"\n\n{col}")
    pareto(df, col)

# %% [markdown]
# #### results [11] : enter.payment_page.csv
# \
# core dropna : 165061
# \
# drop duplicate : 21 \
# 'user_id' - max conut : 101 \
# over 1 : 21.52% \
# 'user_id', 'client_event_time' - max conut : 2 \
# \
# too close log : 23354, 14.15%

# %% [markdown]
# #### [12] : enter.signup_page.csv
# - 설명 : 회원가입 페이지 진입

# %%
# df
file_no = 12
df = dfs[file_no].copy()
print(filelist[file_no])
# Out:
# enter.signup_page.csv

# %%
#
display(df.info())
display(df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596829 entries, 0 to 596828
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   city               581024 non-null  object
#  1   client_event_time  596829 non-null  datetime64[ns]
#  2   country            596315 non-null  object
#  3   device_family      596747 non-null  object
#  4   device_type        567387 non-null  object
#  5   event_type         596829 non-null  object
#  6   language           596829 non-null  object
#  7   os_name            596754 non-null  object
#  8   os_version         596829 non-null  object
#  9   platform           596829 non-null  object
#  10  user_id            0 non-null       float64
# dtypes: datetime64[ns](1), float64(1), object(9)
# memory usage: 50.1+ MB
# None
#          city       client_event_time      country     device_family  \
# 0       Seoul 2023-04-05 21:30:42.557  South Korea     Samsung Phone
# 1       Seoul 2023-04-05 21:37:41.467  South Korea  Samsung SM-S916N
# 2       Seoul 2023-04-05 21:05:53.237  South Korea      Apple iPhone
# 3  Gangnam-gu 2023-04-05 21:41:58.269  South Korea               Mac
# 4       Seoul 2023-04-05 21:44:53.294  South Korea               Mac
#
#              device_type         event_type language        os_name  \
# 0  Samsung Galaxy A51 5G  enter.signup_page   Korean         Chrome
# 1                    NaN  enter.signup_page   Korean         Chrome
# 2           Apple iPhone  enter.signup_page   Korean  Mobile Safari
# 3                    Mac  enter.signup_page   Korean         Safari
# 4                    Mac  enter.signup_page   Korean         Safari
#
#   os_version platform  user_id
# 0  112.0.0.0      Web      NaN
# 1  111.0.0.0      Web      NaN
# 2       16.4      Web      NaN
# 3       16.3      Web      NaN
# 4     15.6.1      Web      NaN

# %%
# dropna in core_cols
print('before dropna :', df.shape[0], 'entries')
df = df.dropna(subset=core_cols[1:])
print('after dropna  :', df.shape[0], 'entries')
# Out:
# before dropna : 596829 entries
# after dropna  : 596829 entries

# %%
# too_close_log
check_too_close_log(df)
# Out:
# drop duplicate : 39 \
# 'user_id' - max conut : nan \
# over 1 : 0.0% \
# 'user_id', 'client_event_time' - max conut : nan \
#
# Series([], Name: client_event_time, dtype: float64)
# Series([], Name: client_event_time, dtype: float64)

# %%
# pareto
for col in df.columns:
    # pass through common columns
    if col in common_cols: continue
    
    # display
    print(f"\n\n{col}")
    pareto(df, col)

# %% [markdown]
# #### results [12] : enter.signup_page.csv
# \
# core dropna : 596829

# %% [markdown]
# #### [13] : renew.subscription.csv
#
# - 설명 : 정기 결제 완료

# %%
# df
file_no = 13
df = dfs[file_no].copy()
print(filelist[file_no])
# Out:
# renew.subscription.csv

# %%
#
display(df.info())
display(df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15945 entries, 0 to 15944
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   city                    15575 non-null  object
#  1   client_event_time       15945 non-null  datetime64[ns]
#  2   country                 15656 non-null  object
#  3   device_family           15657 non-null  object
#  4   device_type             15484 non-null  object
#  5   event_type              15945 non-null  object
#  6   language                15657 non-null  object
#  7   os_name                 15654 non-null  object
#  8   os_version              15945 non-null  object
#  9   platform                15657 non-null  object
#  10  user_id                 15945 non-null  object
#  11  plan_price              15945 non-null  int64
#  12  paid_amount             15945 non-null  int64
#  13  coupon_discount_amount  15945 non-null  int64
#  14  pg_type                 2732 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(11)
# memory usage: 1.8+ MB
# None
#          city       client_event_time      country device_family device_type  \
# 0      Nam-gu 2022-09-08 03:05:02.068  South Korea       Windows     Windows
# 1      Nam-gu 2022-09-08 03:40:02.050  South Korea       Windows     Windows
# 2  Dongjak-gu 2022-09-08 03:49:00.829  South Korea       Windows     Windows
# 3   Yongin-si 2022-09-08 04:10:06.406  South Korea       Windows     Windows
# 4  Dongjak-gu 2022-09-08 04:40:01.895  South Korea       Android     Android
#
#            event_type language        os_name os_version platform  \
# 0  renew.subscription   Korean           Edge        104      Web
# 1  renew.subscription   Korean         Chrome        104      Web
# 2  renew.subscription   Korean         Chrome        104      Web
# 3  renew.subscription   Korean         Chrome        104      Web
# 4  renew.subscription   Korean  Chrome Mobile        103      Web
#
#                             user_id  plan_price  paid_amount  \
# 0  6ddea3af2eaae869861c1190dcc9d4a3       15920        15920
# 1  c2d47034960fdff5df495822ff66fbc1       15920        15920
# 2  de91f1226dd938990fefc79545daf468       42960        40812
# 3  bf14840a8cb4643e6d557da96e35a3af       15920        15920
# 4  7ddc1c2990d0645d82885394e3c518b5       15920        15920
#
#    coupon_discount_amount pg_type
# 0                       0     NaN
# 1                       0     NaN
# 2                    2148     NaN
# 3                       0     NaN
# 4                       0     NaN

# %%
# dropna in core_cols
print('before dropna :', df.shape[0], 'entries')
df = df.dropna(subset=core_cols)
print('after dropna  :', df.shape[0], 'entries')
# Out:
# before dropna : 15945 entries
# after dropna  : 15945 entries

# %%
# too_close_log
check_too_close_log(df)
# Out:
# drop duplicate : 0 \
# 'user_id' - max conut : 17 \
# over 1 : 19.96% \
# 'user_id', 'client_event_time' - max conut : 1 \
#
# 15899    4.109101e+07
# 15216    3.714870e+07
# 14891    3.680670e+07
# Name: client_event_time, dtype: float64
# 3074    148.658
# 9411    114.000
# 4442     56.954
# Name: client_event_time, dtype: float64

# %%
# pareto
for col in df.columns:
    # pass through common columns
    if col in common_cols: continue
    
    # display
    print(f"\n\n{col}")
    pareto(df, col)
# Out:
# plan_price
# total plan_price : 11
#    plan_price  count  percentage  cum_percentage
# 0       15920  11817       74.11           74.11
# 1       42960   1062        6.66           80.77
# 2       79200    954        5.98           86.75
# 3      131600    891        5.59           92.34
# 4       95520    537        3.37           95.71
#    plan_price  count  percentage  cum_percentage
# 0       15920  11817       74.11           74.11
# over 50% : 9.09%
#    plan_price  count  percentage  cum_percentage
# 1       42960   1062        6.66           80.77
# over 80% : 18.18%
#    plan_price  count  percentage  cum_percentage
# 4       95520    537        3.37           95.71
# over 95% : 45.45%
#
#
# paid_amount
# total paid_amount : 43
#    paid_amount  count  percentage  cum_percentage
# 0        15920  10621       66.61           66.61
# 1        42960    968        6.07           72.68
# 2        79200    943        5.91           78.60
# 3         7960    872        5.47           84.06
# 4       131600    823        5.16           89.23
#    paid_amount  count  percentage  cum_percentage
# 0        15920  10621       66.61           66.61
# over 50% : 2.33%
#    paid_amount  count  percentage  cum_percentage
# 3         7960    872        5.47           84.06
# over 80% : 9.3%
#    paid_amount  count  percentage  cum_percentage
# 7        87200    160         1.0           95.24
# over 95% : 18.6%
#
#
# coupon_discount_amount
# total coupon_discount_amount : 37
#    coupon_discount_amount  count  percentage  cum_percentage
# 0                       0  14526       91.10           91.10
# 1                    7960    872        5.47           96.57
# 2                    2388    131        0.82           97.39
# 3                   11960     78        0.49           97.88
# 4                   17184     64        0.40           98.28
#    coupon_discount_amount  count  percentage  cum_percentage
# 0                       0  14526        91.1            91.1
# over 50% : 2.7%
#    coupon_discount_amount  count  percentage  cum_percentage
# 0                       0  14526        91.1            91.1
# over 80% : 2.7%
#    coupon_discount_amount  count  percentage  cum_percentage
# 1                    7960    872        5.47           96.57
# over 95% : 5.41%
#
#
# pg_type
# total pg_type : 3
#   pg_type  count  percentage  cum_percentage
# 0       A   2579       94.40           94.40
# 1       B    104        3.81           98.21
# 2       C     49        1.79          100.00
#   pg_type  count  percentage  cum_percentage
# 0       A   2579        94.4            94.4
# over 50% : 33.33%
#   pg_type  count  percentage  cum_percentage
# 0       A   2579        94.4            94.4
# over 80% : 33.33%
#   pg_type  count  percentage  cum_percentage
# 1       B    104        3.81           98.21
# over 95% : 66.67%

# %% [markdown]
# #### results [13] : renew.subscription.csv
# \
# core dropna : 15945
# \
# drop duplicate : 0 \
# 'user_id' - max conut : 17 \
# over 1 : 19.96% \
# 'user_id', 'client_event_time' - unique \
# \
# pareto : \
# \
# total plan_price : 11 \
# \
# over 50% : 9.09% \
# over 80% : 18.18% \
# over 95% : 45.45% \
# \
# total paid_amount : 43 \
# \
# over 50% : 2.33% \
# over 80% : 9.3% \
# over 95% : 18.6% \
# \
# total coupon_discount_amount : 37 \
# \
# over 50% : 2.7% \
# over 80% : 2.7% \
# over 95% : 5.41% \
# \
# total pg_type : 3

# %% [markdown]
# #### [14] : resubscribe.subscription.csv
#
# - 설명 : 만료 후 재구독 완료

# %%
# df
file_no = 14
df = dfs[file_no].copy()
print(filelist[file_no])
# Out:
# resubscribe.subscription.csv

# %%
# 
display(df.info())
display(df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 791 entries, 0 to 790
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   city                    775 non-null    object
#  1   client_event_time       791 non-null    datetime64[ns]
#  2   country                 784 non-null    object
#  3   device_family           784 non-null    object
#  4   device_type             773 non-null    object
#  5   event_type              791 non-null    object
#  6   language                784 non-null    object
#  7   os_name                 784 non-null    object
#  8   os_version              791 non-null    object
#  9   platform                784 non-null    object
#  10  user_id                 791 non-null    object
#  11  plan_price              791 non-null    int64
#  12  paid_amount             791 non-null    int64
#  13  coupon_discount_amount  791 non-null    int64
#  14  pg_type                 173 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(11)
# memory usage: 92.8+ KB
# None
#          city       client_event_time      country  device_family  \
# 0     Daejeon 2023-04-05 21:11:45.525  South Korea        Windows
# 1       Seoul 2023-06-30 09:59:56.848  South Korea  Samsung Phone
# 2    Nowon-gu 2023-06-13 06:20:22.524  South Korea        Windows
# 3       Suwon 2023-06-11 11:02:11.878  South Korea        Windows
# 4  Koishikawa 2023-06-13 14:39:25.736        Japan   Apple iPhone
#
#            device_type                event_type  language         os_name  \
# 0              Windows  resubscribe.subscription    Korean            Edge
# 1  Samsung Galaxy S22+  resubscribe.subscription    Korean  Chrome WebView
# 2              Windows  resubscribe.subscription    Korean          Chrome
# 3              Windows  resubscribe.subscription    Korean          Chrome
# 4         Apple iPhone  resubscribe.subscription  Japanese          Chrome
#
#        os_version platform                           user_id  plan_price  \
# 0   111.0.1661.62      Web  41362ad5ebcade2bb1b78344a53e7ccf       15920
# 1  113.0.5672.162      Web  68831c27e47f0e8f04ba809baeec218e       15920
# 2       114.0.0.0      Web  4e7568cb7db01f8386614ec2c6c961cd       15920
# 3       114.0.0.0      Web  f91f19527b9ec688e028ec884b1b5c1c      131600
# 4   114.0.5735.99      Web  2276d7d2a31e05f4a5558c6406cc36c9      131600
#
#    paid_amount  coupon_discount_amount pg_type
# 0        15920                       0     NaN
# 1        15920                       0     NaN
# 2        15920                       0     NaN
# 3       131600                       0     NaN
# 4       131600                       0     NaN

# %%
# dropna in core_cols
print('before dropna :', df.shape[0], 'entries')
df = df.dropna(subset=core_cols)
print('after dropna  :', df.shape[0], 'entries')
# Out:
# before dropna : 791 entries
# after dropna  : 791 entries

# %%
# too_close_log
check_too_close_log(df)
# Out:
# drop duplicate : 0 \
# 'user_id' - max conut : 3 \
# over 1 : 3.29% \
# 'user_id', 'client_event_time' - max conut : 1 \
#
# 361    4.036989e+07
# 477    2.867280e+07
# 438    2.851033e+07
# Name: client_event_time, dtype: float64
# 458    5633123.334
# 736    3418259.560
# 93     3010329.346
# Name: client_event_time, dtype: float64

# %%
# pareto
for col in df.columns:
    # pass through common columns
    if col in common_cols: continue
    
    # display
    print(f"\n\n{col}")
    pareto(df, col)
# Out:
# plan_price
# total plan_price : 4
#    plan_price  count  percentage  cum_percentage
# 0       15920    544       68.77           68.77
# 1      131600    116       14.66           83.44
# 2       95520     93       11.76           95.20
# 3       42960     38        4.80          100.00
#    plan_price  count  percentage  cum_percentage
# 0       15920    544       68.77           68.77
# over 50% : 25.0%
#    plan_price  count  percentage  cum_percentage
# 1      131600    116       14.66           83.44
# over 80% : 50.0%
#    plan_price  count  percentage  cum_percentage
# 2       95520     93       11.76            95.2
# over 95% : 75.0%
#
#
# paid_amount
# total paid_amount : 22
#    paid_amount  count  percentage  cum_percentage
# 0        15920    480       60.68           60.68
# 1       131600     98       12.39           73.07
# 2        95520     93       11.76           84.83
# 3        42960     29        3.67           88.50
# 4        13532     18        2.28           90.77
#    paid_amount  count  percentage  cum_percentage
# 0        15920    480       60.68           60.68
# over 50% : 4.55%
#    paid_amount  count  percentage  cum_percentage
# 2        95520     93       11.76           84.83
# over 80% : 13.64%
#    paid_amount  count  percentage  cum_percentage
# 7       111860      6        0.76           95.07
# over 95% : 36.36%
#
#
# coupon_discount_amount
# total coupon_discount_amount : 19
#    coupon_discount_amount  count  percentage  cum_percentage
# 0                       0    700       88.50           88.50
# 1                    2388     18        2.28           90.77
# 2                     796     14        1.77           92.54
# 3                     478     14        1.77           94.31
# 4                    7960      6        0.76           95.07
#    coupon_discount_amount  count  percentage  cum_percentage
# 0                       0    700        88.5            88.5
# over 50% : 5.26%
#    coupon_discount_amount  count  percentage  cum_percentage
# 0                       0    700        88.5            88.5
# over 80% : 5.26%
#    coupon_discount_amount  count  percentage  cum_percentage
# 4                    7960      6        0.76           95.07
# over 95% : 26.32%
#
#
# pg_type
# total pg_type : 2
#   pg_type  count  percentage  cum_percentage
# 0       A    123        71.1            71.1
# 1       B     50        28.9           100.0
#   pg_type  count  percentage  cum_percentage
# 0       A    123        71.1            71.1
# over 50% : 50.0%
#   pg_type  count  percentage  cum_percentage
# 1       B     50        28.9           100.0
# over 80% : 100.0%
#   pg_type  count  percentage  cum_percentage
# 1       B     50        28.9           100.0
# over 95% : 100.0%

# %% [markdown]
# #### results [14] : resubscribe.subscription.csv
# \
# core dropna : 791
# \
# drop duplicate : 0 \
# 'user_id' - max conut : 3 \
# over 1 : 3.29% \
# 'user_id', 'client_event_time' - unique \
# \
# pareto : \
# \
# total plan_price : 4 \
# \
# over 50% : 25.0% \
# over 80% : 50.0% \
# over 95% : 75.0% \
# \
# total paid_amount : 22 \
# \
# over 50% : 4.55% \
# over 80% : 13.64% \
# over 95% : 36.36% \
# \
# total coupon_discount_amount : 19 \
# \
# over 50% : 5.26% \
# over 80% : 5.26% \
# over 95% : 26.32% \
# \
# total pg_type : 2 \
# A 71.1 \
# B 28.9

# %% [markdown]
# #### [15] : start.content.csv
#
# - 설명 : 콘텐츠 수강 시작
#  / 22년 8월부터 수집된 테이블입니다.

# %%
# df
file_no = 15
df = dfs[file_no].copy()
print(filelist[file_no])
# Out:
# start.content.csv

# %%
#
display(df.info())
display(df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124917 entries, 0 to 124916
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   city                121017 non-null  object
#  1   client_event_time   124917 non-null  datetime64[ns]
#  2   country             122032 non-null  object
#  3   device_family       122690 non-null  object
#  4   device_type         120068 non-null  object
#  5   event_type          124917 non-null  object
#  6   language            122692 non-null  object
#  7   os_name             122671 non-null  object
#  8   os_version          124917 non-null  object
#  9   platform            122692 non-null  object
#  10  user_id             124917 non-null  object
#  11  content_id          124917 non-null  object
#  12  content_difficulty  124917 non-null  object
# dtypes: datetime64[ns](1), object(12)
# memory usage: 12.4+ MB
# None
#       city       client_event_time      country device_family device_type  \
# 0  Daejeon 2023-04-05 21:14:39.906  South Korea       Windows     Windows
# 1    Seoul 2023-04-05 21:50:19.674  South Korea           Mac         Mac
# 2    Seoul 2023-04-10 14:06:26.585  South Korea           Mac         Mac
# 3  Toronto 2023-04-10 14:15:29.040       Canada       Windows     Windows
# 4    Seoul 2023-04-10 14:21:36.467  South Korea       Windows     Windows
#
#       event_type language os_name     os_version platform  \
# 0  start.content   Korean    Edge  111.0.1661.62      Web
# 1  start.content   Korean  Safari         15.6.1      Web
# 2  start.content   Korean   Whale    3.19.166.16      Web
# 3  start.content  English  Chrome      111.0.0.0      Web
# 4  start.content   Korean  Chrome      111.0.0.0      Web
#
#                             user_id                        content_id  \
# 0  41362ad5ebcade2bb1b78344a53e7ccf  445fac33232adcb3d1cdab7d8a579430
# 1  06b6868000a5d576180aca47896d6cce  f4be1a0fe0e301b03115591777fddf29
# 2  7b2ff3116db46b5e4326d49c7b027631  61b6463287573f00de13a930805a52d6
# 3  eb7515590646ead796fdfb54e2729240  61b6463287573f00de13a930805a52d6
# 4  85a332649d34bc7b5ebdec7660b1d57d  18992b667be06d6f29ba0008f99d9745
#
#   content_difficulty
# 0           beginner
# 1           beginner
# 2           beginner
# 3           beginner
# 4           advanced

# %%
# dropna in core_cols
print('before dropna :', df.shape[0], 'entries')
df = df.dropna(subset=core_cols)
print('after dropna  :', df.shape[0], 'entries')
# Out:
# before dropna : 124917 entries
# after dropna  : 124917 entries

# %%
# too_close_log
check_too_close_log(df)
# Out:
# drop duplicate : 0 \
# 'user_id' - max conut : 83 \
# over 1 : 13.79% \
# 'user_id', 'client_event_time' - max conut : 1 \
#
# 119286    4.241172e+07
# 74538     4.182159e+07
# 67118     4.145035e+07
# Name: client_event_time, dtype: float64
# 88044     0.002
# 122190    0.002
# 22596     0.001
# Name: client_event_time, dtype: float64
#
#
# too close log : 99, 0.08%
#                 city       client_event_time        country device_family  \
# 115714    Suyeong-gu 2023-10-15 08:36:55.103    South Korea       Windows
# 30277      Jeju City 2023-04-03 16:41:37.377    South Korea  Apple iPhone
# 30278      Jeju City 2023-04-03 16:41:37.875    South Korea  Apple iPhone
# 2816           Seoul 2023-05-07 03:54:05.242    South Korea         Linux
# 117282         Seoul 2023-10-02 06:40:39.715    South Korea       Windows
# ...              ...                     ...            ...           ...
# 112966  Uijeongbu-si 2023-12-19 13:03:52.482    South Korea           Mac
# 112967  Uijeongbu-si 2023-12-19 13:03:52.902    South Korea           Mac
# 112968  Uijeongbu-si 2023-12-19 13:03:52.948    South Korea           Mac
# 54647        Amherst 2022-09-07 10:25:34.069  United States       Windows
# 88682            NaN 2023-08-06 19:06:06.009            NaN           NaN
#
#                 device_type     event_type language   os_name os_version  \
# 115714              Windows  start.content   Korean    Chrome  118.0.0.0
# 30277   Apple iPhone 7 Plus  start.content   Korean  Facebook        nan
# 30278   Apple iPhone 7 Plus  start.content   Korean  Facebook        nan
# 2816                  Linux  start.content   Korean    Chrome  112.0.0.0
# 117282              Windows  start.content   Korean    Chrome  117.0.0.0
# ...                     ...            ...      ...       ...        ...
# 112966                  Mac  start.content   Korean    Chrome  120.0.0.0
# 112967                  Mac  start.content   Korean    Chrome  120.0.0.0
# 112968                  Mac  start.content   Korean    Chrome  120.0.0.0
# 54647               Windows  start.content   Korean    Chrome        104
# 88682                   NaN  start.content      NaN       NaN        nan
#
#        platform                           user_id  \
# 115714      Web  02c6b331129ea8588abca4e1dd41adea
# 30277       Web  065f04b00835f52f288cfc7c4516ccd4
# 30278       Web  065f04b00835f52f288cfc7c4516ccd4
# 2816        Web  0a636d3bc32f16c6410f02a989507aa4
# 117282      Web  0b5fa0fea50b30af6cd6c6d7fc1559a8
# ...         ...                               ...
# 112966      Web  f84c4f83ca1e977a89e0f7f7e6561a48
# 112967      Web  f84c4f83ca1e977a89e0f7f7e6561a48
# 112968      Web  f84c4f83ca1e977a89e0f7f7e6561a48
# 54647       Web  f8868b5573dc20f97a1c65b25a02b7fb
# 88682       NaN  fb0bac2e4fdb7258ad045754be43b80f
#
#                               content_id content_difficulty
# 115714  621c7ad99b17d2d16832b618d47aea7e           advanced
# 30277   f4be1a0fe0e301b03115591777fddf29           beginner
# 30278   f4be1a0fe0e301b03115591777fddf29           beginner
# 2816    e543c38ec7fa6bcd5045049ecc31e5f8           advanced
# 117282  cf76ec385bf471bd774ddebf1749d3d4           advanced
# ...                                  ...                ...
# 112966  f64c475280676531a31f2f8e0648599c       intermediate
# 112967  f64c475280676531a31f2f8e0648599c       intermediate
# 112968  f64c475280676531a31f2f8e0648599c       intermediate
# 54647   7fef928cdccef0185dfb931ef59b37d7           advanced
# 88682   595cb4bbfc83e683b0314ca1312cfbde       intermediate
#
# [99 rows x 13 columns]

# %%
# pareto
for col in df.columns:
    # pass through common columns
    if col in common_cols: continue
    
    # display
    print(f"\n\n{col}")
    pareto(df, col)
# Out:
# content_id
# total content_id : 151
#                          content_id  count  percentage  cum_percentage
# 0  f4be1a0fe0e301b03115591777fddf29  25051       20.05           20.05
# 1  61b6463287573f00de13a930805a52d6  15234       12.20           32.25
# 2  f491517f4737a60d661cd1fcacc702c0   5617        4.50           36.75
# 3  68a3658f1b936bfff3bd6960cd561b0a   5571        4.46           41.21
# 4  445fac33232adcb3d1cdab7d8a579430   4717        3.78           44.98
#                          content_id  count  percentage  cum_percentage
# 6  c269eb6df3a374b464f7c18f12fa398f   3451        2.76           51.06
# over 50% : 4.64%
#                           content_id  count  percentage  cum_percentage
# 31  66fbc8fa22ac46a73eb3dfe499d270a7    926        0.74           80.52
# over 80% : 21.19%
#                           content_id  count  percentage  cum_percentage
# 66  25affb7ca2791a79dbd0a96d7ecf9b4b    315        0.25           95.08
# over 95% : 44.37%
#
#
# content_difficulty
# total content_difficulty : 4
#   content_difficulty  count  percentage  cum_percentage
# 0           beginner  58628       46.93           46.93
# 1       intermediate  36109       28.91           75.84
# 2           advanced  27485       22.00           97.84
# 3               hard   2695        2.16          100.00
#   content_difficulty  count  percentage  cum_percentage
# 1       intermediate  36109       28.91           75.84
# over 50% : 50.0%
#   content_difficulty  count  percentage  cum_percentage
# 2           advanced  27485        22.0           97.84
# over 80% : 75.0%
#   content_difficulty  count  percentage  cum_percentage
# 2           advanced  27485        22.0           97.84
# over 95% : 75.0%

# %% [markdown]
# #### results #### [15] : start.content.csv
# \
# core dropna : 124917
# \
# drop duplicate : 0 \
# 'user_id' - max conut : 83 \
# over 1 : 13.79% \
# 'user_id', 'client_event_time' - unique \
# \
# too close log : 99, 0.08% \
# \
# pareto : \
# \
# total content_id : 151 \
# \
# over 50% : 4.64% \
# over 80% : 21.19% \
# over 95% : 44.37% \
# \
# total paid_amount : 22 \
# \
# over 50% : 4.55% \
# over 80% : 13.64% \
# over 95% : 36.36% \
# \
# total content_difficulty : 4 \
# \
# beginner 46.93 \
# intermediate 28.91 \
# advanced 22.00 \
# hard 2.16

# %% [markdown]
# #### [16] : start.free_trial.csv
#
# - 설명 : 서비스 무료체험 시작

# %%
# df
file_no = 16
df = dfs[file_no].copy()
print(filelist[file_no])
# Out:
# start.free_trial.csv

# %%
#
display(df.info())
display(df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30621 entries, 0 to 30620
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   city               30133 non-null  object
#  1   client_event_time  30621 non-null  datetime64[ns]
#  2   country            30491 non-null  object
#  3   device_family      30499 non-null  object
#  4   device_type        30478 non-null  object
#  5   event_type         30621 non-null  object
#  6   language           30499 non-null  object
#  7   os_name            30499 non-null  object
#  8   os_version         30621 non-null  object
#  9   platform           30499 non-null  object
#  10  user_id            30607 non-null  object
#  11  plan_price         2439 non-null   float64
#  12  plan_type          2439 non-null   object
#  13  trial_type         30621 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(12)
# memory usage: 3.3+ MB
# None
#         city       client_event_time      country device_family device_type  \
# 0      Seoul 2023-04-05 21:49:36.156  South Korea           Mac         Mac
# 1  Dobong-gu 2023-03-12 08:28:29.384  South Korea       Windows     Windows
# 2        NaN 2023-03-12 08:35:00.107          NaN           NaN         NaN
# 3      Seoul 2023-04-12 11:36:50.250  South Korea           Mac         Mac
# 4        NaN 2023-02-18 04:13:20.822          NaN           NaN         NaN
#
#          event_type language os_name os_version platform  \
# 0  start.free_trial   Korean  Safari     15.6.1      Web
# 1  start.free_trial   Korean  Chrome  110.0.0.0      Web
# 2  start.free_trial      NaN     NaN        nan      NaN
# 3  start.free_trial   Korean  Safari       15.1      Web
# 4  start.free_trial      NaN     NaN        nan      NaN
#
#                             user_id  plan_price plan_type trial_type
# 0  06b6868000a5d576180aca47896d6cce     15920.0    1개월 플랜          B
# 1  40acc1ddfc012f3d2f58a3de95e9e748     15920.0    1개월 플랜          B
# 2  38aca03fba9753a6b2f31b829fb16a30     15920.0    1개월 플랜          B
# 3  cc8051a75f62278b0e4216dd0a182d8c     15920.0    1개월 플랜          B
# 4  4cc436ad294973993ccad3e3a70053a7    131600.0   12개월 플랜          B

# %%
# dropna in core_cols
print('before dropna :', df.shape[0], 'entries')
df = df.dropna(subset=core_cols)
print('after dropna  :', df.shape[0], 'entries')
# Out:
# before dropna : 30621 entries
# after dropna  : 30607 entries

# %%
# too_close_log
check_too_close_log(df)
# Out:
# drop duplicate : 0 \
# 'user_id' - max conut : 66 \
# over 1 : 19.32% \
# 'user_id', 'client_event_time' - max conut : 2 \
#              city       client_event_time      country device_family  \
# 5468   Dongjak-gu 2021-12-28 10:57:50.504  South Korea       Android
# 21571       Seoul 2021-12-28 10:57:50.504  South Korea       Android
#
#       device_type        event_type language          os_name os_version  \
# 5468      Android  start.free_trial   Korean  Samsung Browser       16.0
# 21571     Android  start.free_trial   Korean  Samsung Browser       16.0
#
#       platform                           user_id  plan_price plan_type  \
# 5468       Web  f6f2c94b0d55814958f27c64c3df775a         NaN       NaN
# 21571      Web  f6f2c94b0d55814958f27c64c3df775a         NaN       NaN
#
#       trial_type
# 5468           A
# 21571          A
# 981     3.683090e+07
# 1838    3.656525e+07
# 913     3.463205e+07
# Name: client_event_time, dtype: float64
# 25805    0.005
# 25807    0.005
# 21571    0.000
# Name: client_event_time, dtype: float64
#
#
# too close log : 274, 0.9%
#              city       client_event_time      country device_family  \
# 23768       Wonju 2022-05-14 23:59:45.405  South Korea    Apple iPad
# 17494  Bucheon-si 2022-05-19 04:28:49.278  South Korea       Windows
# 26402   Pohang-si 2022-07-06 08:49:18.835  South Korea       Windows
# 6010   Bucheon-si 2022-06-12 11:03:11.101  South Korea       Windows
# 13060       Seoul 2022-02-06 06:52:22.728  South Korea       Windows
# ...           ...                     ...          ...           ...
# 19219       Mokpo 2022-01-11 01:09:20.186  South Korea       Windows
# 14361  Gangbuk-gu 2022-01-12 03:23:22.428  South Korea       Windows
# 14362  Gangbuk-gu 2022-01-12 03:23:22.981  South Korea       Windows
# 24849    Ansan-si 2022-05-24 09:01:46.525  South Korea       Windows
# 26559   Chuncheon 2022-04-26 12:55:48.490  South Korea       Windows
#
#       device_type        event_type language        os_name os_version  \
# 23768  Apple iPad  start.free_trial   Korean  Chrome Mobile      101.0
# 17494     Windows  start.free_trial   Korean         Chrome      101.0
# 26402     Windows  start.free_trial   Korean         Chrome      103.0
# 6010      Windows  start.free_trial   Korean         Chrome      102.0
# 13060     Windows  start.free_trial   Korean         Chrome       98.0
# ...           ...               ...      ...            ...        ...
# 19219     Windows  start.free_trial   Korean         Chrome       96.0
# 14361     Windows  start.free_trial   Korean         Chrome       96.0
# 14362     Windows  start.free_trial   Korean         Chrome       96.0
# 24849     Windows  start.free_trial   Korean           Edge      101.0
# 26559     Windows  start.free_trial   Korean         Chrome      100.0
#
#       platform                           user_id  plan_price plan_type  \
# 23768      Web  01b0b7e0e256a75c5a2b1e7d703abf3a         NaN       NaN
# 17494      Web  0432b6494167d2c64d3e1cb7297bf020         NaN       NaN
# 26402      Web  087b7dbeba41ae6062f6cb58d6257cf8         NaN       NaN
# 6010       Web  0901aaa049091a0e60f7367aaecd673e         NaN       NaN
# 13060      Web  0a40d8cfc9c8fde661acfa0d8aff3410         NaN       NaN
# ...        ...                               ...         ...       ...
# 19219      Web  fb1dbb308f066b69f4160a8e7ef719d3         NaN       NaN
# 14361      Web  fd9f20cab43785801d910f7d40a3614f         NaN       NaN
# 14362      Web  fd9f20cab43785801d910f7d40a3614f         NaN       NaN
# 24849      Web  fe78f01346074dd83a401ba68b23002c         NaN       NaN
# 26559      Web  fed315fca830193a3b6c9c691b3f77f9         NaN       NaN
#
#       trial_type
# 23768          A
# 17494          A
# 26402          A
# 6010           A
# 13060          A
# ...          ...
# 19219          A
# 14361          A
# 14362          A
# 24849          A
# 26559          A
#
# [274 rows x 14 columns]

# %%
# pareto
for col in df.columns:
    # pass through common columns
    if col in common_cols: continue
    
    # display
    print(f"\n\n{col}")
    pareto(df, col)
# Out:
# plan_price
# total plan_price : 2
#    plan_price  count  percentage  cum_percentage
# 0     15920.0   1278        52.4            52.4
# 1    131600.0   1161        47.6           100.0
#    plan_price  count  percentage  cum_percentage
# 0     15920.0   1278        52.4            52.4
# over 50% : 50.0%
#    plan_price  count  percentage  cum_percentage
# 1    131600.0   1161        47.6           100.0
# over 80% : 100.0%
#    plan_price  count  percentage  cum_percentage
# 1    131600.0   1161        47.6           100.0
# over 95% : 100.0%
#
#
# plan_type
# total plan_type : 2
#   plan_type  count  percentage  cum_percentage
# 0    1개월 플랜   1278        52.4            52.4
# 1   12개월 플랜   1161        47.6           100.0
#   plan_type  count  percentage  cum_percentage
# 0    1개월 플랜   1278        52.4            52.4
# over 50% : 50.0%
#   plan_type  count  percentage  cum_percentage
# 1   12개월 플랜   1161        47.6           100.0
# over 80% : 100.0%
#   plan_type  count  percentage  cum_percentage
# 1   12개월 플랜   1161        47.6           100.0
# over 95% : 100.0%
#
#
# trial_type
# total trial_type : 2
#   trial_type  count  percentage  cum_percentage
# 0          A  28168       92.03           92.03
# 1          B   2439        7.97          100.00
#   trial_type  count  percentage  cum_percentage
# 0          A  28168       92.03           92.03
# over 50% : 50.0%
#   trial_type  count  percentage  cum_percentage
# 0          A  28168       92.03           92.03
# over 80% : 50.0%
#   trial_type  count  percentage  cum_percentage
# 1          B   2439        7.97           100.0
# over 95% : 100.0%

# %% [markdown]
# #### ======== end of simple EDA ========

# %% [markdown]
# #### 할일 7, 8, 9, 10, 17
#
# 7  : [11] : enter.payment_page.csv
# 8  : [6] : complete.subscription.csv
# 9  : [13] : renew.subscription.csv
# 10 : [14] : resubscribe.subscription.csv
# 17 : [0] : click.cancel_plan_button.csv

# %%
def get_com_df(df, core_cols, common_cols):
    target_col = [ col for col in df.columns if col not in common_cols]
    print(target_col)
    result = df[core_cols + target_col]
    display(result.head(5))
    
    return result

# %%
print(core_cols)
print(common_cols)

# 7  : [11] : enter.payment_page.csv
enter_pay_df = dfs[11].copy()

com_enter_pay_df = get_com_df(enter_pay_df, core_cols, common_cols)

display(enter_pay_df.info())
display(enter_pay_df.head(5))
display(com_enter_pay_df.head(5))

# 8  : [6]  : complete.subscription.csv
first_subscript_df = dfs[6].copy()

print(over1_first_subscript_user[:5])
com_first_subscript_df = get_com_df(first_subscript_df, core_cols, common_cols)

display(first_subscript_df.info())
display(first_subscript_df.head(5))
display(com_first_subscript_df.head(5))

# 9  : [13] : renew.subscription.csv
auto_pay_df = dfs[13].copy()

com_auto_pay_df = get_com_df(auto_pay_df, core_cols, common_cols)

display(auto_pay_df.info())
display(auto_pay_df.head(5))
display(com_auto_pay_df.head(5))

# 10 : [14] : resubscribe.subscription.csv
re_subscript_df = dfs[14].copy()

com_re_subscript_df = get_com_df(re_subscript_df, core_cols, common_cols)

display(re_subscript_df.info())
display(re_subscript_df.head(5))
display(com_re_subscript_df.head(5))

# 17 : [0]  : click.cancel_plan_button.csv
cancel_plan_df = dfs[0].copy()

com_cancel_plan_df = get_com_df(cancel_plan_df, core_cols, common_cols)

display(cancel_plan_df.info())
display(cancel_plan_df.head(5))
display(com_cancel_plan_df.head(5))
# Out:
# ['user_id', 'event_type', 'client_event_time']
# ['client_event_time', 'os_version', 'user_id', 'os_name', 'country', 'language', 'city', 'platform', 'event_type', 'device_family', 'device_type', 'device_carrier']
# []
#                             user_id          event_type  \
# 0  8ee58bcaa05b234cdbf84167c0983385  enter.payment_page
# 1  74d17c27a41656e7788b0c81d9f76cda  enter.payment_page
# 2  62cfa08370da60b8db4495baaff62806  enter.payment_page
# 3  06b6868000a5d576180aca47896d6cce  enter.payment_page
# 4  06b6868000a5d576180aca47896d6cce  enter.payment_page
#
#         client_event_time
# 0 2023-04-05 21:31:27.602
# 1 2023-04-05 21:33:30.699
# 2 2023-04-05 21:05:28.337
# 3 2023-04-05 21:45:27.935
# 4 2023-04-05 21:46:50.632
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165061 entries, 0 to 165060
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   city               162362 non-null  object
#  1   client_event_time  165061 non-null  datetime64[ns]
#  2   country            164899 non-null  object
#  3   device_family      165060 non-null  object
#  4   device_type        159066 non-null  object
#  5   event_type         165061 non-null  object
#  6   language           165061 non-null  object
#  7   os_name            165061 non-null  object
#  8   os_version         165061 non-null  object
#  9   platform           165061 non-null  object
#  10  user_id            158834 non-null  object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 13.9+ MB
# None
#       city       client_event_time      country  device_family  \
# 0    Seoul 2023-04-05 21:31:27.602  South Korea  Samsung Phone
# 1    Wonju 2023-04-05 21:33:30.699  South Korea        Windows
# 2  Daejeon 2023-04-05 21:05:28.337  South Korea        Windows
# 3    Seoul 2023-04-05 21:45:27.935  South Korea            Mac
# 4    Seoul 2023-04-05 21:46:50.632  South Korea            Mac
#
#              device_type          event_type language os_name     os_version  \
# 0  Samsung Galaxy A51 5G  enter.payment_page   Korean  Chrome      112.0.0.0
# 1                Windows  enter.payment_page   Korean  Chrome      111.0.0.0
# 2                Windows  enter.payment_page   Korean    Edge  111.0.1661.62
# 3                    Mac  enter.payment_page   Korean  Safari         15.6.1
# 4                    Mac  enter.payment_page   Korean  Safari         15.6.1
#
#   platform                           user_id
# 0      Web  8ee58bcaa05b234cdbf84167c0983385
# 1      Web  74d17c27a41656e7788b0c81d9f76cda
# 2      Web  62cfa08370da60b8db4495baaff62806
# 3      Web  06b6868000a5d576180aca47896d6cce
# 4      Web  06b6868000a5d576180aca47896d6cce
#                             user_id          event_type  \
# 0  8ee58bcaa05b234cdbf84167c0983385  enter.payment_page
# 1  74d17c27a41656e7788b0c81d9f76cda  enter.payment_page
# 2  62cfa08370da60b8db4495baaff62806  enter.payment_page
# 3  06b6868000a5d576180aca47896d6cce  enter.payment_page
# 4  06b6868000a5d576180aca47896d6cce  enter.payment_page
#
#         client_event_time
# 0 2023-04-05 21:31:27.602
# 1 2023-04-05 21:33:30.699
# 2 2023-04-05 21:05:28.337
# 3 2023-04-05 21:45:27.935
# 4 2023-04-05 21:46:50.632
# ['018e9f53c73beed1d161a392126d513b', '01ee9c8e8858d201d0ae72cc2757546c', '02a857284f291785a949fbd7ed7d6e91', '046469242e1de011419057a9511925c3', '04e3ed921de9a3cb187256ece5cf81bc']
# ['plan_price', 'paid_amount', 'coupon_discount_amount', 'pg_type']
#                             user_id             event_type  \
# 0  1116a2ae90ca6b06f85feba27ad51ef0  complete.subscription
# 1  c0f5678df8967163e6e2c464ed006791  complete.subscription
# 2  79421b5d038205ad7adbb1e2c3b89741  complete.subscription
# 3  bdffe1f18684704d4ea2d7eebcaed180  complete.subscription
# 4  d4f54ecf6c4d7bf8742f80505f02d6dc  complete.subscription
#
#         client_event_time  plan_price  paid_amount  coupon_discount_amount  \
# 0 2023-04-05 21:40:04.000       15920        15920                       0
# 1 2023-04-10 14:20:03.008      131600       131600                       0
# 2 2023-03-12 08:46:14.026      131600       119756                   11844
# 3 2023-04-12 11:35:01.865      131600       131600                       0
# 4 2023-05-31 01:25:55.820       15920        15920                       0
#
#   pg_type
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14289 entries, 0 to 14288
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   city                    13757 non-null  object
#  1   client_event_time       14289 non-null  datetime64[ns]
#  2   country                 13906 non-null  object
#  3   device_family           13914 non-null  object
#  4   device_type             13764 non-null  object
#  5   event_type              14289 non-null  object
#  6   language                13914 non-null  object
#  7   os_name                 13908 non-null  object
#  8   os_version              14289 non-null  object
#  9   platform                13914 non-null  object
#  10  user_id                 14289 non-null  object
#  11  plan_price              14289 non-null  int64
#  12  paid_amount             14289 non-null  int64
#  13  coupon_discount_amount  14289 non-null  int64
#  14  pg_type                 1642 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(11)
# memory usage: 1.6+ MB
# None
#            city       client_event_time      country device_family  \
# 0      Nowon-gu 2023-04-05 21:40:04.000  South Korea       Windows
# 1         Seoul 2023-04-10 14:20:03.008  South Korea  Apple iPhone
# 2       Yangsan 2023-03-12 08:46:14.026  South Korea       Windows
# 3  Geumjeong-gu 2023-04-12 11:35:01.865  South Korea       Windows
# 4   Gwangmyeong 2023-05-31 01:25:55.820  South Korea           Mac
#
#     device_type             event_type language        os_name     os_version  \
# 0       Windows  complete.subscription   Korean           Edge  111.0.1661.62
# 1  Apple iPhone  complete.subscription   Korean  Mobile Safari           16.3
# 2       Windows  complete.subscription   Korean         Chrome      111.0.0.0
# 3       Windows  complete.subscription   Korean         Chrome      111.0.0.0
# 4           Mac  complete.subscription   Korean         Chrome      113.0.0.0
#
#   platform                           user_id  plan_price  paid_amount  \
# 0      Web  1116a2ae90ca6b06f85feba27ad51ef0       15920        15920
# 1      Web  c0f5678df8967163e6e2c464ed006791      131600       131600
# 2      Web  79421b5d038205ad7adbb1e2c3b89741      131600       119756
# 3      Web  bdffe1f18684704d4ea2d7eebcaed180      131600       131600
# 4      Web  d4f54ecf6c4d7bf8742f80505f02d6dc       15920        15920
#
#    coupon_discount_amount pg_type
# 0                       0     NaN
# 1                       0     NaN
# 2                   11844     NaN
# 3                       0     NaN
# 4                       0     NaN
#                             user_id             event_type  \
# 0  1116a2ae90ca6b06f85feba27ad51ef0  complete.subscription
# 1  c0f5678df8967163e6e2c464ed006791  complete.subscription
# 2  79421b5d038205ad7adbb1e2c3b89741  complete.subscription
# 3  bdffe1f18684704d4ea2d7eebcaed180  complete.subscription
# 4  d4f54ecf6c4d7bf8742f80505f02d6dc  complete.subscription
#
#         client_event_time  plan_price  paid_amount  coupon_discount_amount  \
# 0 2023-04-05 21:40:04.000       15920        15920                       0
# 1 2023-04-10 14:20:03.008      131600       131600                       0
# 2 2023-03-12 08:46:14.026      131600       119756                   11844
# 3 2023-04-12 11:35:01.865      131600       131600                       0
# 4 2023-05-31 01:25:55.820       15920        15920                       0
#
#   pg_type
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ['plan_price', 'paid_amount', 'coupon_discount_amount', 'pg_type']
#                             user_id          event_type  \
# 0  6ddea3af2eaae869861c1190dcc9d4a3  renew.subscription
# 1  c2d47034960fdff5df495822ff66fbc1  renew.subscription
# 2  de91f1226dd938990fefc79545daf468  renew.subscription
# 3  bf14840a8cb4643e6d557da96e35a3af  renew.subscription
# 4  7ddc1c2990d0645d82885394e3c518b5  renew.subscription
#
#         client_event_time  plan_price  paid_amount  coupon_discount_amount  \
# 0 2022-09-08 03:05:02.068       15920        15920                       0
# 1 2022-09-08 03:40:02.050       15920        15920                       0
# 2 2022-09-08 03:49:00.829       42960        40812                    2148
# 3 2022-09-08 04:10:06.406       15920        15920                       0
# 4 2022-09-08 04:40:01.895       15920        15920                       0
#
#   pg_type
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15945 entries, 0 to 15944
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   city                    15575 non-null  object
#  1   client_event_time       15945 non-null  datetime64[ns]
#  2   country                 15656 non-null  object
#  3   device_family           15657 non-null  object
#  4   device_type             15484 non-null  object
#  5   event_type              15945 non-null  object
#  6   language                15657 non-null  object
#  7   os_name                 15654 non-null  object
#  8   os_version              15945 non-null  object
#  9   platform                15657 non-null  object
#  10  user_id                 15945 non-null  object
#  11  plan_price              15945 non-null  int64
#  12  paid_amount             15945 non-null  int64
#  13  coupon_discount_amount  15945 non-null  int64
#  14  pg_type                 2732 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(11)
# memory usage: 1.8+ MB
# None
#          city       client_event_time      country device_family device_type  \
# 0      Nam-gu 2022-09-08 03:05:02.068  South Korea       Windows     Windows
# 1      Nam-gu 2022-09-08 03:40:02.050  South Korea       Windows     Windows
# 2  Dongjak-gu 2022-09-08 03:49:00.829  South Korea       Windows     Windows
# 3   Yongin-si 2022-09-08 04:10:06.406  South Korea       Windows     Windows
# 4  Dongjak-gu 2022-09-08 04:40:01.895  South Korea       Android     Android
#
#            event_type language        os_name os_version platform  \
# 0  renew.subscription   Korean           Edge        104      Web
# 1  renew.subscription   Korean         Chrome        104      Web
# 2  renew.subscription   Korean         Chrome        104      Web
# 3  renew.subscription   Korean         Chrome        104      Web
# 4  renew.subscription   Korean  Chrome Mobile        103      Web
#
#                             user_id  plan_price  paid_amount  \
# 0  6ddea3af2eaae869861c1190dcc9d4a3       15920        15920
# 1  c2d47034960fdff5df495822ff66fbc1       15920        15920
# 2  de91f1226dd938990fefc79545daf468       42960        40812
# 3  bf14840a8cb4643e6d557da96e35a3af       15920        15920
# 4  7ddc1c2990d0645d82885394e3c518b5       15920        15920
#
#    coupon_discount_amount pg_type
# 0                       0     NaN
# 1                       0     NaN
# 2                    2148     NaN
# 3                       0     NaN
# 4                       0     NaN
#                             user_id          event_type  \
# 0  6ddea3af2eaae869861c1190dcc9d4a3  renew.subscription
# 1  c2d47034960fdff5df495822ff66fbc1  renew.subscription
# 2  de91f1226dd938990fefc79545daf468  renew.subscription
# 3  bf14840a8cb4643e6d557da96e35a3af  renew.subscription
# 4  7ddc1c2990d0645d82885394e3c518b5  renew.subscription
#
#         client_event_time  plan_price  paid_amount  coupon_discount_amount  \
# 0 2022-09-08 03:05:02.068       15920        15920                       0
# 1 2022-09-08 03:40:02.050       15920        15920                       0
# 2 2022-09-08 03:49:00.829       42960        40812                    2148
# 3 2022-09-08 04:10:06.406       15920        15920                       0
# 4 2022-09-08 04:40:01.895       15920        15920                       0
#
#   pg_type
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ['plan_price', 'paid_amount', 'coupon_discount_amount', 'pg_type']
#                             user_id                event_type  \
# 0  41362ad5ebcade2bb1b78344a53e7ccf  resubscribe.subscription
# 1  68831c27e47f0e8f04ba809baeec218e  resubscribe.subscription
# 2  4e7568cb7db01f8386614ec2c6c961cd  resubscribe.subscription
# 3  f91f19527b9ec688e028ec884b1b5c1c  resubscribe.subscription
# 4  2276d7d2a31e05f4a5558c6406cc36c9  resubscribe.subscription
#
#         client_event_time  plan_price  paid_amount  coupon_discount_amount  \
# 0 2023-04-05 21:11:45.525       15920        15920                       0
# 1 2023-06-30 09:59:56.848       15920        15920                       0
# 2 2023-06-13 06:20:22.524       15920        15920                       0
# 3 2023-06-11 11:02:11.878      131600       131600                       0
# 4 2023-06-13 14:39:25.736      131600       131600                       0
#
#   pg_type
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 791 entries, 0 to 790
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   city                    775 non-null    object
#  1   client_event_time       791 non-null    datetime64[ns]
#  2   country                 784 non-null    object
#  3   device_family           784 non-null    object
#  4   device_type             773 non-null    object
#  5   event_type              791 non-null    object
#  6   language                784 non-null    object
#  7   os_name                 784 non-null    object
#  8   os_version              791 non-null    object
#  9   platform                784 non-null    object
#  10  user_id                 791 non-null    object
#  11  plan_price              791 non-null    int64
#  12  paid_amount             791 non-null    int64
#  13  coupon_discount_amount  791 non-null    int64
#  14  pg_type                 173 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(11)
# memory usage: 92.8+ KB
# None
#          city       client_event_time      country  device_family  \
# 0     Daejeon 2023-04-05 21:11:45.525  South Korea        Windows
# 1       Seoul 2023-06-30 09:59:56.848  South Korea  Samsung Phone
# 2    Nowon-gu 2023-06-13 06:20:22.524  South Korea        Windows
# 3       Suwon 2023-06-11 11:02:11.878  South Korea        Windows
# 4  Koishikawa 2023-06-13 14:39:25.736        Japan   Apple iPhone
#
#            device_type                event_type  language         os_name  \
# 0              Windows  resubscribe.subscription    Korean            Edge
# 1  Samsung Galaxy S22+  resubscribe.subscription    Korean  Chrome WebView
# 2              Windows  resubscribe.subscription    Korean          Chrome
# 3              Windows  resubscribe.subscription    Korean          Chrome
# 4         Apple iPhone  resubscribe.subscription  Japanese          Chrome
#
#        os_version platform                           user_id  plan_price  \
# 0   111.0.1661.62      Web  41362ad5ebcade2bb1b78344a53e7ccf       15920
# 1  113.0.5672.162      Web  68831c27e47f0e8f04ba809baeec218e       15920
# 2       114.0.0.0      Web  4e7568cb7db01f8386614ec2c6c961cd       15920
# 3       114.0.0.0      Web  f91f19527b9ec688e028ec884b1b5c1c      131600
# 4   114.0.5735.99      Web  2276d7d2a31e05f4a5558c6406cc36c9      131600
#
#    paid_amount  coupon_discount_amount pg_type
# 0        15920                       0     NaN
# 1        15920                       0     NaN
# 2        15920                       0     NaN
# 3       131600                       0     NaN
# 4       131600                       0     NaN
#                             user_id                event_type  \
# 0  41362ad5ebcade2bb1b78344a53e7ccf  resubscribe.subscription
# 1  68831c27e47f0e8f04ba809baeec218e  resubscribe.subscription
# 2  4e7568cb7db01f8386614ec2c6c961cd  resubscribe.subscription
# 3  f91f19527b9ec688e028ec884b1b5c1c  resubscribe.subscription
# 4  2276d7d2a31e05f4a5558c6406cc36c9  resubscribe.subscription
#
#         client_event_time  plan_price  paid_amount  coupon_discount_amount  \
# 0 2023-04-05 21:11:45.525       15920        15920                       0
# 1 2023-06-30 09:59:56.848       15920        15920                       0
# 2 2023-06-13 06:20:22.524       15920        15920                       0
# 3 2023-06-11 11:02:11.878      131600       131600                       0
# 4 2023-06-13 14:39:25.736      131600       131600                       0
#
#   pg_type
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# []
#                             user_id                event_type  \
# 0  9e59ecf9a8fbe9051bd0d54f4b702f30  click.cancel_plan_button
# 1  4ed4d8f12c45504a148bfff0f2e9466e  click.cancel_plan_button
# 2  b6a1bba3cc4139d7dc821561319221e6  click.cancel_plan_button
# 3  40acc1ddfc012f3d2f58a3de95e9e748  click.cancel_plan_button
# 4  bdffe1f18684704d4ea2d7eebcaed180  click.cancel_plan_button
#
#         client_event_time
# 0 2023-04-10 14:57:48.556
# 1 2023-03-12 08:26:16.224
# 2 2023-03-12 08:23:04.955
# 3 2023-03-12 08:32:39.271
# 4 2023-04-12 11:36:28.311
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17895 entries, 0 to 17894
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   city               17742 non-null  object
#  1   client_event_time  17895 non-null  datetime64[ns]
#  2   country            17893 non-null  object
#  3   device_family      17895 non-null  object
#  4   device_type        17567 non-null  object
#  5   event_type         17895 non-null  object
#  6   language           17895 non-null  object
#  7   os_name            17895 non-null  object
#  8   os_version         17895 non-null  object
#  9   platform           17895 non-null  object
#  10  user_id            16853 non-null  object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 1.5+ MB
# None
#            city       client_event_time      country device_family  \
# 0         Daegu 2023-04-10 14:57:48.556  South Korea       Windows
# 1         Seoul 2023-03-12 08:26:16.224  South Korea    Apple iPad
# 2  Uijeongbu-si 2023-03-12 08:23:04.955  South Korea       Windows
# 3     Dobong-gu 2023-03-12 08:32:39.271  South Korea       Windows
# 4  Geumjeong-gu 2023-04-12 11:36:28.311  South Korea       Windows
#
#   device_type                event_type language        os_name os_version  \
# 0     Windows  click.cancel_plan_button   Korean         Chrome  111.0.0.0
# 1  Apple iPad  click.cancel_plan_button  English  Mobile Safari       16.3
# 2     Windows  click.cancel_plan_button   Korean         Chrome  110.0.0.0
# 3     Windows  click.cancel_plan_button   Korean         Chrome  110.0.0.0
# 4     Windows  click.cancel_plan_button   Korean         Chrome  111.0.0.0
#
#   platform                           user_id
# 0      Web  9e59ecf9a8fbe9051bd0d54f4b702f30
# 1      Web  4ed4d8f12c45504a148bfff0f2e9466e
# 2      Web  b6a1bba3cc4139d7dc821561319221e6
# 3      Web  40acc1ddfc012f3d2f58a3de95e9e748
# 4      Web  bdffe1f18684704d4ea2d7eebcaed180
#                             user_id                event_type  \
# 0  9e59ecf9a8fbe9051bd0d54f4b702f30  click.cancel_plan_button
# 1  4ed4d8f12c45504a148bfff0f2e9466e  click.cancel_plan_button
# 2  b6a1bba3cc4139d7dc821561319221e6  click.cancel_plan_button
# 3  40acc1ddfc012f3d2f58a3de95e9e748  click.cancel_plan_button
# 4  bdffe1f18684704d4ea2d7eebcaed180  click.cancel_plan_button
#
#         client_event_time
# 0 2023-04-10 14:57:48.556
# 1 2023-03-12 08:26:16.224
# 2 2023-03-12 08:23:04.955
# 3 2023-03-12 08:32:39.271
# 4 2023-04-12 11:36:28.311

# %%
# 각 유저가 처음 결제 페이지 들어간 시간
first_enter_pay_df = com_enter_pay_df.groupby('user_id')['client_event_time'].min()
first_enter_pay_df = first_enter_pay_df.reset_index()
first_enter_pay_df.head(5)
# Out:
#                             user_id       client_event_time
# 0  0000572f2ba8079bcefd2760b632e820 2023-03-18 10:34:12.788
# 1  000087537cbfd934375364218ff10f91 2023-03-27 05:14:47.532
# 2  0001f15911b404f3bf5b8571afafa4e4 2023-11-29 01:05:51.564
# 3  0001f28a707789a7d78dc28fd2e84dce 2023-10-15 15:09:35.679
# 4  0002cebfe69ec57026c34088069384ab 2022-11-18 11:17:18.213

# %%
first_enter_pay_date = first_enter_pay_df\
                        .groupby(first_enter_pay_df['client_event_time'].dt.date)\
                        .size()

# check head
display(first_enter_pay_date.head(5))

# day plot            
first_enter_pay_date.plot()
plt.show()

# week plot
first_enter_pay_date.rolling(min_periods=1, window=7).mean().plot()
plt.show()

# month plot
first_enter_pay_date.rolling(min_periods=1, window=50).mean().plot()
plt.show()
# Out:
# client_event_time
# 2022-11-03    146
# 2022-11-04    123
# 2022-11-05    118
# 2022-11-06    120
# 2022-11-07    190
# dtype: int64

# %%
print(f'first_subscript_df : {first_subscript_df.shape[0]}')
print(first_subscript_df.duplicated().sum())
print(f're_subscript_df : {re_subscript_df.shape[0]}')
print(re_subscript_df.duplicated().sum())
print(f'auto_pay_df : {auto_pay_df.shape[0]}')
print(auto_pay_df.duplicated().sum())

print("first_subscript_df, re_subscript_df")
temp = pd.merge(first_subscript_df, re_subscript_df
                , on=['user_id', 'client_event_time']
                , how='inner')
if temp.size > 0:
    temp = temp[['user_id', 'client_event_time']]
    display(temp)
    display(pd.merge(temp, first_subscript_df
                     , on=['user_id', 'client_event_time']
                     , how='inner'))
    display(pd.merge(temp, re_subscript_df
                     , on=['user_id', 'client_event_time']
                     , how='inner'))
    
print("auto_pay_df, re_subscript_df")
temp = pd.merge(auto_pay_df, re_subscript_df
                , on=['user_id', 'client_event_time']
                , how='inner')
if temp.size > 0:
    temp = temp[['user_id', 'client_event_time']]
    display(temp)
    display(pd.merge(temp, auto_pay_df
                     , on=['user_id', 'client_event_time']
                     , how='inner'))
    display(pd.merge(temp, re_subscript_df
                     , on=['user_id', 'client_event_time']
                     , how='inner'))

print("auto_pay_df, first_subscript_df")
temp = pd.merge(auto_pay_df, first_subscript_df
                , on=['user_id', 'client_event_time']
                , how='inner')
if temp.size > 0:
    temp = temp[['user_id', 'client_event_time']]
    display(temp)
    display(pd.merge(temp, auto_pay_df
                     , on=['user_id', 'client_event_time']
                     , how='inner'))
    display(pd.merge(temp, first_subscript_df
                     , on=['user_id', 'client_event_time']
                     , how='inner'))
# Out:
# first_subscript_df : 14289
# 2
# re_subscript_df : 791
# 0
# auto_pay_df : 15945
# 0
# first_subscript_df, re_subscript_df
# auto_pay_df, re_subscript_df
#                             user_id       client_event_time
# 0  0889fec8022c71328b877826576a764f 2022-11-18 02:49:40.687
#                             user_id       client_event_time         city  \
# 0  0889fec8022c71328b877826576a764f 2022-11-18 02:49:40.687  Gwangjin-gu
#
#        country device_family device_type          event_type language os_name  \
# 0  South Korea       Windows     Windows  renew.subscription   Korean  Chrome
#
#   os_version platform  plan_price  paid_amount  coupon_discount_amount pg_type
# 0  107.0.0.0      Web       15920        15442                     478     NaN
#                             user_id       client_event_time         city  \
# 0  0889fec8022c71328b877826576a764f 2022-11-18 02:49:40.687  Gwangjin-gu
#
#        country device_family device_type                event_type language  \
# 0  South Korea       Windows     Windows  resubscribe.subscription   Korean
#
#   os_name os_version platform  plan_price  paid_amount  \
# 0  Chrome  107.0.0.0      Web       15920        15442
#
#    coupon_discount_amount pg_type
# 0                     478     NaN
# auto_pay_df, first_subscript_df
#                             user_id       client_event_time
# 0  7fb2da7924c07cc24515000c9d2f237a 2022-09-24 01:45:02.179
# 1  2466261a18d5757e8504ff8045d4b0e1 2022-09-24 13:09:30.345
# 2  7f6ac355cd862e7361735903b53f1c92 2022-09-26 10:20:01.953
# 3  08e0a0b1e7ae39f10cba93cfbfec6ec1 2022-11-11 17:10:01.825
# 4  6b889dac8d1646374b43ccd0130182ff 2022-11-17 08:45:02.108
#                             user_id       client_event_time        city  \
# 0  7fb2da7924c07cc24515000c9d2f237a 2022-09-24 01:45:02.179     Mapo-gu
# 1  2466261a18d5757e8504ff8045d4b0e1 2022-09-24 13:09:30.345       Seoul
# 2  7f6ac355cd862e7361735903b53f1c92 2022-09-26 10:20:01.953      Sejong
# 3  08e0a0b1e7ae39f10cba93cfbfec6ec1 2022-11-11 17:10:01.825  Gangnam-gu
# 4  6b889dac8d1646374b43ccd0130182ff 2022-11-17 08:45:02.108       Seoul
#
#        country device_family device_type          event_type language os_name  \
# 0  South Korea           Mac         Mac  renew.subscription   Korean  Chrome
# 1  South Korea           Mac         Mac  renew.subscription   Korean  Safari
# 2  South Korea         Linux       Linux  renew.subscription   Korean  Chrome
# 3  South Korea       Windows     Windows  renew.subscription   Korean  Chrome
# 4  South Korea           Mac         Mac  renew.subscription   Korean  Chrome
#
#   os_version platform  plan_price  paid_amount  coupon_discount_amount pg_type
# 0        105      Web       15920        15920                       0     NaN
# 1         14      Web       15920        15920                       0     NaN
# 2         91      Web       15920        15920                       0     NaN
# 3        107      Web       15920        15920                       0     NaN
# 4  107.0.0.0      Web      131600       131600                       0     NaN
#                             user_id       client_event_time        city  \
# 0  7fb2da7924c07cc24515000c9d2f237a 2022-09-24 01:45:02.179     Mapo-gu
# 1  2466261a18d5757e8504ff8045d4b0e1 2022-09-24 13:09:30.345       Seoul
# 2  7f6ac355cd862e7361735903b53f1c92 2022-09-26 10:20:01.953      Sejong
# 3  08e0a0b1e7ae39f10cba93cfbfec6ec1 2022-11-11 17:10:01.825  Gangnam-gu
# 4  6b889dac8d1646374b43ccd0130182ff 2022-11-17 08:45:02.108       Seoul
#
#        country device_family device_type             event_type language  \
# 0  South Korea           Mac         Mac  complete.subscription   Korean
# 1  South Korea           Mac         Mac  complete.subscription   Korean
# 2  South Korea         Linux       Linux  complete.subscription   Korean
# 3  South Korea       Windows     Windows  complete.subscription   Korean
# 4  South Korea           Mac         Mac  complete.subscription   Korean
#
#   os_name os_version platform  plan_price  paid_amount  \
# 0  Chrome        105      Web       15920        15920
# 1  Safari         14      Web       15920        15920
# 2  Chrome         91      Web       15920        15920
# 3  Chrome        107      Web       15920        15920
# 4  Chrome  107.0.0.0      Web      131600       131600
#
#    coupon_discount_amount pg_type
# 0                       0     NaN
# 1                       0     NaN
# 2                       0     NaN
# 3                       0     NaN
# 4                       0     NaN

# %% [markdown]
# 첫 결제와 정기 결제는 겹치는게 없음\
# 만료후 재구독은 다른 두 데이터에서 겹치는 부분이 있지만\
# 수가 적고 데이터의 초기 부분이라 초기 운영의 오류의 수 있음

# %%
temp1 = first_subscript_df.groupby('user_id')['client_event_time'].min()
temp2 = auto_pay_df.groupby('user_id')['client_event_time'].min()
temp3 = re_subscript_df.groupby('user_id')['client_event_time'].min()

# %%
print(temp1.shape[0])
print(temp2.shape[0])

# merge first_subscript_df and auto_pay_df
result = pd.merge(temp1, temp2, how='inner', on='user_id')\
    .reset_index()\
    .rename(columns={'client_event_time_x' : 'first_subscript_date', 'client_event_time_y' : 'auto_pay_date'})
print(result.shape[0])

# Create a new column 'diff' in the result DataFrame
result['diff'] = result['first_subscript_date'] - result['auto_pay_date']
result['diff'] = result['diff'].dt.total_seconds()
result['diff'] = result['diff']

# 날짜 대소 비교
temp = result[result['diff'].abs() < 600]
display(temp)
display(temp['diff'].describe())
temp = result[result['diff'].abs() >= 600]
display(temp)
display(temp['diff'].describe())
# Out:
# 13881
# 7498
# 5385
#                                user_id    first_subscript_date  \
# 9     00713a0e97135815ea700dfe82ce49fb 2022-10-07 15:40:01.797
# 18    010a4a8efd5fd2528719b5bd8098286a 2022-10-07 00:30:02.524
# 21    0126ad7cca27944f9856d7c6ec5974b5 2022-10-03 01:20:01.864
# 24    01449049533c7dfe50cdfbdb605410e2 2022-11-06 19:05:02.671
# 27    0157e1eaf2645e7d4de1fba14fe72a0f 2022-10-10 02:40:01.405
# ...                                ...                     ...
# 5312  fc52c92792b44f3f461ddc1167aa90a1 2022-11-07 01:15:01.136
# 5319  fcdf96b4de5958aeabf554e6f7e9daec 2022-09-28 02:10:02.126
# 5324  fd35e6f4c96e4f1d2b5ebd12ef26bced 2022-10-09 10:00:03.650
# 5337  fdb13da083ec2460c8ab4dd4218363a0 2022-11-06 08:00:02.938
# 5351  fe47fabc4baa52ef9f85cd749349a33f 2022-09-25 15:10:01.739
#
#                auto_pay_date   diff
# 9    2022-10-07 15:40:01.779  0.018
# 18   2022-10-07 00:30:02.004  0.520
# 21   2022-10-03 01:20:02.723 -0.859
# 24   2022-11-06 19:05:02.672 -0.001
# 27   2022-10-10 02:40:01.533 -0.128
# ...                      ...    ...
# 5312 2022-11-07 01:15:01.644 -0.508
# 5319 2022-09-28 02:10:01.625  0.501
# 5324 2022-10-09 10:00:02.763  0.887
# 5337 2022-11-06 08:00:02.412  0.526
# 5351 2022-09-25 15:10:02.621 -0.882
#
# [479 rows x 4 columns]
# count    479.000000
# mean      -1.350777
# std       23.333267
# min     -451.367000
# 25%       -0.019000
# 50%        0.013000
# 75%        0.520000
# max        1.411000
# Name: diff, dtype: float64
#                                user_id    first_subscript_date  \
# 0     0000572f2ba8079bcefd2760b632e820 2023-03-25 14:40:01.647
# 1     000be07bc09ceff42c11978f4a9f1c1a 2022-08-20 13:05:01.083
# 2     001ddbe4885db89888b34bf0eb14f6e1 2022-04-10 06:02:28.859
# 3     002109ba574914ed127dcae867110f91 2022-02-17 02:39:54.910
# 4     0031482d16469048027f6096d13c8b22 2023-09-10 23:34:21.696
# ...                                ...                     ...
# 5380  ffa1cfa6bc3b410a927be11e23ff5340 2022-12-19 12:50:01.076
# 5381  ffb19e67ac35d18a6711c55d2ace39ba 2022-08-10 05:25:22.823
# 5382  ffe13db0ad3751c9be06a73aa38bc9fc 2022-09-08 02:35:01.476
# 5383  ffe3e486f61399d62d83727e53a850dc 2022-07-30 06:04:32.692
# 5384  fffadab35ddc8234e1c5139815bfc017 2023-09-10 03:16:01.197
#
#                auto_pay_date          diff
# 0    2023-04-25 14:45:01.747 -2.678700e+06
# 1    2022-11-20 13:10:01.891 -7.949101e+06
# 2    2023-01-21 09:00:05.092 -2.472106e+07
# 3    2023-02-17 08:10:06.967 -3.155581e+07
# 4    2023-10-10 23:35:02.550 -2.592041e+06
# ...                      ...           ...
# 5380 2023-12-31 14:42:16.966 -3.257954e+07
# 5381 2022-09-10 05:30:02.277 -2.678679e+06
# 5382 2022-10-08 02:40:02.035 -2.592301e+06
# 5383 2023-07-31 02:03:05.911 -3.160791e+07
# 5384 2023-10-17 03:20:02.210 -3.197041e+06
#
# [4906 rows x 4 columns]
# count    4.906000e+03
# mean    -8.818868e+06
# std      1.033928e+07
# min     -5.812338e+07
# 25%     -9.797943e+06
# 50%     -2.768429e+06
# 75%     -2.592301e+06
# max     -6.000720e+02
# Name: diff, dtype: float64

# %% [markdown]
# 첫 구독과 정기 결제가 시간적으로 동일한(오차 1초 이내) 데이터가 존재한다.
# 두 데이터는 일부분 겹친다.\
# 첫구독은 언제나 구독날짜가 동일하거나 앞서있다.

# %%
print(temp2.shape[0])
print(temp3.shape[0])

# merge re_subscript_df and auto_pay_df
result = pd.merge(temp2, temp3, how='inner', on='user_id')\
    .reset_index()\
    .rename(columns={'client_event_time_x' : 'auto_pay_date', 'client_event_time_y' : 're_subscript_date'})
print(result.shape[0])

# Create a new column 'diff' in the result DataFrame
result['diff'] = result['auto_pay_date'] - result['re_subscript_date']
result['diff'] = result['diff'].dt.total_seconds()
result['diff'] = result['diff']

# 날짜 대소 비교
temp = result[result['diff'].abs() < 600]
display(temp)
display(temp['diff'].describe())
temp = result[result['diff'].abs() >= 600]
display(temp)
display(temp['diff'].describe())
# Out:
# 7498
# 761
# 511
#                               user_id           auto_pay_date  \
# 2    01420e0a936792dbdcabad14fe9fece1 2022-11-13 10:05:13.135
# 18   04230eb1c628b99fb70aa483344e47ad 2022-11-13 04:39:41.375
# 24   0772cb88d17b51d6822f12f315ba6687 2022-11-19 08:21:36.490
# 28   0889fec8022c71328b877826576a764f 2022-11-18 02:49:40.687
# 51   1562a3b4d08ee3c44e068009fe01cbbe 2022-11-13 17:14:21.671
# 57   1be14d4ed3bef4e82d3a2331ace77dc1 2022-11-08 10:50:44.742
# 71   23a69672ced44709d2790430b6fecf33 2022-11-29 08:37:26.761
# 98   35588439329bcfa58841c588aba35201 2023-08-01 05:48:02.091
# 106  3966266887fba64584a2c890fd7400d5 2022-11-12 04:48:28.011
# 129  4591c8f94f84533e7013713d9302a70b 2022-11-11 07:16:59.188
# 166  5742aa3f4f18772f6b9acff5895758cc 2022-11-13 04:30:29.110
# 173  599774b767c03563638c00501eb844e7 2022-11-30 14:53:10.002
# 198  688a59aa0378a80cf660175bd6d2e226 2022-11-08 14:58:55.112
# 217  70617254d04166160cd6c52284a6ce8a 2022-11-24 12:14:27.640
# 221  717493271ccd4309a4cf7becf3080973 2022-11-25 15:36:09.149
# 238  78c83cee9e56d24ab0cc886a70ccc573 2022-11-16 02:55:20.058
# 274  8c632d570bc5a4c8d52c120df6fc0432 2023-07-28 04:23:15.446
# 276  8cca5a51f68890467dfe0aa53b81924c 2022-11-09 03:21:52.675
# 305  9d42cbfd17c1f8604bbce524eda6de1b 2022-11-28 05:04:42.870
# 308  9d9ef24bed7e145ab1e7a82e209dcbdc 2022-11-25 06:56:03.530
# 336  ae9b7fac6126da5c47983595db2d5132 2022-11-28 00:25:32.070
# 337  afc1e9fb08cea0fdad30f71b1f3998ca 2022-11-13 23:03:21.196
# 344  b2cfb8768c84d9be57b17155875120aa 2022-11-15 16:21:47.632
# 378  c04348357725a6139bc5e18216a3d2a2 2022-11-13 10:42:23.777
# 395  c9ca83ec5f91a308ef458d2745819b77 2022-11-10 14:42:56.190
# 445  e10d0ae73a5b9881ff3194b7723aad1d 2022-11-11 22:44:17.960
# 450  e338e71d34b6e5e7a80ddcaabdcc483e 2022-11-26 08:43:48.475
# 467  ea08d0030696141e2ec26b54b5fd2ee1 2022-11-19 04:12:02.757
# 480  f2bae016fcb02eba23bee7b36f272d11 2022-11-28 02:27:10.680
#
#           re_subscript_date     diff
# 2   2022-11-13 10:05:13.681   -0.546
# 18  2022-11-13 04:39:42.825   -1.450
# 24  2022-11-19 08:21:36.503   -0.013
# 28  2022-11-18 02:49:40.687    0.000
# 51  2022-11-13 17:14:21.661    0.010
# 57  2022-11-08 10:50:43.860    0.882
# 71  2022-11-29 08:37:27.293   -0.532
# 98  2023-08-01 05:40:11.642  470.449
# 106 2022-11-12 04:48:28.116   -0.105
# 129 2022-11-11 07:16:59.748   -0.560
# 166 2022-11-13 04:30:29.109    0.001
# 173 2022-11-30 14:53:10.507   -0.505
# 198 2022-11-08 14:58:55.689   -0.577
# 217 2022-11-24 12:14:29.048   -1.408
# 221 2022-11-25 15:36:09.156   -0.007
# 238 2022-11-16 02:55:20.589   -0.531
# 274 2023-07-28 04:15:17.273  478.173
# 276 2022-11-09 03:21:54.340   -1.665
# 305 2022-11-28 05:04:43.412   -0.542
# 308 2022-11-25 06:56:03.539   -0.009
# 336 2022-11-28 00:25:31.211    0.859
# 337 2022-11-13 23:03:20.800    0.396
# 344 2022-11-15 16:21:47.631    0.001
# 378 2022-11-13 10:42:25.173   -1.396
# 395 2022-11-10 14:42:56.192   -0.002
# 445 2022-11-11 22:44:18.107   -0.147
# 450 2022-11-26 08:43:48.092    0.383
# 467 2022-11-19 04:12:03.189   -0.432
# 480 2022-11-28 02:27:11.145   -0.465
# count     29.000000
# mean      32.422828
# std      122.401396
# min       -1.665000
# 25%       -0.542000
# 50%       -0.105000
# 75%        0.001000
# max      478.173000
# Name: diff, dtype: float64
#                               user_id           auto_pay_date  \
# 0    0108538a502bb0339cdee7d33f96a510 2023-02-01 01:05:26.946
# 1    010a54b7adcb47015c5813cf8509461e 2022-09-20 12:30:50.004
# 3    0169c3e54cbd0d8b35d7dd59b40ca65c 2022-10-13 06:00:07.462
# 4    01946f0541feaf69418576cd1f77e321 2022-10-13 03:00:01.358
# 5    01bb08e6b27802710bb8421493ae3688 2023-09-10 12:40:03.073
# ..                                ...                     ...
# 506  ff27c0ef4f7c2c87a09e295c496727f5 2023-07-25 02:35:02.556
# 507  ff917e8b6bcf53a48bd1b1efae5d00f5 2023-09-25 03:20:03.315
# 508  ff9bb243eff83d84e2cb289ff629aba8 2023-08-25 07:03:48.454
# 509  ffe13db0ad3751c9be06a73aa38bc9fc 2022-10-08 02:40:02.035
# 510  fffe529de03d6187ef7ed765650c8d2b 2023-04-08 12:45:01.546
#
#           re_subscript_date          diff
# 0   2023-11-27 00:03:46.443 -2.582990e+07
# 1   2023-04-13 03:36:01.458 -1.767991e+07
# 3   2022-09-13 05:59:00.147  2.592067e+06
# 4   2023-07-10 02:22:25.467 -2.332574e+07
# 5   2023-08-10 12:35:25.240  2.678678e+06
# ..                      ...           ...
# 506 2023-12-18 05:11:13.874 -1.262377e+07
# 507 2022-09-25 03:17:16.348  3.153617e+07
# 508 2023-07-25 06:31:11.205  2.680357e+06
# 509 2023-08-19 13:29:33.039 -2.725497e+07
# 510 2023-12-30 08:44:49.356 -2.296799e+07
#
# [482 rows x 4 columns]
# count    4.820000e+02
# mean    -6.401387e+06
# std      1.270910e+07
# min     -3.965727e+07
# 25%     -1.596852e+07
# 50%      2.592007e+06
# 75%      2.678587e+06
# max      3.153617e+07
# Name: diff, dtype: float64

# %% [markdown]
# 정기 결제와 재 구독은 겹치지 않는다.

# %%
print(temp1.shape[0])
print(temp3.shape[0])

result = pd.merge(temp1, temp3, how='inner', on='user_id')\
    .reset_index()\
    .rename(columns={'client_event_time_x' : 'first_subscript_date', 'client_event_time_y' : 're_subscript_date'})
print(result.shape[0])

result['diff'] = result['re_subscript_date'] - result['first_subscript_date']
result['diff'] = result['diff'].dt.total_seconds()
result['diff'] = result['diff']

# 날짜 대소 비교
temp = result[result['diff'].abs() < 600]
display(temp)
display(temp['diff'].describe())
temp = result[result['diff'].abs() >= 600]
display(temp)
display(temp['diff'].describe())
# Out:
# 13881
# 761
# 402
#                               user_id    first_subscript_date  \
# 7    0308b8ea736768f9399d3b81d34b00a0 2022-10-17 12:11:11.485
# 41   182f52b6dcc8288afce0a629b4de3a9f 2022-10-18 08:00:02.292
# 43   1a9bc9f6ba2ab755b45b04d981555ba5 2022-10-02 23:20:15.717
# 49   1d8c3941b13b5fd9969bbf2a350bc8cf 2022-10-25 02:06:12.900
# 51   1da0b4afbbf62bbfa74e8e22c710919c 2022-11-01 10:10:33.510
# 59   2466261a18d5757e8504ff8045d4b0e1 2022-09-24 07:43:38.349
# 63   274b46e35dfbfd919ef8ec923a3a16bb 2022-11-13 01:56:11.643
# 77   308ee0950741e4321045d0ba604778de 2022-09-12 02:09:15.703
# 84   374312364e615be115ae0b43759a2b72 2022-10-01 14:09:51.447
# 104  41aa0116e4ddf9f13e4ccabd7f1f8040 2022-10-01 10:38:26.892
# 172  692b648a6fe4672c5110d4bf4bee6124 2022-09-08 12:59:40.320
# 222  83fdb635b9e43b97791535b002490544 2022-10-15 13:56:58.280
# 249  99f5e31e874060cb7d602b389d015b05 2022-10-17 13:22:25.892
# 269  a5d058da1cd5978936f51a4d82633c2d 2022-10-13 05:59:30.181
# 272  a7c1e2e4d881d8b5e8967d431f8c3c6f 2022-11-19 17:41:49.244
# 279  af3b13bc0841b358adcdedf3e8822795 2022-09-08 05:42:30.429
# 318  c6f9e470833856d4c58147b9fd1fdca7 2022-10-23 13:20:28.669
# 332  d0a1dc518a5fd6508d98b86c031fd964 2022-10-06 13:33:53.658
# 335  d124f58c350f43f04092146be76736d4 2022-10-09 14:57:23.909
# 340  d2b582b1eaceb13d00fa6f6edf9cac18 2022-10-20 08:47:13.227
# 351  dd038cd3b6630a91bf870d338b45d3a6 2022-09-22 23:17:07.202
# 387  f769a6729d255e44a96531827d0ffd57 2022-10-28 06:18:31.594
#
#           re_subscript_date   diff
# 7   2022-10-17 12:11:11.486  0.001
# 41  2022-10-18 08:00:02.816  0.524
# 43  2022-10-02 23:20:14.827 -0.890
# 49  2022-10-25 02:06:13.336  0.436
# 51  2022-11-01 10:10:34.409  0.899
# 59  2022-09-24 07:43:38.321 -0.028
# 63  2022-11-13 01:56:11.784  0.141
# 77  2022-09-12 02:09:15.193 -0.510
# 84  2022-10-01 14:09:50.556 -0.891
# 104 2022-10-01 10:38:27.442  0.550
# 172 2022-09-08 12:59:39.784 -0.536
# 222 2022-10-15 13:56:58.288  0.008
# 249 2022-10-17 13:22:25.876 -0.016
# 269 2022-10-13 05:59:29.670 -0.511
# 272 2022-11-19 17:41:49.237 -0.007
# 279 2022-09-08 05:42:29.912 -0.517
# 318 2022-10-23 13:20:28.678  0.009
# 332 2022-10-06 13:33:53.661  0.003
# 335 2022-10-09 14:57:23.388 -0.521
# 340 2022-10-20 08:47:12.704 -0.523
# 351 2022-09-22 23:17:07.196 -0.006
# 387 2022-10-28 06:18:32.095  0.501
# count    22.000000
# mean     -0.085636
# std       0.482698
# min      -0.891000
# 25%      -0.515500
# 50%      -0.006500
# 75%       0.108000
# max       0.899000
# Name: diff, dtype: float64
#                               user_id    first_subscript_date  \
# 0    010a54b7adcb47015c5813cf8509461e 2022-07-18 00:53:24.343
# 1    01420e0a936792dbdcabad14fe9fece1 2022-02-19 03:27:16.121
# 2    01946f0541feaf69418576cd1f77e321 2022-10-13 03:00:01.875
# 3    0221a206c47958f0983da6875b7c8e0f 2022-06-15 17:34:51.345
# 4    0292f9b9e5eee6d5419862b20151993e 2023-07-27 10:03:51.920
# ..                                ...                     ...
# 397  fe551a948c862c220158e34d3bc2bc47 2023-08-01 05:23:00.896
# 398  ff27c0ef4f7c2c87a09e295c496727f5 2023-06-25 02:30:40.699
# 399  ff386ac202b4d9791259039e8f5879f4 2023-07-23 04:03:59.033
# 400  ff9bb243eff83d84e2cb289ff629aba8 2023-03-22 06:30:01.899
# 401  ffe13db0ad3751c9be06a73aa38bc9fc 2022-09-08 02:35:01.476
#
#           re_subscript_date          diff
# 0   2023-04-13 03:36:01.458  2.325136e+07
# 1   2022-11-13 10:05:13.681  2.309268e+07
# 2   2023-07-10 02:22:25.467  2.332574e+07
# 3   2022-10-25 08:36:09.184  1.137248e+07
# 4   2023-11-07 04:56:51.178  8.880779e+06
# ..                      ...           ...
# 397 2023-12-19 06:26:21.393  1.209980e+07
# 398 2023-12-18 05:11:13.874  1.521603e+07
# 399 2023-12-23 09:30:13.106  1.323877e+07
# 400 2023-07-25 06:31:11.205  1.080007e+07
# 401 2023-08-19 13:29:33.039  2.984727e+07
#
# [380 rows x 4 columns]
# count    3.800000e+02
# mean     2.275585e+07
# std      1.319475e+07
# min      4.046058e+06
# 25%      1.217153e+07
# 50%      1.871865e+07
# 75%      3.264609e+07
# max      5.720753e+07
# Name: diff, dtype: float64

# %% [markdown]
# 첫 구독과 재구독가 시간적으로 동일한(오차 1초 이내) 데이터가 존재한다.
# 두 데이터는 일부분 겹친다.\
# 첫구독은 언제나 구독날짜가 동일하거나 앞서있다.

# %%
# get too close log
check_too_close_log
# Out:
# <function __main__.check_too_close_log(df, offset=1)>

# %%
temp = first_subscript_df.groupby('user_id')['user_id'].count()
temp[temp > 1].sort_values(ascending=False)
# Out:
# user_id
# 3767d4c7a827422fccf61d45ae889669    8
# f833cca4c382ac8c502c6f99bc432725    6
# ccea16701cf72a9027d7d5f2c3d3019c    5
# e04c24e899b1e875ed432a7b398a4308    4
# 1718432f54ebca48832fc7ee9a82810e    3
#                                    ..
# 5817b1cfddd5cf26d9060b21949e526d    2
# 5802bceee9ecedf9a8b5608598bc19e0    2
# 57d0d79f7f708d49bcb33e24d7ba1e78    2
# 57ccaec293dd573fcd8d7697919719a6    2
# ffe3e486f61399d62d83727e53a850dc    2
# Name: user_id, Length: 361, dtype: int64

# %%
## set
# union all the pay data and compact
total_pay_df = pd.concat([first_subscript_df, re_subscript_df, auto_pay_df], axis=0).reset_index(drop=True)
total_pay_df = total_pay_df[['user_id', 'client_event_time', 'event_type']]

# sort by event time
total_pay_df = total_pay_df.sort_values(['user_id', 'client_event_time'])

# display
display(f'first_subscript_df : {first_subscript_df.shape[0]}')
display(f're_subscript_df : {re_subscript_df.shape[0]}')
display(f'auto_pay_df : {auto_pay_df.shape[0]}')
display(total_pay_df.shape[0])

temp = total_pay_df.groupby('user_id').count()
temp = temp[temp['client_event_time'] > 1]
mask = total_pay_df['user_id'].isin(temp.index)
display(total_pay_df[mask].head(25))

## process
# check too close log
temp = total_pay_df.groupby('user_id')['client_event_time'].diff().dt.total_seconds()
temp = temp.dropna().astype('float64')
display(temp)

too_close_log_index = temp[temp < 60].index
first_log_index = total_pay_df.groupby('user_id')['client_event_time'].idxmin().values

## get too close log
# mask : first + too close log
first_log_index = total_pay_df.groupby('user_id')['client_event_time'].idxmin().values
mask = list(first_log_index) + list(too_close_log_index)
mask = list(set(mask))
mask = total_pay_df.index.isin(mask)

# get only 'count() > 1' user
temp = total_pay_df[mask]
temp = temp.groupby('user_id')['user_id'].count()
too_close_log_user = temp[temp > 1].index

# get too close log in total_pay_df
result = total_pay_df[mask]
result = result[result['user_id'].isin(too_close_log_user)]
display(result)

# value count
result.groupby('user_id')['event_type'].sum().str.replace('.subscription', ', ').value_counts()
# Out:
# 'first_subscript_df : 14289'
# 're_subscript_df : 791'
# 'auto_pay_df : 15945'
# 31025
#                                 user_id       client_event_time  \
# 3179   0000572f2ba8079bcefd2760b632e820 2023-03-25 14:40:01.647
# 22508  0000572f2ba8079bcefd2760b632e820 2023-04-25 14:45:01.747
# 23150  0000572f2ba8079bcefd2760b632e820 2023-05-25 14:50:01.753
# 3628   000be07bc09ceff42c11978f4a9f1c1a 2022-08-20 13:05:01.083
# 17585  000be07bc09ceff42c11978f4a9f1c1a 2022-11-20 13:10:01.891
# 20605  000be07bc09ceff42c11978f4a9f1c1a 2023-01-25 06:16:22.464
# 4645   001ddbe4885db89888b34bf0eb14f6e1 2022-04-10 06:02:28.859
# 20473  001ddbe4885db89888b34bf0eb14f6e1 2023-01-21 09:00:05.092
# 5796   002109ba574914ed127dcae867110f91 2022-02-17 02:39:54.910
# 21319  002109ba574914ed127dcae867110f91 2023-02-17 08:10:06.967
# 11634  0031482d16469048027f6096d13c8b22 2023-09-10 23:34:21.696
# 27648  0031482d16469048027f6096d13c8b22 2023-10-10 23:35:02.550
# 28911  0031482d16469048027f6096d13c8b22 2023-11-14 01:17:34.595
# 30022  0031482d16469048027f6096d13c8b22 2023-12-14 01:20:01.773
# 9393   003d94a1c1aacab781d2f811503fc806 2022-12-04 14:46:38.202
# 29666  003d94a1c1aacab781d2f811503fc806 2023-12-06 12:12:50.273
# 14059  003dc1089ee8075dfe8aab161efc6188 2023-08-15 10:07:27.355
# 26670  003dc1089ee8075dfe8aab161efc6188 2023-09-15 10:10:01.759
# 27890  003dc1089ee8075dfe8aab161efc6188 2023-10-15 10:15:01.452
# 266    004cf75983af1fead9ecf6815b5da6ce 2023-02-22 23:15:01.786
# 21886  004cf75983af1fead9ecf6815b5da6ce 2023-03-22 23:20:01.828
# 22489  004cf75983af1fead9ecf6815b5da6ce 2023-04-24 10:35:50.331
# 23393  004cf75983af1fead9ecf6815b5da6ce 2023-06-05 10:45:16.058
# 24118  004cf75983af1fead9ecf6815b5da6ce 2023-07-05 10:50:02.518
# 3060   0052fcc7e62a04f47a1b23c3488d31a0 2023-05-23 15:38:01.369
#
#                   event_type
# 3179   complete.subscription
# 22508     renew.subscription
# 23150     renew.subscription
# 3628   complete.subscription
# 17585     renew.subscription
# 20605     renew.subscription
# 4645   complete.subscription
# 20473     renew.subscription
# 5796   complete.subscription
# 21319     renew.subscription
# 11634  complete.subscription
# 27648     renew.subscription
# 28911     renew.subscription
# 30022     renew.subscription
# 9393   complete.subscription
# 29666     renew.subscription
# 14059  complete.subscription
# 26670     renew.subscription
# 27890     renew.subscription
# 266    complete.subscription
# 21886     renew.subscription
# 22489     renew.subscription
# 23393     renew.subscription
# 24118     renew.subscription
# 3060   complete.subscription
# 22508    2.678700e+06
# 23150    2.592300e+06
# 17585    7.949101e+06
# 20605    5.677581e+06
# 20473    2.472106e+07
#              ...
# 22768    2.592300e+06
# 23466    2.678700e+06
# 25174    5.152425e+06
# 27086    4.406328e+06
# 14849    8.138235e+06
# Name: client_event_time, Length: 14878, dtype: float64
#                                 user_id       client_event_time  \
# 16202  00713a0e97135815ea700dfe82ce49fb 2022-10-07 15:40:01.779
# 7743   00713a0e97135815ea700dfe82ce49fb 2022-10-07 15:40:01.797
# 16164  010a4a8efd5fd2528719b5bd8098286a 2022-10-07 00:30:02.004
# 9532   010a4a8efd5fd2528719b5bd8098286a 2022-10-07 00:30:02.524
# 4691   0126ad7cca27944f9856d7c6ec5974b5 2022-10-03 01:20:01.864
# ...                                 ...                     ...
# 7574   fdb13da083ec2460c8ab4dd4218363a0 2022-11-06 08:00:02.938
# 9281   fdd65930c3cb37b64725377df0a7b380 2022-11-17 06:20:03.725
# 9282   fdd65930c3cb37b64725377df0a7b380 2022-11-17 06:20:03.875
# 8131   fe47fabc4baa52ef9f85cd749349a33f 2022-09-25 15:10:01.739
# 15744  fe47fabc4baa52ef9f85cd749349a33f 2022-09-25 15:10:02.621
#
#                   event_type
# 16202     renew.subscription
# 7743   complete.subscription
# 16164     renew.subscription
# 9532   complete.subscription
# 4691   complete.subscription
# ...                      ...
# 7574   complete.subscription
# 9281   complete.subscription
# 9282   complete.subscription
# 8131   complete.subscription
# 15744     renew.subscription
#
# [1213 rows x 3 columns]
# event_type
# renew, complete,                     259
# complete, renew,                     190
# complete, complete,                   48
# complete, resubscribe,                22
# renew, complete, complete,            21
# renew, resubscribe,                   10
# resubscribe, complete,                10
# complete, renew, complete,             6
# complete, renew, renew,                5
# renew, complete, renew,                5
# resubscribe, renew,                    4
# resubscribe, complete, renew,          1
# complete, resubscribe, complete,       1
# renew, complete, renew, renew,         1
# resubscribe, complete, complete,       1
# complete, complete, renew,             1
# Name: count, dtype: int64

# %% [markdown]
# #### 데이터 통합

# %%
if len(DF) > 0:
    DF = []

DF = pd.concat(dfs[:9] + dfs[10:], axis=0).reset_index(drop=True)
print(DF.shape[0])

encoder_dict = dict()
DF['os_version'] = DF['os_version'].astype(str)
col_unique_dict['os_version'] = { str(x) for x in list(col_unique_dict['os_version']) }

for col in DF.columns:
    # exception handling
    if col in ['client_event_time', 'device_carrier']:
        continue
    
    
    print(f"\n\n{col}")
    
    # label encoding
    le = LabelEncoder()
    le = le.fit([ None, np.nan ] + list(col_unique_dict[col]))
    
    # update encoder_dict
    encoder_dict[col] = le
    
    # update DF
    DF[col] = le.transform(DF[col])
    
    # display
    display(DF[col].value_counts())
    
DF
# Out:
# 9751911
#
#
# city
# city
# 3439    1915512
# 3435     345250
# 4340     342851
# 3693     310560
# 1227     289517
#          ...
# 1465          1
# 1516          1
# 1269          1
# 3348          1
# 4108          1
# Name: count, Length: 4286, dtype: int64
# country
# country
# 157    9321855
# 189     210475
# 180      64511
# 84       27114
# 30       19886
#         ...
# 89           1
# 102          1
# 37           1
# 117          1
# 122          1
# Name: count, Length: 189, dtype: int64
# device_family
# device_family
# 1028    5834483
# 569     1560914
# 134      873957
# 772      494877
# 128      371959
#          ...
# 260           1
# 655           1
# 674           1
# 780           1
# 301           1
# Name: count, Length: 1118, dtype: int64
# device_type
# device_type
# 608    5834483
# 157    1560914
# 37      667688
# 3       371959
# 652     277591
#         ...
# 582          1
# 223          1
# 170          1
# 374          1
# 596          1
# Name: count, Length: 652, dtype: int64
# event_type
# event_type
# 4     2826034
# 10    2133548
# 8     1914257
# 3     1379136
# 12     596829
# 2      172911
# 11     165061
# 5      145133
# 15     124917
# 7      120582
# 1       93962
# 16      30621
# 0       17895
# 13      15945
# 6       14289
# 14        791
# Name: count, dtype: int64
# language
# language
# 37    9133166
# 14     459437
# 71     131294
# 32      10897
# 9        3621
#        ...
# 8           1
# 59          1
# 62          1
# 60          1
# 33          1
# Name: count, Length: 71, dtype: int64
# os_name
# os_name
# 3     6091683
# 9      986382
# 22     508092
# 33     393228
# 39     341653
# 16     334088
# 34     315881
# 6      198861
# 5      156689
# 44     134022
# 38     110246
# 11      58070
# 4       54052
# 12      38803
# 14      19582
# 25       3931
# 40       2591
# 2        1643
# 1         747
# 19        483
# 37        247
# 27        237
# 35        144
# 10        115
# 0         114
# 29         52
# 31         51
# 18         49
# 15         37
# 32         32
# 41         30
# 7          26
# 36         24
# 30          8
# 13          5
# 20          4
# 26          2
# 21          1
# 23          1
# 24          1
# 42          1
# 17          1
# 28          1
# 8           1
# Name: count, dtype: int64
# os_version
# os_version
# 3001    484070
# 222     424228
# 3017    400141
# 467     381805
# 89      353356
#          ...
# 1327         1
# 2975         1
# 1754         1
# 98           1
# 1689         1
# Name: count, Length: 3048, dtype: int64
# platform
# platform
# 0    9620617
# 2     131294
# Name: count, dtype: int64
# user_id
# user_id
# 179757    2861025
# 56111       30063
# 147615      24341
# 101728       5157
# 3798         4752
#            ...
# 174128          1
# 110869          1
# 9732            1
# 88956           1
# 169600          1
# Name: count, Length: 178823, dtype: int64
# content.id
# content.id
# 212    3674696
# 200     464889
# 199     449691
# 84      324251
# 158     317523
#         ...
# 47           1
# 129          1
# 62           1
# 122          1
# 24           1
# Name: count, Length: 211, dtype: int64
# button.name
# button.name
# 9    9665669
# 5      40961
# 6      27797
# 1      13596
# 2       2513
# 3        907
# 4        293
# 0        174
# 7          1
# Name: count, dtype: int64
# button_name
# button_name
# 5    9712960
# 3      23793
# 0       6094
# 2       5348
# 1       3716
# Name: count, dtype: int64
# question.id
# question.id
# 7796    8927122
# 6966       6160
# 7618       3607
# 5969       3324
# 5981       2875
#          ...
# 6004          1
# 7318          1
# 4874          1
# 1461          1
# 1172          1
# Name: count, Length: 7796, dtype: int64
# lesson.id
# lesson.id
# 5489    6101088
# 4120      23015
# 2073      16234
# 48        15803
# 3562      15409
#          ...
# 1734          1
# 2817          1
# 1963          1
# 4265          1
# 3081          1
# Name: count, Length: 5014, dtype: int64
# type
# type
# 7    9606953
# 3      89484
# 2      21465
# 4      19440
# 0      14126
# 1        442
# 5          1
# Name: count, dtype: int64
# plan.price
# plan.price
# 13    9718447
# 1       21343
# 11       4060
# 3        2230
# 4        2171
# 9        1500
# 5         850
# 6         496
# 8         461
# 7         326
# 0          23
# 10          3
# 2           1
# Name: count, dtype: int64
# paid_amount
# paid_amount
# 51    9720886
# 12      16836
# 49       2261
# 30       2160
# 22       1742
# 40       1483
# 1         896
# 0         871
# 6         855
# 33        827
# 34        494
# 39        461
# 36        325
# 43        316
# 17        254
# 7         242
# 5         213
# 16        101
# 44         99
# 42         95
# 14         71
# 11         68
# 41         56
# 10         40
# 4          38
# 15         28
# 37         27
# 21         24
# 48         24
# 29         20
# 38         17
# 9          13
# 47         12
# 8           9
# 28          8
# 2           6
# 45          5
# 26          4
# 19          4
# 18          3
# 20          3
# 46          3
# 25          2
# 24          2
# 3           1
# 13          1
# 32          1
# 23          1
# 31          1
# 27          1
# 35          1
# Name: count, dtype: int64
# coupon.discount_amount
# coupon.discount_amount
# 45    9720886
# 2       26590
# 28        896
# 33        871
# 12        855
# 37        316
# 25        254
# 8         219
# 16        213
# 29        101
# 34         96
# 38         95
# 36         71
# 3          68
# 39         56
# 4          40
# 20         38
# 31         28
# 40         27
# 6          24
# 18         24
# 42         20
# 1          18
# 9          17
# 5          13
# 26         12
# 7           9
# 11          8
# 21          7
# 24          6
# 32          5
# 19          4
# 15          4
# 30          3
# 10          3
# 17          3
# 43          2
# 23          2
# 35          1
# 0           1
# 13          1
# 27          1
# 14          1
# 41          1
# 22          1
# Name: count, dtype: int64
# pg.type
# pg.type
# 4    9747364
# 0       3731
# 1        767
# 2         49
# Name: count, dtype: int64
# content.difficulty
# content.difficulty
# 5    9626994
# 1      58628
# 3      36109
# 0      27485
# 2       2695
# Name: count, dtype: int64
# plan.type
# plan.type
# 3    9749472
# 1       1278
# 0       1161
# Name: count, dtype: int64
# trial.type
# trial.type
# 3    9721290
# 0      28182
# 1       2439
# Name: count, dtype: int64
#          city       client_event_time  country  device_family  device_type  \
# 0         885 2023-04-10 14:57:48.556      157           1028          608
# 1        3439 2023-03-12 08:26:16.224      157            129            4
# 2        3944 2023-03-12 08:23:04.955      157           1028          608
# 3         966 2023-03-12 08:32:39.271      157           1028          608
# 4        1259 2023-04-12 11:36:28.311      157           1028          608
# ...       ...                     ...      ...            ...          ...
# 9751906  2764 2022-02-21 04:56:12.117      157           1028          608
# 9751907  3439 2022-02-21 04:49:35.114      157            129            4
# 9751908  3423 2022-02-21 04:37:53.294      157           1028          608
# 9751909  3439 2022-02-21 04:13:10.443      157            134           37
# 9751910  3439 2022-02-21 04:43:01.015      157            128            3
#
#          event_type  language  os_name  os_version  platform  ...  \
# 0                 0        37        3         348         0  ...
# 1                 0        14       22         903         0  ...
# 2                 0        37        3         309         0  ...
# 3                 0        37        3         309         0  ...
# 4                 0        37        3         348         0  ...
# ...             ...       ...      ...         ...       ...  ...
# 9751906          16        37        3        3018         0  ...
# 9751907          16        37       22         843         0  ...
# 9751908          16        37        3        3018         0  ...
# 9751909          16        37       22         843         0  ...
# 9751910          16        37        6        3018         0  ...
#
#          question.id  lesson.id  type  plan.price  paid_amount  \
# 0               7796       5489     7          13           51
# 1               7796       5489     7          13           51
# 2               7796       5489     7          13           51
# 3               7796       5489     7          13           51
# 4               7796       5489     7          13           51
# ...              ...        ...   ...         ...          ...
# 9751906         7796       5489     7          13           51
# 9751907         7796       5489     7          13           51
# 9751908         7796       5489     7          13           51
# 9751909         7796       5489     7          13           51
# 9751910         7796       5489     7          13           51
#
#          coupon.discount_amount  pg.type  content.difficulty  plan.type  \
# 0                            45        4                   5          3
# 1                            45        4                   5          3
# 2                            45        4                   5          3
# 3                            45        4                   5          3
# 4                            45        4                   5          3
# ...                         ...      ...                 ...        ...
# 9751906                      45        4                   5          3
# 9751907                      45        4                   5          3
# 9751908                      45        4                   5          3
# 9751909                      45        4                   5          3
# 9751910                      45        4                   5          3
#
#          trial.type
# 0                 3
# 1                 3
# 2                 3
# 3                 3
# 4                 3
# ...             ...
# 9751906           0
# 9751907           0
# 9751908           0
# 9751909           0
# 9751910           0
#
# [9751911 rows x 24 columns]

# %%
# save encoder_dict
for encoder in encoder_dict:
    print(f"\n\n{encoder}")
    np.save(f'./encoders/{encoder}.npy', encoder_dict[encoder].classes_)
    
# save the DF
DF.to_csv('total.csv', index=False)
# Out:
# city
#
#
# country
#
#
# device_family
#
#
# device_type
#
#
# event_type
#
#
# language
#
#
# os_name
#
#
# os_version
#
#
# platform
#
#
# user_id
#
#
# content.id
#
#
# button.name
#
#
# button_name
#
#
# question.id
#
#
# lesson.id
#
#
# type
#
#
# plan.price
#
#
# paid_amount
#
#
# coupon.discount_amount
#
#
# pg.type
#
#
# content.difficulty
#
#
# plan.type
#
#
# trial.type

# %%
com_DF = DF[core_cols].copy() # copy core_cols

# le = LabelEncoder()
# le = le.fit(DF['event_type'])
# com_DF['event_type'] = le.transform(DF['event_type'])

print(com_DF.info())
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9751911 entries, 0 to 9751910
# Data columns (total 3 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   user_id            int32
#  1   event_type         int32
#  2   client_event_time  datetime64[ns]
# dtypes: datetime64[ns](1), int32(2)
# memory usage: 148.8 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9751911 entries, 0 to 9751910
# Data columns (total 24 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   city                    int32
#  1   client_event_time       datetime64[ns]
#  2   country                 int32
#  3   device_family           int32
#  4   device_type             int32
#  5   event_type              int32
#  6   language                int32
#  7   os_name                 int32
#  8   os_version              int32
#  9   platform                int32
#  10  user_id                 int32
#  11  content.id              int32
#  12  button.name             int32
#  13  button_name             int32
#  14  question.id             int32
#  15  lesson.id               int32
#  16  type                    int32
#  17  plan.price              int32
#  18  paid_amount             int32
#  19  coupon.discount_amount  int32
#  20  pg.type                 int32
#  21  content.difficulty      int32
#  22  plan.type               int32
#  23  trial.type              int32
# dtypes: datetime64[ns](1), int32(23)
# memory usage: 930.0 MB

# %%
big_df = pd.read_csv(path.join(BaseFilePath, dirname, filelist[9]), chunksize=2000000)
enc_chunks = []

for i, chunk in enumerate(big_df):
    # preprocessing
    chunk = chunk.drop('device_carrier', axis=1)
    chunk['client_event_time'] = pd.to_datetime(chunk['client_event_time'])
    chunk['os_version'] = chunk['os_version'].astype(str)
    
    # display
    print(f"\n\n{i}")
    print(chunk.info())
    
    # encoding
    for col in chunk.columns:
        # exception handling
        if col in ['client_event_time', 'device_carrier', 'is_trial', 'is_free_trial']:
            continue
        
        # label encoding
        chunk[col] = encoder_dict[col].transform(chunk[col])
        
    enc_chunks.append(chunk)
    
big_df = pd.concat(enc_chunks, axis=0)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\2755470516.py:4: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(big_df):
# 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Data columns (total 16 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   city               object
#  1   client_event_time  object
#  2   country            object
#  3   device_carrier     float64
#  4   device_family      object
#  5   device_type        object
#  6   event_type         object
#  7   language           object
#  8   os_name            object
#  9   os_version         object
#  10  platform           object
#  11  user_id            object
#  12  content.id         object
#  13  is_trial           object
#  14  lesson.id          object
#  15  is_free_trial      float64
# dtypes: float64(2), object(14)
# memory usage: 244.1+ MB
# None
#
#
# 1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 2000000 to 3999999
# Data columns (total 16 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   city               object
#  1   client_event_time  object
#  2   country            object
#  3   device_carrier     float64
#  4   device_family      object
#  5   device_type        object
#  6   event_type         object
#  7   language           object
#  8   os_name            object
#  9   os_version         object
#  10  platform           object
#  11  user_id            object
#  12  content.id         object
#  13  is_trial           bool
#  14  lesson.id          object
#  15  is_free_trial      float64
# dtypes: bool(1), float64(2), object(13)
# memory usage: 230.8+ MB
# None
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\2755470516.py:4: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(big_df):
# 2
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 4000000 to 5999999
# Data columns (total 16 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   city               object
#  1   client_event_time  object
#  2   country            object
#  3   device_carrier     float64
#  4   device_family      object
#  5   device_type        object
#  6   event_type         object
#  7   language           object
#  8   os_name            object
#  9   os_version         object
#  10  platform           object
#  11  user_id            object
#  12  content.id         object
#  13  is_trial           object
#  14  lesson.id          object
#  15  is_free_trial      float64
# dtypes: float64(2), object(14)
# memory usage: 244.1+ MB
# None
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\2755470516.py:4: DtypeWarning: Columns (9,13,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(big_df):
# 3
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 6000000 to 7999999
# Data columns (total 16 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   city               object
#  1   client_event_time  object
#  2   country            object
#  3   device_carrier     float64
#  4   device_family      object
#  5   device_type        object
#  6   event_type         object
#  7   language           object
#  8   os_name            object
#  9   os_version         object
#  10  platform           object
#  11  user_id            object
#  12  content.id         object
#  13  is_trial           object
#  14  lesson.id          object
#  15  is_free_trial      object
# dtypes: float64(1), object(15)
# memory usage: 244.1+ MB
# None
#
#
# 4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 8000000 to 9999999
# Data columns (total 16 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   city               object
#  1   client_event_time  object
#  2   country            object
#  3   device_carrier     float64
#  4   device_family      object
#  5   device_type        object
#  6   event_type         object
#  7   language           object
#  8   os_name            object
#  9   os_version         object
#  10  platform           object
#  11  user_id            object
#  12  content.id         object
#  13  is_trial           float64
#  14  lesson.id          object
#  15  is_free_trial      object
# dtypes: float64(2), object(14)
# memory usage: 244.1+ MB
# None
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\2755470516.py:4: DtypeWarning: Columns (9,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(big_df):
# 5
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 10000000 to 11999999
# Data columns (total 16 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   city               object
#  1   client_event_time  object
#  2   country            object
#  3   device_carrier     float64
#  4   device_family      object
#  5   device_type        object
#  6   event_type         object
#  7   language           object
#  8   os_name            object
#  9   os_version         object
#  10  platform           object
#  11  user_id            object
#  12  content.id         object
#  13  is_trial           float64
#  14  lesson.id          object
#  15  is_free_trial      object
# dtypes: float64(2), object(14)
# memory usage: 244.1+ MB
# None
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\2755470516.py:4: DtypeWarning: Columns (9,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(big_df):
# 6
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 12000000 to 13999999
# Data columns (total 16 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   city               object
#  1   client_event_time  object
#  2   country            object
#  3   device_carrier     float64
#  4   device_family      object
#  5   device_type        object
#  6   event_type         object
#  7   language           object
#  8   os_name            object
#  9   os_version         object
#  10  platform           object
#  11  user_id            object
#  12  content.id         object
#  13  is_trial           float64
#  14  lesson.id          object
#  15  is_free_trial      object
# dtypes: float64(2), object(14)
# memory usage: 244.1+ MB
# None
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\2755470516.py:4: DtypeWarning: Columns (13,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(big_df):
# 7
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 14000000 to 15999999
# Data columns (total 16 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   city               object
#  1   client_event_time  object
#  2   country            object
#  3   device_carrier     float64
#  4   device_family      object
#  5   device_type        object
#  6   event_type         object
#  7   language           object
#  8   os_name            object
#  9   os_version         object
#  10  platform           object
#  11  user_id            object
#  12  content.id         object
#  13  is_trial           object
#  14  lesson.id          object
#  15  is_free_trial      object
# dtypes: float64(1), object(15)
# memory usage: 244.1+ MB
# None
#
#
# 8
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 16000000 to 17999999
# Data columns (total 16 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   city               object
#  1   client_event_time  object
#  2   country            object
#  3   device_carrier     float64
#  4   device_family      object
#  5   device_type        object
#  6   event_type         object
#  7   language           object
#  8   os_name            object
#  9   os_version         object
#  10  platform           object
#  11  user_id            object
#  12  content.id         object
#  13  is_trial           bool
#  14  lesson.id          object
#  15  is_free_trial      float64
# dtypes: bool(1), float64(2), object(13)
# memory usage: 230.8+ MB
# None
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_5528\2755470516.py:4: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   for i, chunk in enumerate(big_df):
# 9
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 18000000 to 19999999
# Data columns (total 16 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   city               object
#  1   client_event_time  object
#  2   country            object
#  3   device_carrier     float64
#  4   device_family      object
#  5   device_type        object
#  6   event_type         object
#  7   language           object
#  8   os_name            object
#  9   os_version         object
#  10  platform           object
#  11  user_id            object
#  12  content.id         object
#  13  is_trial           object
#  14  lesson.id          object
#  15  is_free_trial      float64
# dtypes: float64(2), object(14)
# memory usage: 244.1+ MB
# None
#
#
# 10
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1029707 entries, 20000000 to 21029706
# Data columns (total 16 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   city               1004475 non-null  object
#  1   client_event_time  1029707 non-null  object
#  2   country            1012635 non-null  object
#  3   device_carrier     0 non-null        float64
#  4   device_family      1029693 non-null  object
#  5   device_type        1015760 non-null  object
#  6   event_type         1029707 non-null  object
#  7   language           1029707 non-null  object
#  8   os_name            1029704 non-null  object
#  9   os_version         1029586 non-null  object
#  10  platform           1029707 non-null  object
#  11  user_id            813552 non-null   object
#  12  content.id         1029665 non-null  object
#  13  is_trial           1029707 non-null  bool
#  14  lesson.id          1029707 non-null  object
#  15  is_free_trial      0 non-null        float64
# dtypes: bool(1), float64(2), object(13)
# memory usage: 118.8+ MB
# None

# %%
print(big_df.info())
big_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21029707 entries, 0 to 21029706
# Data columns (total 15 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   city               int32
#  1   client_event_time  datetime64[ns]
#  2   country            int32
#  3   device_family      int32
#  4   device_type        int32
#  5   event_type         int32
#  6   language           int32
#  7   os_name            int32
#  8   os_version         int32
#  9   platform           int32
#  10  user_id            int32
#  11  content.id         int32
#  12  is_trial           object
#  13  lesson.id          int32
#  14  is_free_trial      object
# dtypes: datetime64[ns](1), int32(12), object(2)
# memory usage: 1.4+ GB
# None
#    city       client_event_time  country  device_family  device_type  \
# 0  4170 2023-04-05 21:46:04.333      157           1028          608
# 1  4170 2023-04-05 21:55:50.787      157           1028          608
# 2  4170 2023-04-05 21:55:55.684      157           1028          608
# 3   978 2023-04-05 21:04:55.828      157            569          157
# 4   978 2023-04-05 21:05:34.139      157            569          157
#
#    event_type  language  os_name  os_version  platform  user_id  content.id  \
# 0           9        37        3         348         0   102080         124
# 1           9        37        3         348         0   102080         124
# 2           9        37        3         348         0   102080         124
# 3           9        37        3         348         0   125591          80
# 4           9        37        3         348         0   125591         181
#
#   is_trial  lesson.id is_free_trial
# 0    False       4543           NaN
# 1    False       4543           NaN
# 2    False       2557           NaN
# 3    False       2277           NaN
# 4    False        409           NaN

# %%
le1 = LabelEncoder()
le1 = le.fit(big_df['is_trial'])
le2 = LabelEncoder()
le2 = le.fit(big_df['is_free_trial'])

big_df['is_trial'] = le1.transform(big_df['is_trial'])
big_df['is_free_trial'] = le2.transform(big_df['is_free_trial'])

print(big_df.info())
big_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21029707 entries, 0 to 21029706
# Data columns (total 15 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   city               int32
#  1   client_event_time  datetime64[ns]
#  2   country            int32
#  3   device_family      int32
#  4   device_type        int32
#  5   event_type         int32
#  6   language           int32
#  7   os_name            int32
#  8   os_version         int32
#  9   platform           int32
#  10  user_id            int32
#  11  content.id         int32
#  12  is_trial           int32
#  13  lesson.id          int32
#  14  is_free_trial      int32
# dtypes: datetime64[ns](1), int32(14)
# memory usage: 1.3 GB
# None
#    city       client_event_time  country  device_family  device_type  \
# 0  4170 2023-04-05 21:46:04.333      157           1028          608
# 1  4170 2023-04-05 21:55:50.787      157           1028          608
# 2  4170 2023-04-05 21:55:55.684      157           1028          608
# 3   978 2023-04-05 21:04:55.828      157            569          157
# 4   978 2023-04-05 21:05:34.139      157            569          157
#
#    event_type  language  os_name  os_version  platform  user_id  content.id  \
# 0           9        37        3         348         0   102080         124
# 1           9        37        3         348         0   102080         124
# 2           9        37        3         348         0   102080         124
# 3           9        37        3         348         0   125591          80
# 4           9        37        3         348         0   125591         181
#
#    is_trial  lesson.id  is_free_trial
# 0         0       4543              2
# 1         0       4543              2
# 2         0       2557              2
# 3         0       2277              2
# 4         0        409              2

# %%
# save encoder_dict
np.save(f'./encoders/is_trial.npy', le1.classes_)
np.save(f'./encoders/is_free_trial.npy', le2.classes_)
    
# save the big_df
big_df.to_csv('total_lesson.csv', index=False)
print('done')
# Out:
# done
